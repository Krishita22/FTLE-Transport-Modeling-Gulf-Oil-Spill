# %%
# blue_pulsing_frames.py
import numpy as np
import matplotlib.pyplot as plt
import os

# === CONFIGURATION ===
T = 10
h = 0.01
frame_dt = 0.1
periods = 30
omega = (6 * np.pi) / 10
A = 0.1
epsilon = 0.25

# === FUNCTIONS ===
def a(t): return epsilon * np.sin(omega * t)
def b(t): return 1 - 2 * epsilon * np.sin(omega * t)
def f(x, t): return a(t) * x**2 + b(t) * x
def df_dx(x, t): return 2 * a(t) * x + b(t)

def compute_flow(X, Y, t):
    fx = f(X, t)
    dfx = df_dx(X, t)
    x_dot = -np.pi * A * np.sin(np.pi * fx) * np.cos(np.pi * Y)
    y_dot = np.pi * A * np.cos(np.pi * fx) * np.sin(np.pi * Y) * dfx
    return x_dot, y_dot

def rk4_flow(X, Y, t, h):
    k1x, k1y = compute_flow(X, Y, t)
    k2x, k2y = compute_flow(X + 0.5*h*k1x, Y + 0.5*h*k1y, t + 0.5*h)
    k3x, k3y = compute_flow(X + 0.5*h*k2x, Y + 0.5*h*k2y, t + 0.5*h)
    k4x, k4y = compute_flow(X + h*k3x, Y + h*k3y, t + h)
    X_new = X + (h/6)*(k1x + 2*k2x + 2*k3x + k4x)
    Y_new = Y + (h/6)*(k1y + 2*k2y + 2*k3y + k4y)
    return X_new, Y_new

# === GRID SETUP ===
x_vals = np.linspace(0, 2, 300)
y_vals = np.linspace(0, 1, 150)
X0, Y0 = np.meshgrid(x_vals, y_vals)

# === OUTPUT ===
output_folder = "blue_pulsing"
os.makedirs(output_folder, exist_ok=True)

# --- Compute FTLE for starting particle
X, Y = X0.copy(), Y0.copy()
for t in np.arange(0, T+h, h):
    X, Y = rk4_flow(X, Y, t, h)

dx = x_vals[1] - x_vals[0]
dy = y_vals[1] - y_vals[0]
J11 = (X[2:,1:-1] - X[:-2,1:-1]) / (2*dx)
J12 = (X[1:-1,2:] - X[1:-1,:-2]) / (2*dy)
J21 = (Y[2:,1:-1] - Y[:-2,1:-1]) / (2*dx)
J22 = (Y[1:-1,2:] - Y[1:-1,:-2]) / (2*dy)

ftle = np.full(J11.shape, np.nan)
for i in range(ftle.shape[0]):
    for j in range(ftle.shape[1]):
        J = np.array([[J11[i,j], J12[i,j]],
                      [J21[i,j], J22[i,j]]])
        delta = J.T @ J
        eigvals = np.linalg.eigvalsh(delta)
        max_eig = np.max(eigvals)
        if max_eig > 1e-12 and np.isfinite(max_eig):
            ftle[i,j] = (1.0/T) * np.log(np.sqrt(max_eig))

ftle_full = np.full_like(X0, np.nan)
ftle_full[1:-1,1:-1] = ftle

# --- Find blue region
# Blue region corresponds to min FTLE values
flat_idx = np.nanargmin(ftle_full)
blue_y, blue_x = np.unravel_index(int(flat_idx), ftle_full.shape)
blue_x_val = X0[blue_y, blue_x]
blue_y_val = Y0[blue_y, blue_x]

# === MAIN LOOP: pulsing blue particle
t0_values = np.arange(0, periods*(10/3), frame_dt)
particle_X = np.array([])  # stores all advected particles
particle_Y = np.array([])

for frame_idx, t0 in enumerate(t0_values):
    t_max = t0 + T
    X, Y = X0.copy(), Y0.copy()
    
    # Advect the FTLE field
    for t in np.arange(t0, t_max+h, h):
        X, Y = rk4_flow(X, Y, t, h)
    
    # Add new particle at blue FTLE spot every frame
    if particle_X.size == 0:
        particle_X = np.array([blue_x_val])
        particle_Y = np.array([blue_y_val])
    else:
        particle_X = np.concatenate([particle_X, [blue_x_val]])
        particle_Y = np.concatenate([particle_Y, [blue_y_val]])
    
    # Advect all particles for this frame
    for t in np.arange(t0, t0 + frame_dt + h, h):
        particle_X, particle_Y = rk4_flow(particle_X, particle_Y, t, h)
    
    # FTLE Jacobians
    J11 = (X[2:,1:-1] - X[:-2,1:-1]) / (2*dx)
    J12 = (X[1:-1,2:] - X[1:-1,:-2]) / (2*dy)
    J21 = (Y[2:,1:-1] - Y[:-2,1:-1]) / (2*dx)
    J22 = (Y[1:-1,2:] - Y[1:-1,:-2]) / (2*dy)

    ftle = np.full(J11.shape, np.nan)
    for i in range(ftle.shape[0]):
        for j in range(ftle.shape[1]):
            J = np.array([[J11[i,j], J12[i,j]],
                          [J21[i,j], J22[i,j]]])
            delta = J.T @ J
            eigvals = np.linalg.eigvalsh(delta)
            max_eig = np.max(eigvals)
            if max_eig > 1e-12 and np.isfinite(max_eig):
                ftle[i,j] = (1.0/T) * np.log(np.sqrt(max_eig))

    ftle_full[1:-1,1:-1] = ftle

    # === PLOTTING ===
    plt.figure(figsize=(12,6))
    plt.contourf(X0, Y0, np.ma.masked_invalid(ftle_full), levels=100, cmap='jet')
    plt.colorbar(label='FTLE')
    plt.scatter(particle_X, particle_Y, color='black', s=20, marker='o')
    plt.title(f"Blue Pulsing Particle | t={t0:.1f} → {t0+T:.1f}")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.xlim(0,2)
    plt.ylim(0,1)
    plt.gca().set_aspect('equal')
    filename = os.path.join(output_folder, f"blue_pulse_{frame_idx:04d}.png")
    plt.savefig(filename, dpi=150)
    plt.close()
    print(f"Saved: {filename}")
# Out:
# Saved: blue_pulsing/blue_pulse_0000.png
# Saved: blue_pulsing/blue_pulse_0001.png
# Saved: blue_pulsing/blue_pulse_0002.png
# Saved: blue_pulsing/blue_pulse_0003.png
# Saved: blue_pulsing/blue_pulse_0004.png
# Saved: blue_pulsing/blue_pulse_0005.png
# Saved: blue_pulsing/blue_pulse_0006.png
# Saved: blue_pulsing/blue_pulse_0007.png
# Saved: blue_pulsing/blue_pulse_0008.png
# Saved: blue_pulsing/blue_pulse_0009.png
# Saved: blue_pulsing/blue_pulse_0010.png
# Saved: blue_pulsing/blue_pulse_0011.png
# Saved: blue_pulsing/blue_pulse_0012.png
# Saved: blue_pulsing/blue_pulse_0013.png
# Saved: blue_pulsing/blue_pulse_0014.png
# Saved: blue_pulsing/blue_pulse_0015.png
# Saved: blue_pulsing/blue_pulse_0016.png
# Saved: blue_pulsing/blue_pulse_0017.png
# Saved: blue_pulsing/blue_pulse_0018.png
# Saved: blue_pulsing/blue_pulse_0019.png
# Saved: blue_pulsing/blue_pulse_0020.png
# Saved: blue_pulsing/blue_pulse_0021.png
# Saved: blue_pulsing/blue_pulse_0022.png
# Saved: blue_pulsing/blue_pulse_0023.png
# Saved: blue_pulsing/blue_pulse_0024.png
# Saved: blue_pulsing/blue_pulse_0025.png
# Saved: blue_pulsing/blue_pulse_0026.png
# Saved: blue_pulsing/blue_pulse_0027.png
# Saved: blue_pulsing/blue_pulse_0028.png
# Saved: blue_pulsing/blue_pulse_0029.png
# Saved: blue_pulsing/blue_pulse_0030.png
# Saved: blue_pulsing/blue_pulse_0031.png
# Saved: blue_pulsing/blue_pulse_0032.png
# Saved: blue_pulsing/blue_pulse_0033.png
# Saved: blue_pulsing/blue_pulse_0034.png
# Saved: blue_pulsing/blue_pulse_0035.png
# Saved: blue_pulsing/blue_pulse_0036.png
# Saved: blue_pulsing/blue_pulse_0037.png
# Saved: blue_pulsing/blue_pulse_0038.png
# Saved: blue_pulsing/blue_pulse_0039.png
# Saved: blue_pulsing/blue_pulse_0040.png
# Saved: blue_pulsing/blue_pulse_0041.png
# Saved: blue_pulsing/blue_pulse_0042.png
# Saved: blue_pulsing/blue_pulse_0043.png
# Saved: blue_pulsing/blue_pulse_0044.png
# Saved: blue_pulsing/blue_pulse_0045.png
# Saved: blue_pulsing/blue_pulse_0046.png
# Saved: blue_pulsing/blue_pulse_0047.png
# Saved: blue_pulsing/blue_pulse_0048.png
# Saved: blue_pulsing/blue_pulse_0049.png
# Saved: blue_pulsing/blue_pulse_0050.png
# Saved: blue_pulsing/blue_pulse_0051.png
# Saved: blue_pulsing/blue_pulse_0052.png
# Saved: blue_pulsing/blue_pulse_0053.png
# Saved: blue_pulsing/blue_pulse_0054.png
# Saved: blue_pulsing/blue_pulse_0055.png
# Saved: blue_pulsing/blue_pulse_0056.png
# Saved: blue_pulsing/blue_pulse_0057.png
# Saved: blue_pulsing/blue_pulse_0058.png
# Saved: blue_pulsing/blue_pulse_0059.png
# Saved: blue_pulsing/blue_pulse_0060.png
# Saved: blue_pulsing/blue_pulse_0061.png
# Saved: blue_pulsing/blue_pulse_0062.png
# Saved: blue_pulsing/blue_pulse_0063.png
# Saved: blue_pulsing/blue_pulse_0064.png
# Saved: blue_pulsing/blue_pulse_0065.png
# Saved: blue_pulsing/blue_pulse_0066.png
# Saved: blue_pulsing/blue_pulse_0067.png
# Saved: blue_pulsing/blue_pulse_0068.png
# Saved: blue_pulsing/blue_pulse_0069.png
# Saved: blue_pulsing/blue_pulse_0070.png
# Saved: blue_pulsing/blue_pulse_0071.png
# Saved: blue_pulsing/blue_pulse_0072.png
# Saved: blue_pulsing/blue_pulse_0073.png
# Saved: blue_pulsing/blue_pulse_0074.png
# Saved: blue_pulsing/blue_pulse_0075.png
# Saved: blue_pulsing/blue_pulse_0076.png
# Saved: blue_pulsing/blue_pulse_0077.png
# Saved: blue_pulsing/blue_pulse_0078.png
# Saved: blue_pulsing/blue_pulse_0079.png
# Saved: blue_pulsing/blue_pulse_0080.png
# Saved: blue_pulsing/blue_pulse_0081.png
# Saved: blue_pulsing/blue_pulse_0082.png
# Saved: blue_pulsing/blue_pulse_0083.png
# Saved: blue_pulsing/blue_pulse_0084.png
# Saved: blue_pulsing/blue_pulse_0085.png
# Saved: blue_pulsing/blue_pulse_0086.png
# Saved: blue_pulsing/blue_pulse_0087.png
# Saved: blue_pulsing/blue_pulse_0088.png
# Saved: blue_pulsing/blue_pulse_0089.png
# Saved: blue_pulsing/blue_pulse_0090.png
# Saved: blue_pulsing/blue_pulse_0091.png
# Saved: blue_pulsing/blue_pulse_0092.png
# Saved: blue_pulsing/blue_pulse_0093.png
# Saved: blue_pulsing/blue_pulse_0094.png
# Saved: blue_pulsing/blue_pulse_0095.png
# Saved: blue_pulsing/blue_pulse_0096.png
# Saved: blue_pulsing/blue_pulse_0097.png
# Saved: blue_pulsing/blue_pulse_0098.png
# Saved: blue_pulsing/blue_pulse_0099.png
# Saved: blue_pulsing/blue_pulse_0100.png
# Saved: blue_pulsing/blue_pulse_0101.png
# Saved: blue_pulsing/blue_pulse_0102.png
# Saved: blue_pulsing/blue_pulse_0103.png
# Saved: blue_pulsing/blue_pulse_0104.png
# Saved: blue_pulsing/blue_pulse_0105.png
# Saved: blue_pulsing/blue_pulse_0106.png
# Saved: blue_pulsing/blue_pulse_0107.png
# Saved: blue_pulsing/blue_pulse_0108.png
# Saved: blue_pulsing/blue_pulse_0109.png
# Saved: blue_pulsing/blue_pulse_0110.png
# Saved: blue_pulsing/blue_pulse_0111.png
# Saved: blue_pulsing/blue_pulse_0112.png
# Saved: blue_pulsing/blue_pulse_0113.png
# Saved: blue_pulsing/blue_pulse_0114.png
# Saved: blue_pulsing/blue_pulse_0115.png
# Saved: blue_pulsing/blue_pulse_0116.png
# Saved: blue_pulsing/blue_pulse_0117.png
# Saved: blue_pulsing/blue_pulse_0118.png
# Saved: blue_pulsing/blue_pulse_0119.png
# Saved: blue_pulsing/blue_pulse_0120.png
# Saved: blue_pulsing/blue_pulse_0121.png
# Saved: blue_pulsing/blue_pulse_0122.png
# Saved: blue_pulsing/blue_pulse_0123.png
# Saved: blue_pulsing/blue_pulse_0124.png
# Saved: blue_pulsing/blue_pulse_0125.png
# Saved: blue_pulsing/blue_pulse_0126.png
# Saved: blue_pulsing/blue_pulse_0127.png
# Saved: blue_pulsing/blue_pulse_0128.png
# Saved: blue_pulsing/blue_pulse_0129.png
# Saved: blue_pulsing/blue_pulse_0130.png
# Saved: blue_pulsing/blue_pulse_0131.png
# Saved: blue_pulsing/blue_pulse_0132.png
# Saved: blue_pulsing/blue_pulse_0133.png
# Saved: blue_pulsing/blue_pulse_0134.png
# Saved: blue_pulsing/blue_pulse_0135.png
# Saved: blue_pulsing/blue_pulse_0136.png
# Saved: blue_pulsing/blue_pulse_0137.png
# Saved: blue_pulsing/blue_pulse_0138.png
# Saved: blue_pulsing/blue_pulse_0139.png
# Saved: blue_pulsing/blue_pulse_0140.png
# Saved: blue_pulsing/blue_pulse_0141.png
# Saved: blue_pulsing/blue_pulse_0142.png
# Saved: blue_pulsing/blue_pulse_0143.png
# Saved: blue_pulsing/blue_pulse_0144.png
# Saved: blue_pulsing/blue_pulse_0145.png
# Saved: blue_pulsing/blue_pulse_0146.png
# Saved: blue_pulsing/blue_pulse_0147.png
# Saved: blue_pulsing/blue_pulse_0148.png
# Saved: blue_pulsing/blue_pulse_0149.png
# Saved: blue_pulsing/blue_pulse_0150.png
# Saved: blue_pulsing/blue_pulse_0151.png
# Saved: blue_pulsing/blue_pulse_0152.png
# Saved: blue_pulsing/blue_pulse_0153.png
# Saved: blue_pulsing/blue_pulse_0154.png
# Saved: blue_pulsing/blue_pulse_0155.png
# Saved: blue_pulsing/blue_pulse_0156.png
# Saved: blue_pulsing/blue_pulse_0157.png
# Saved: blue_pulsing/blue_pulse_0158.png
# Saved: blue_pulsing/blue_pulse_0159.png
# Saved: blue_pulsing/blue_pulse_0160.png
# Saved: blue_pulsing/blue_pulse_0161.png
# Saved: blue_pulsing/blue_pulse_0162.png
# Saved: blue_pulsing/blue_pulse_0163.png
# Saved: blue_pulsing/blue_pulse_0164.png
# Saved: blue_pulsing/blue_pulse_0165.png
# Saved: blue_pulsing/blue_pulse_0166.png
# Saved: blue_pulsing/blue_pulse_0167.png
# Saved: blue_pulsing/blue_pulse_0168.png
# Saved: blue_pulsing/blue_pulse_0169.png
# Saved: blue_pulsing/blue_pulse_0170.png
# Saved: blue_pulsing/blue_pulse_0171.png
# Saved: blue_pulsing/blue_pulse_0172.png
# Saved: blue_pulsing/blue_pulse_0173.png
# Saved: blue_pulsing/blue_pulse_0174.png
# Saved: blue_pulsing/blue_pulse_0175.png
# Saved: blue_pulsing/blue_pulse_0176.png
# Saved: blue_pulsing/blue_pulse_0177.png
# Saved: blue_pulsing/blue_pulse_0178.png
# Saved: blue_pulsing/blue_pulse_0179.png
# Saved: blue_pulsing/blue_pulse_0180.png
# Saved: blue_pulsing/blue_pulse_0181.png
# Saved: blue_pulsing/blue_pulse_0182.png
# Saved: blue_pulsing/blue_pulse_0183.png
# Saved: blue_pulsing/blue_pulse_0184.png
# Saved: blue_pulsing/blue_pulse_0185.png
# Saved: blue_pulsing/blue_pulse_0186.png
# Saved: blue_pulsing/blue_pulse_0187.png
# Saved: blue_pulsing/blue_pulse_0188.png
# Saved: blue_pulsing/blue_pulse_0189.png
# Saved: blue_pulsing/blue_pulse_0190.png
# Saved: blue_pulsing/blue_pulse_0191.png
# Saved: blue_pulsing/blue_pulse_0192.png
# Saved: blue_pulsing/blue_pulse_0193.png
# Saved: blue_pulsing/blue_pulse_0194.png
# Saved: blue_pulsing/blue_pulse_0195.png
# Saved: blue_pulsing/blue_pulse_0196.png
# Saved: blue_pulsing/blue_pulse_0197.png
# Saved: blue_pulsing/blue_pulse_0198.png
# Saved: blue_pulsing/blue_pulse_0199.png
# Saved: blue_pulsing/blue_pulse_0200.png
# Saved: blue_pulsing/blue_pulse_0201.png
# Saved: blue_pulsing/blue_pulse_0202.png
# Saved: blue_pulsing/blue_pulse_0203.png
# Saved: blue_pulsing/blue_pulse_0204.png
# Saved: blue_pulsing/blue_pulse_0205.png
# Saved: blue_pulsing/blue_pulse_0206.png
# Saved: blue_pulsing/blue_pulse_0207.png
# Saved: blue_pulsing/blue_pulse_0208.png
# Saved: blue_pulsing/blue_pulse_0209.png
# Saved: blue_pulsing/blue_pulse_0210.png
# Saved: blue_pulsing/blue_pulse_0211.png
# Saved: blue_pulsing/blue_pulse_0212.png
# Saved: blue_pulsing/blue_pulse_0213.png
# Saved: blue_pulsing/blue_pulse_0214.png
# Saved: blue_pulsing/blue_pulse_0215.png
# Saved: blue_pulsing/blue_pulse_0216.png
# Saved: blue_pulsing/blue_pulse_0217.png
# Saved: blue_pulsing/blue_pulse_0218.png
# Saved: blue_pulsing/blue_pulse_0219.png
# Saved: blue_pulsing/blue_pulse_0220.png
# Saved: blue_pulsing/blue_pulse_0221.png
# Saved: blue_pulsing/blue_pulse_0222.png
# Saved: blue_pulsing/blue_pulse_0223.png
# Saved: blue_pulsing/blue_pulse_0224.png
# Saved: blue_pulsing/blue_pulse_0225.png
# Saved: blue_pulsing/blue_pulse_0226.png
# Saved: blue_pulsing/blue_pulse_0227.png
# Saved: blue_pulsing/blue_pulse_0228.png
# Saved: blue_pulsing/blue_pulse_0229.png
# Saved: blue_pulsing/blue_pulse_0230.png
# Saved: blue_pulsing/blue_pulse_0231.png
# Saved: blue_pulsing/blue_pulse_0232.png
# Saved: blue_pulsing/blue_pulse_0233.png
# Saved: blue_pulsing/blue_pulse_0234.png
# Saved: blue_pulsing/blue_pulse_0235.png
# Saved: blue_pulsing/blue_pulse_0236.png
# Saved: blue_pulsing/blue_pulse_0237.png
# Saved: blue_pulsing/blue_pulse_0238.png
# Saved: blue_pulsing/blue_pulse_0239.png
# Saved: blue_pulsing/blue_pulse_0240.png
# Saved: blue_pulsing/blue_pulse_0241.png
# Saved: blue_pulsing/blue_pulse_0242.png
# Saved: blue_pulsing/blue_pulse_0243.png
# Saved: blue_pulsing/blue_pulse_0244.png
# Saved: blue_pulsing/blue_pulse_0245.png
# Saved: blue_pulsing/blue_pulse_0246.png
# Saved: blue_pulsing/blue_pulse_0247.png
# Saved: blue_pulsing/blue_pulse_0248.png
# Saved: blue_pulsing/blue_pulse_0249.png
# Saved: blue_pulsing/blue_pulse_0250.png
# Saved: blue_pulsing/blue_pulse_0251.png
# Saved: blue_pulsing/blue_pulse_0252.png
# Saved: blue_pulsing/blue_pulse_0253.png
# Saved: blue_pulsing/blue_pulse_0254.png
# Saved: blue_pulsing/blue_pulse_0255.png
# Saved: blue_pulsing/blue_pulse_0256.png
# Saved: blue_pulsing/blue_pulse_0257.png
# Saved: blue_pulsing/blue_pulse_0258.png
# Saved: blue_pulsing/blue_pulse_0259.png
# Saved: blue_pulsing/blue_pulse_0260.png
# Saved: blue_pulsing/blue_pulse_0261.png
# Saved: blue_pulsing/blue_pulse_0262.png
# Saved: blue_pulsing/blue_pulse_0263.png
# Saved: blue_pulsing/blue_pulse_0264.png
# Saved: blue_pulsing/blue_pulse_0265.png
# Saved: blue_pulsing/blue_pulse_0266.png
# Saved: blue_pulsing/blue_pulse_0267.png
# Saved: blue_pulsing/blue_pulse_0268.png
# Saved: blue_pulsing/blue_pulse_0269.png
# Saved: blue_pulsing/blue_pulse_0270.png
# Saved: blue_pulsing/blue_pulse_0271.png
# Saved: blue_pulsing/blue_pulse_0272.png
# Saved: blue_pulsing/blue_pulse_0273.png
# Saved: blue_pulsing/blue_pulse_0274.png
# Saved: blue_pulsing/blue_pulse_0275.png
# Saved: blue_pulsing/blue_pulse_0276.png
# Saved: blue_pulsing/blue_pulse_0277.png
# Saved: blue_pulsing/blue_pulse_0278.png
# Saved: blue_pulsing/blue_pulse_0279.png
# Saved: blue_pulsing/blue_pulse_0280.png
# Saved: blue_pulsing/blue_pulse_0281.png
# Saved: blue_pulsing/blue_pulse_0282.png
# Saved: blue_pulsing/blue_pulse_0283.png
# Saved: blue_pulsing/blue_pulse_0284.png
# Saved: blue_pulsing/blue_pulse_0285.png
# Saved: blue_pulsing/blue_pulse_0286.png
# Saved: blue_pulsing/blue_pulse_0287.png
# Saved: blue_pulsing/blue_pulse_0288.png
# Saved: blue_pulsing/blue_pulse_0289.png
# Saved: blue_pulsing/blue_pulse_0290.png
# Saved: blue_pulsing/blue_pulse_0291.png
# Saved: blue_pulsing/blue_pulse_0292.png
# Saved: blue_pulsing/blue_pulse_0293.png
# Saved: blue_pulsing/blue_pulse_0294.png
# Saved: blue_pulsing/blue_pulse_0295.png
# Saved: blue_pulsing/blue_pulse_0296.png
# Saved: blue_pulsing/blue_pulse_0297.png
# Saved: blue_pulsing/blue_pulse_0298.png
# Saved: blue_pulsing/blue_pulse_0299.png
# Saved: blue_pulsing/blue_pulse_0300.png
# Saved: blue_pulsing/blue_pulse_0301.png
# Saved: blue_pulsing/blue_pulse_0302.png
# Saved: blue_pulsing/blue_pulse_0303.png
# Saved: blue_pulsing/blue_pulse_0304.png
# Saved: blue_pulsing/blue_pulse_0305.png
# Saved: blue_pulsing/blue_pulse_0306.png
# Saved: blue_pulsing/blue_pulse_0307.png
# Saved: blue_pulsing/blue_pulse_0308.png
# Saved: blue_pulsing/blue_pulse_0309.png
# Saved: blue_pulsing/blue_pulse_0310.png
# Saved: blue_pulsing/blue_pulse_0311.png
# Saved: blue_pulsing/blue_pulse_0312.png
# Saved: blue_pulsing/blue_pulse_0313.png
# Saved: blue_pulsing/blue_pulse_0314.png
# Saved: blue_pulsing/blue_pulse_0315.png
# Saved: blue_pulsing/blue_pulse_0316.png
# Saved: blue_pulsing/blue_pulse_0317.png
# Saved: blue_pulsing/blue_pulse_0318.png
# Saved: blue_pulsing/blue_pulse_0319.png
# Saved: blue_pulsing/blue_pulse_0320.png
# Saved: blue_pulsing/blue_pulse_0321.png
# Saved: blue_pulsing/blue_pulse_0322.png
# Saved: blue_pulsing/blue_pulse_0323.png
# Saved: blue_pulsing/blue_pulse_0324.png
# Saved: blue_pulsing/blue_pulse_0325.png
# Saved: blue_pulsing/blue_pulse_0326.png
# Saved: blue_pulsing/blue_pulse_0327.png
# Saved: blue_pulsing/blue_pulse_0328.png
# Saved: blue_pulsing/blue_pulse_0329.png
# Saved: blue_pulsing/blue_pulse_0330.png
# Saved: blue_pulsing/blue_pulse_0331.png
# Saved: blue_pulsing/blue_pulse_0332.png
# Saved: blue_pulsing/blue_pulse_0333.png
# Saved: blue_pulsing/blue_pulse_0334.png
# Saved: blue_pulsing/blue_pulse_0335.png
# Saved: blue_pulsing/blue_pulse_0336.png
# Saved: blue_pulsing/blue_pulse_0337.png
# Saved: blue_pulsing/blue_pulse_0338.png
# Saved: blue_pulsing/blue_pulse_0339.png
# Saved: blue_pulsing/blue_pulse_0340.png
# Saved: blue_pulsing/blue_pulse_0341.png
# Saved: blue_pulsing/blue_pulse_0342.png
# Saved: blue_pulsing/blue_pulse_0343.png
# Saved: blue_pulsing/blue_pulse_0344.png
# Saved: blue_pulsing/blue_pulse_0345.png
# Saved: blue_pulsing/blue_pulse_0346.png
# Saved: blue_pulsing/blue_pulse_0347.png
# Saved: blue_pulsing/blue_pulse_0348.png
# Saved: blue_pulsing/blue_pulse_0349.png
# Saved: blue_pulsing/blue_pulse_0350.png
# Saved: blue_pulsing/blue_pulse_0351.png
# Saved: blue_pulsing/blue_pulse_0352.png
# Saved: blue_pulsing/blue_pulse_0353.png
# Saved: blue_pulsing/blue_pulse_0354.png
# Saved: blue_pulsing/blue_pulse_0355.png
# Saved: blue_pulsing/blue_pulse_0356.png
# Saved: blue_pulsing/blue_pulse_0357.png
# Saved: blue_pulsing/blue_pulse_0358.png
# Saved: blue_pulsing/blue_pulse_0359.png
# Saved: blue_pulsing/blue_pulse_0360.png
# Saved: blue_pulsing/blue_pulse_0361.png
# Saved: blue_pulsing/blue_pulse_0362.png
# Saved: blue_pulsing/blue_pulse_0363.png
# Saved: blue_pulsing/blue_pulse_0364.png
# Saved: blue_pulsing/blue_pulse_0365.png
# Saved: blue_pulsing/blue_pulse_0366.png
# Saved: blue_pulsing/blue_pulse_0367.png
# Saved: blue_pulsing/blue_pulse_0368.png
# Saved: blue_pulsing/blue_pulse_0369.png
# Saved: blue_pulsing/blue_pulse_0370.png
# Saved: blue_pulsing/blue_pulse_0371.png
# Saved: blue_pulsing/blue_pulse_0372.png
# Saved: blue_pulsing/blue_pulse_0373.png
# Saved: blue_pulsing/blue_pulse_0374.png
# Saved: blue_pulsing/blue_pulse_0375.png
# Saved: blue_pulsing/blue_pulse_0376.png
# Saved: blue_pulsing/blue_pulse_0377.png
# Saved: blue_pulsing/blue_pulse_0378.png
# Saved: blue_pulsing/blue_pulse_0379.png
# Saved: blue_pulsing/blue_pulse_0380.png
# Saved: blue_pulsing/blue_pulse_0381.png
# Saved: blue_pulsing/blue_pulse_0382.png
# Saved: blue_pulsing/blue_pulse_0383.png
# Saved: blue_pulsing/blue_pulse_0384.png
# Saved: blue_pulsing/blue_pulse_0385.png
# Saved: blue_pulsing/blue_pulse_0386.png
# Saved: blue_pulsing/blue_pulse_0387.png
# Saved: blue_pulsing/blue_pulse_0388.png
# Saved: blue_pulsing/blue_pulse_0389.png
# Saved: blue_pulsing/blue_pulse_0390.png
# Saved: blue_pulsing/blue_pulse_0391.png
# Saved: blue_pulsing/blue_pulse_0392.png
# Saved: blue_pulsing/blue_pulse_0393.png
# Saved: blue_pulsing/blue_pulse_0394.png
# Saved: blue_pulsing/blue_pulse_0395.png
# Saved: blue_pulsing/blue_pulse_0396.png
# Saved: blue_pulsing/blue_pulse_0397.png
# Saved: blue_pulsing/blue_pulse_0398.png
# Saved: blue_pulsing/blue_pulse_0399.png
# Saved: blue_pulsing/blue_pulse_0400.png
# Saved: blue_pulsing/blue_pulse_0401.png
# Saved: blue_pulsing/blue_pulse_0402.png
# Saved: blue_pulsing/blue_pulse_0403.png
# Saved: blue_pulsing/blue_pulse_0404.png
# Saved: blue_pulsing/blue_pulse_0405.png
# Saved: blue_pulsing/blue_pulse_0406.png
# Saved: blue_pulsing/blue_pulse_0407.png
# Saved: blue_pulsing/blue_pulse_0408.png
# Saved: blue_pulsing/blue_pulse_0409.png
# Saved: blue_pulsing/blue_pulse_0410.png
# Saved: blue_pulsing/blue_pulse_0411.png
# Saved: blue_pulsing/blue_pulse_0412.png
# Saved: blue_pulsing/blue_pulse_0413.png
# Saved: blue_pulsing/blue_pulse_0414.png
# Saved: blue_pulsing/blue_pulse_0415.png
# Saved: blue_pulsing/blue_pulse_0416.png
# Saved: blue_pulsing/blue_pulse_0417.png
# Saved: blue_pulsing/blue_pulse_0418.png
# Saved: blue_pulsing/blue_pulse_0419.png
# Saved: blue_pulsing/blue_pulse_0420.png
# Saved: blue_pulsing/blue_pulse_0421.png
# Saved: blue_pulsing/blue_pulse_0422.png
# Saved: blue_pulsing/blue_pulse_0423.png
# Saved: blue_pulsing/blue_pulse_0424.png
# Saved: blue_pulsing/blue_pulse_0425.png
# Saved: blue_pulsing/blue_pulse_0426.png
# Saved: blue_pulsing/blue_pulse_0427.png
# Saved: blue_pulsing/blue_pulse_0428.png
# Saved: blue_pulsing/blue_pulse_0429.png
# Saved: blue_pulsing/blue_pulse_0430.png
# Saved: blue_pulsing/blue_pulse_0431.png
# Saved: blue_pulsing/blue_pulse_0432.png
# Saved: blue_pulsing/blue_pulse_0433.png
# Saved: blue_pulsing/blue_pulse_0434.png
# Saved: blue_pulsing/blue_pulse_0435.png
# Saved: blue_pulsing/blue_pulse_0436.png
# Saved: blue_pulsing/blue_pulse_0437.png
# Saved: blue_pulsing/blue_pulse_0438.png
# Saved: blue_pulsing/blue_pulse_0439.png
# Saved: blue_pulsing/blue_pulse_0440.png
# Saved: blue_pulsing/blue_pulse_0441.png
# Saved: blue_pulsing/blue_pulse_0442.png
# Saved: blue_pulsing/blue_pulse_0443.png
# Saved: blue_pulsing/blue_pulse_0444.png
# Saved: blue_pulsing/blue_pulse_0445.png
# Saved: blue_pulsing/blue_pulse_0446.png
# Saved: blue_pulsing/blue_pulse_0447.png
# Saved: blue_pulsing/blue_pulse_0448.png
# Saved: blue_pulsing/blue_pulse_0449.png
# Saved: blue_pulsing/blue_pulse_0450.png
# Saved: blue_pulsing/blue_pulse_0451.png
# Saved: blue_pulsing/blue_pulse_0452.png
# Saved: blue_pulsing/blue_pulse_0453.png
# Saved: blue_pulsing/blue_pulse_0454.png
# Saved: blue_pulsing/blue_pulse_0455.png
# Saved: blue_pulsing/blue_pulse_0456.png
# Saved: blue_pulsing/blue_pulse_0457.png
# Saved: blue_pulsing/blue_pulse_0458.png
# Saved: blue_pulsing/blue_pulse_0459.png
# Saved: blue_pulsing/blue_pulse_0460.png
# Saved: blue_pulsing/blue_pulse_0461.png
# Saved: blue_pulsing/blue_pulse_0462.png
# Saved: blue_pulsing/blue_pulse_0463.png
# Saved: blue_pulsing/blue_pulse_0464.png
# Saved: blue_pulsing/blue_pulse_0465.png
# Saved: blue_pulsing/blue_pulse_0466.png
# Saved: blue_pulsing/blue_pulse_0467.png
# Saved: blue_pulsing/blue_pulse_0468.png
# Saved: blue_pulsing/blue_pulse_0469.png
# Saved: blue_pulsing/blue_pulse_0470.png
# Saved: blue_pulsing/blue_pulse_0471.png
# Saved: blue_pulsing/blue_pulse_0472.png
# Saved: blue_pulsing/blue_pulse_0473.png
# Saved: blue_pulsing/blue_pulse_0474.png
# Saved: blue_pulsing/blue_pulse_0475.png
# Saved: blue_pulsing/blue_pulse_0476.png
# Saved: blue_pulsing/blue_pulse_0477.png
# Saved: blue_pulsing/blue_pulse_0478.png
# Saved: blue_pulsing/blue_pulse_0479.png
# Saved: blue_pulsing/blue_pulse_0480.png
# Saved: blue_pulsing/blue_pulse_0481.png
# Saved: blue_pulsing/blue_pulse_0482.png
# Saved: blue_pulsing/blue_pulse_0483.png
# Saved: blue_pulsing/blue_pulse_0484.png
# Saved: blue_pulsing/blue_pulse_0485.png
# Saved: blue_pulsing/blue_pulse_0486.png
# Saved: blue_pulsing/blue_pulse_0487.png
# Saved: blue_pulsing/blue_pulse_0488.png
# Saved: blue_pulsing/blue_pulse_0489.png
# Saved: blue_pulsing/blue_pulse_0490.png
# Saved: blue_pulsing/blue_pulse_0491.png
# Saved: blue_pulsing/blue_pulse_0492.png
# Saved: blue_pulsing/blue_pulse_0493.png
# Saved: blue_pulsing/blue_pulse_0494.png
# Saved: blue_pulsing/blue_pulse_0495.png
# Saved: blue_pulsing/blue_pulse_0496.png
# Saved: blue_pulsing/blue_pulse_0497.png
# Saved: blue_pulsing/blue_pulse_0498.png
# Saved: blue_pulsing/blue_pulse_0499.png
# Saved: blue_pulsing/blue_pulse_0500.png
# Saved: blue_pulsing/blue_pulse_0501.png
# Saved: blue_pulsing/blue_pulse_0502.png
# Saved: blue_pulsing/blue_pulse_0503.png
# Saved: blue_pulsing/blue_pulse_0504.png
# Saved: blue_pulsing/blue_pulse_0505.png
# Saved: blue_pulsing/blue_pulse_0506.png
# Saved: blue_pulsing/blue_pulse_0507.png
# Saved: blue_pulsing/blue_pulse_0508.png
# Saved: blue_pulsing/blue_pulse_0509.png
# Saved: blue_pulsing/blue_pulse_0510.png
# Saved: blue_pulsing/blue_pulse_0511.png
# Saved: blue_pulsing/blue_pulse_0512.png
# Saved: blue_pulsing/blue_pulse_0513.png
# Saved: blue_pulsing/blue_pulse_0514.png
# Saved: blue_pulsing/blue_pulse_0515.png
# Saved: blue_pulsing/blue_pulse_0516.png
# Saved: blue_pulsing/blue_pulse_0517.png
# Saved: blue_pulsing/blue_pulse_0518.png
# Saved: blue_pulsing/blue_pulse_0519.png
# Saved: blue_pulsing/blue_pulse_0520.png
# Saved: blue_pulsing/blue_pulse_0521.png
# Saved: blue_pulsing/blue_pulse_0522.png
# Saved: blue_pulsing/blue_pulse_0523.png
# Saved: blue_pulsing/blue_pulse_0524.png
# Saved: blue_pulsing/blue_pulse_0525.png
# Saved: blue_pulsing/blue_pulse_0526.png
# Saved: blue_pulsing/blue_pulse_0527.png
# Saved: blue_pulsing/blue_pulse_0528.png
# Saved: blue_pulsing/blue_pulse_0529.png
# Saved: blue_pulsing/blue_pulse_0530.png
# Saved: blue_pulsing/blue_pulse_0531.png
# Saved: blue_pulsing/blue_pulse_0532.png
# Saved: blue_pulsing/blue_pulse_0533.png
# Saved: blue_pulsing/blue_pulse_0534.png
# Saved: blue_pulsing/blue_pulse_0535.png
# Saved: blue_pulsing/blue_pulse_0536.png
# Saved: blue_pulsing/blue_pulse_0537.png
# Saved: blue_pulsing/blue_pulse_0538.png
# Saved: blue_pulsing/blue_pulse_0539.png
# Saved: blue_pulsing/blue_pulse_0540.png
# Saved: blue_pulsing/blue_pulse_0541.png
# Saved: blue_pulsing/blue_pulse_0542.png
# Saved: blue_pulsing/blue_pulse_0543.png
# Saved: blue_pulsing/blue_pulse_0544.png
# Saved: blue_pulsing/blue_pulse_0545.png
# Saved: blue_pulsing/blue_pulse_0546.png
# Saved: blue_pulsing/blue_pulse_0547.png
# Saved: blue_pulsing/blue_pulse_0548.png
# Saved: blue_pulsing/blue_pulse_0549.png
# Saved: blue_pulsing/blue_pulse_0550.png
# Saved: blue_pulsing/blue_pulse_0551.png
# Saved: blue_pulsing/blue_pulse_0552.png
# Saved: blue_pulsing/blue_pulse_0553.png
# Saved: blue_pulsing/blue_pulse_0554.png
# Saved: blue_pulsing/blue_pulse_0555.png
# Saved: blue_pulsing/blue_pulse_0556.png
# Saved: blue_pulsing/blue_pulse_0557.png
# Saved: blue_pulsing/blue_pulse_0558.png
# Saved: blue_pulsing/blue_pulse_0559.png
# Saved: blue_pulsing/blue_pulse_0560.png
# Saved: blue_pulsing/blue_pulse_0561.png
# Saved: blue_pulsing/blue_pulse_0562.png
# Saved: blue_pulsing/blue_pulse_0563.png
# Saved: blue_pulsing/blue_pulse_0564.png
# Saved: blue_pulsing/blue_pulse_0565.png
# Saved: blue_pulsing/blue_pulse_0566.png
# Saved: blue_pulsing/blue_pulse_0567.png
# Saved: blue_pulsing/blue_pulse_0568.png
# Saved: blue_pulsing/blue_pulse_0569.png
# Saved: blue_pulsing/blue_pulse_0570.png
# Saved: blue_pulsing/blue_pulse_0571.png
# Saved: blue_pulsing/blue_pulse_0572.png
# Saved: blue_pulsing/blue_pulse_0573.png
# Saved: blue_pulsing/blue_pulse_0574.png
# Saved: blue_pulsing/blue_pulse_0575.png
# Saved: blue_pulsing/blue_pulse_0576.png
# Saved: blue_pulsing/blue_pulse_0577.png
# Saved: blue_pulsing/blue_pulse_0578.png
# Saved: blue_pulsing/blue_pulse_0579.png
# Saved: blue_pulsing/blue_pulse_0580.png
# Saved: blue_pulsing/blue_pulse_0581.png
# Saved: blue_pulsing/blue_pulse_0582.png
# Saved: blue_pulsing/blue_pulse_0583.png
# Saved: blue_pulsing/blue_pulse_0584.png
# Saved: blue_pulsing/blue_pulse_0585.png
# Saved: blue_pulsing/blue_pulse_0586.png
# Saved: blue_pulsing/blue_pulse_0587.png
# Saved: blue_pulsing/blue_pulse_0588.png
# Saved: blue_pulsing/blue_pulse_0589.png
# Saved: blue_pulsing/blue_pulse_0590.png
# Saved: blue_pulsing/blue_pulse_0591.png
# Saved: blue_pulsing/blue_pulse_0592.png
# Saved: blue_pulsing/blue_pulse_0593.png
# Saved: blue_pulsing/blue_pulse_0594.png
# Saved: blue_pulsing/blue_pulse_0595.png
# Saved: blue_pulsing/blue_pulse_0596.png
# Saved: blue_pulsing/blue_pulse_0597.png
# Saved: blue_pulsing/blue_pulse_0598.png
# Saved: blue_pulsing/blue_pulse_0599.png
# Saved: blue_pulsing/blue_pulse_0600.png
# Saved: blue_pulsing/blue_pulse_0601.png
# Saved: blue_pulsing/blue_pulse_0602.png
# Saved: blue_pulsing/blue_pulse_0603.png
# Saved: blue_pulsing/blue_pulse_0604.png
# Saved: blue_pulsing/blue_pulse_0605.png
# Saved: blue_pulsing/blue_pulse_0606.png
# Saved: blue_pulsing/blue_pulse_0607.png
# Saved: blue_pulsing/blue_pulse_0608.png
# Saved: blue_pulsing/blue_pulse_0609.png
# Saved: blue_pulsing/blue_pulse_0610.png
# Saved: blue_pulsing/blue_pulse_0611.png
# Saved: blue_pulsing/blue_pulse_0612.png
# Saved: blue_pulsing/blue_pulse_0613.png
# Saved: blue_pulsing/blue_pulse_0614.png
# Saved: blue_pulsing/blue_pulse_0615.png
# Saved: blue_pulsing/blue_pulse_0616.png
# Saved: blue_pulsing/blue_pulse_0617.png
# Saved: blue_pulsing/blue_pulse_0618.png
# Saved: blue_pulsing/blue_pulse_0619.png
# Saved: blue_pulsing/blue_pulse_0620.png
# Saved: blue_pulsing/blue_pulse_0621.png
# Saved: blue_pulsing/blue_pulse_0622.png
# Saved: blue_pulsing/blue_pulse_0623.png
# Saved: blue_pulsing/blue_pulse_0624.png
# Saved: blue_pulsing/blue_pulse_0625.png
# Saved: blue_pulsing/blue_pulse_0626.png
# Saved: blue_pulsing/blue_pulse_0627.png
# Saved: blue_pulsing/blue_pulse_0628.png
# Saved: blue_pulsing/blue_pulse_0629.png
# Saved: blue_pulsing/blue_pulse_0630.png
# Saved: blue_pulsing/blue_pulse_0631.png
# Saved: blue_pulsing/blue_pulse_0632.png
# Saved: blue_pulsing/blue_pulse_0633.png
# Saved: blue_pulsing/blue_pulse_0634.png
# Saved: blue_pulsing/blue_pulse_0635.png
# Saved: blue_pulsing/blue_pulse_0636.png
# Saved: blue_pulsing/blue_pulse_0637.png
# Saved: blue_pulsing/blue_pulse_0638.png
# Saved: blue_pulsing/blue_pulse_0639.png
# Saved: blue_pulsing/blue_pulse_0640.png
# Saved: blue_pulsing/blue_pulse_0641.png
# Saved: blue_pulsing/blue_pulse_0642.png
# Saved: blue_pulsing/blue_pulse_0643.png
# Saved: blue_pulsing/blue_pulse_0644.png
# Saved: blue_pulsing/blue_pulse_0645.png
# Saved: blue_pulsing/blue_pulse_0646.png
# Saved: blue_pulsing/blue_pulse_0647.png
# Saved: blue_pulsing/blue_pulse_0648.png
# Saved: blue_pulsing/blue_pulse_0649.png
# Saved: blue_pulsing/blue_pulse_0650.png
# Saved: blue_pulsing/blue_pulse_0651.png
# Saved: blue_pulsing/blue_pulse_0652.png
# Saved: blue_pulsing/blue_pulse_0653.png
# Saved: blue_pulsing/blue_pulse_0654.png
# Saved: blue_pulsing/blue_pulse_0655.png
# Saved: blue_pulsing/blue_pulse_0656.png
# Saved: blue_pulsing/blue_pulse_0657.png
# Saved: blue_pulsing/blue_pulse_0658.png
# Saved: blue_pulsing/blue_pulse_0659.png
# Saved: blue_pulsing/blue_pulse_0660.png
# Saved: blue_pulsing/blue_pulse_0661.png
# Saved: blue_pulsing/blue_pulse_0662.png
# Saved: blue_pulsing/blue_pulse_0663.png
# Saved: blue_pulsing/blue_pulse_0664.png
# Saved: blue_pulsing/blue_pulse_0665.png
# Saved: blue_pulsing/blue_pulse_0666.png
# Saved: blue_pulsing/blue_pulse_0667.png
# Saved: blue_pulsing/blue_pulse_0668.png
# Saved: blue_pulsing/blue_pulse_0669.png
# Saved: blue_pulsing/blue_pulse_0670.png
# Saved: blue_pulsing/blue_pulse_0671.png
# Saved: blue_pulsing/blue_pulse_0672.png
# Saved: blue_pulsing/blue_pulse_0673.png
# Saved: blue_pulsing/blue_pulse_0674.png
# Saved: blue_pulsing/blue_pulse_0675.png
# Saved: blue_pulsing/blue_pulse_0676.png
# Saved: blue_pulsing/blue_pulse_0677.png
# Saved: blue_pulsing/blue_pulse_0678.png
# Saved: blue_pulsing/blue_pulse_0679.png
# Saved: blue_pulsing/blue_pulse_0680.png
# Saved: blue_pulsing/blue_pulse_0681.png
# Saved: blue_pulsing/blue_pulse_0682.png
# Saved: blue_pulsing/blue_pulse_0683.png
# Saved: blue_pulsing/blue_pulse_0684.png
# Saved: blue_pulsing/blue_pulse_0685.png
# Saved: blue_pulsing/blue_pulse_0686.png
# Saved: blue_pulsing/blue_pulse_0687.png
# Saved: blue_pulsing/blue_pulse_0688.png
# Saved: blue_pulsing/blue_pulse_0689.png
# Saved: blue_pulsing/blue_pulse_0690.png
# Saved: blue_pulsing/blue_pulse_0691.png
# Saved: blue_pulsing/blue_pulse_0692.png
# Saved: blue_pulsing/blue_pulse_0693.png
# Saved: blue_pulsing/blue_pulse_0694.png
# Saved: blue_pulsing/blue_pulse_0695.png
# Saved: blue_pulsing/blue_pulse_0696.png
# Saved: blue_pulsing/blue_pulse_0697.png
# Saved: blue_pulsing/blue_pulse_0698.png
# Saved: blue_pulsing/blue_pulse_0699.png
# Saved: blue_pulsing/blue_pulse_0700.png
# Saved: blue_pulsing/blue_pulse_0701.png
# Saved: blue_pulsing/blue_pulse_0702.png
# Saved: blue_pulsing/blue_pulse_0703.png
# Saved: blue_pulsing/blue_pulse_0704.png
# Saved: blue_pulsing/blue_pulse_0705.png
# Saved: blue_pulsing/blue_pulse_0706.png
# Saved: blue_pulsing/blue_pulse_0707.png
# Saved: blue_pulsing/blue_pulse_0708.png
# Saved: blue_pulsing/blue_pulse_0709.png
# Saved: blue_pulsing/blue_pulse_0710.png
# Saved: blue_pulsing/blue_pulse_0711.png
# Saved: blue_pulsing/blue_pulse_0712.png
# Saved: blue_pulsing/blue_pulse_0713.png
# Saved: blue_pulsing/blue_pulse_0714.png
# Saved: blue_pulsing/blue_pulse_0715.png
# Saved: blue_pulsing/blue_pulse_0716.png
# Saved: blue_pulsing/blue_pulse_0717.png
# Saved: blue_pulsing/blue_pulse_0718.png
# Saved: blue_pulsing/blue_pulse_0719.png
# Saved: blue_pulsing/blue_pulse_0720.png
# Saved: blue_pulsing/blue_pulse_0721.png
# Saved: blue_pulsing/blue_pulse_0722.png
# Saved: blue_pulsing/blue_pulse_0723.png
# Saved: blue_pulsing/blue_pulse_0724.png
# Saved: blue_pulsing/blue_pulse_0725.png
# Saved: blue_pulsing/blue_pulse_0726.png
# Saved: blue_pulsing/blue_pulse_0727.png
# Saved: blue_pulsing/blue_pulse_0728.png
# Saved: blue_pulsing/blue_pulse_0729.png
# Saved: blue_pulsing/blue_pulse_0730.png
# Saved: blue_pulsing/blue_pulse_0731.png
# Saved: blue_pulsing/blue_pulse_0732.png
# Saved: blue_pulsing/blue_pulse_0733.png
# Saved: blue_pulsing/blue_pulse_0734.png
# Saved: blue_pulsing/blue_pulse_0735.png
# Saved: blue_pulsing/blue_pulse_0736.png
# Saved: blue_pulsing/blue_pulse_0737.png
# Saved: blue_pulsing/blue_pulse_0738.png
# Saved: blue_pulsing/blue_pulse_0739.png
# Saved: blue_pulsing/blue_pulse_0740.png
# Saved: blue_pulsing/blue_pulse_0741.png
# Saved: blue_pulsing/blue_pulse_0742.png
# Saved: blue_pulsing/blue_pulse_0743.png
# Saved: blue_pulsing/blue_pulse_0744.png
# Saved: blue_pulsing/blue_pulse_0745.png
# Saved: blue_pulsing/blue_pulse_0746.png
# Saved: blue_pulsing/blue_pulse_0747.png
# Saved: blue_pulsing/blue_pulse_0748.png
# Saved: blue_pulsing/blue_pulse_0749.png
# Saved: blue_pulsing/blue_pulse_0750.png
# Saved: blue_pulsing/blue_pulse_0751.png
# Saved: blue_pulsing/blue_pulse_0752.png
# Saved: blue_pulsing/blue_pulse_0753.png
# Saved: blue_pulsing/blue_pulse_0754.png
# Saved: blue_pulsing/blue_pulse_0755.png
# Saved: blue_pulsing/blue_pulse_0756.png
# Saved: blue_pulsing/blue_pulse_0757.png
# Saved: blue_pulsing/blue_pulse_0758.png
# Saved: blue_pulsing/blue_pulse_0759.png
# Saved: blue_pulsing/blue_pulse_0760.png
# Saved: blue_pulsing/blue_pulse_0761.png
# Saved: blue_pulsing/blue_pulse_0762.png
# Saved: blue_pulsing/blue_pulse_0763.png
# Saved: blue_pulsing/blue_pulse_0764.png
# Saved: blue_pulsing/blue_pulse_0765.png
# Saved: blue_pulsing/blue_pulse_0766.png
# Saved: blue_pulsing/blue_pulse_0767.png
# Saved: blue_pulsing/blue_pulse_0768.png
# Saved: blue_pulsing/blue_pulse_0769.png
# Saved: blue_pulsing/blue_pulse_0770.png
# Saved: blue_pulsing/blue_pulse_0771.png
# Saved: blue_pulsing/blue_pulse_0772.png
# Saved: blue_pulsing/blue_pulse_0773.png
# Saved: blue_pulsing/blue_pulse_0774.png
# Saved: blue_pulsing/blue_pulse_0775.png
# Saved: blue_pulsing/blue_pulse_0776.png
# Saved: blue_pulsing/blue_pulse_0777.png
# Saved: blue_pulsing/blue_pulse_0778.png
# Saved: blue_pulsing/blue_pulse_0779.png
# Saved: blue_pulsing/blue_pulse_0780.png
# Saved: blue_pulsing/blue_pulse_0781.png
# Saved: blue_pulsing/blue_pulse_0782.png
# Saved: blue_pulsing/blue_pulse_0783.png
# Saved: blue_pulsing/blue_pulse_0784.png
# Saved: blue_pulsing/blue_pulse_0785.png
# Saved: blue_pulsing/blue_pulse_0786.png
# Saved: blue_pulsing/blue_pulse_0787.png
# Saved: blue_pulsing/blue_pulse_0788.png
# Saved: blue_pulsing/blue_pulse_0789.png
# Saved: blue_pulsing/blue_pulse_0790.png
# Saved: blue_pulsing/blue_pulse_0791.png
# Saved: blue_pulsing/blue_pulse_0792.png
# Saved: blue_pulsing/blue_pulse_0793.png
# Saved: blue_pulsing/blue_pulse_0794.png
# Saved: blue_pulsing/blue_pulse_0795.png
# Saved: blue_pulsing/blue_pulse_0796.png
# Saved: blue_pulsing/blue_pulse_0797.png
# Saved: blue_pulsing/blue_pulse_0798.png
# Saved: blue_pulsing/blue_pulse_0799.png
# Saved: blue_pulsing/blue_pulse_0800.png
# Saved: blue_pulsing/blue_pulse_0801.png
# Saved: blue_pulsing/blue_pulse_0802.png
# Saved: blue_pulsing/blue_pulse_0803.png
# Saved: blue_pulsing/blue_pulse_0804.png
# Saved: blue_pulsing/blue_pulse_0805.png
# Saved: blue_pulsing/blue_pulse_0806.png
# Saved: blue_pulsing/blue_pulse_0807.png
# Saved: blue_pulsing/blue_pulse_0808.png
# Saved: blue_pulsing/blue_pulse_0809.png
# Saved: blue_pulsing/blue_pulse_0810.png
# Saved: blue_pulsing/blue_pulse_0811.png
# Saved: blue_pulsing/blue_pulse_0812.png
# Saved: blue_pulsing/blue_pulse_0813.png
# Saved: blue_pulsing/blue_pulse_0814.png
# Saved: blue_pulsing/blue_pulse_0815.png
# Saved: blue_pulsing/blue_pulse_0816.png
# Saved: blue_pulsing/blue_pulse_0817.png
# Saved: blue_pulsing/blue_pulse_0818.png
# Saved: blue_pulsing/blue_pulse_0819.png
# Saved: blue_pulsing/blue_pulse_0820.png
# Saved: blue_pulsing/blue_pulse_0821.png
# Saved: blue_pulsing/blue_pulse_0822.png
# Saved: blue_pulsing/blue_pulse_0823.png
# Saved: blue_pulsing/blue_pulse_0824.png
# Saved: blue_pulsing/blue_pulse_0825.png
# Saved: blue_pulsing/blue_pulse_0826.png
# Saved: blue_pulsing/blue_pulse_0827.png
# Saved: blue_pulsing/blue_pulse_0828.png
# Saved: blue_pulsing/blue_pulse_0829.png
# Saved: blue_pulsing/blue_pulse_0830.png
# Saved: blue_pulsing/blue_pulse_0831.png
# Saved: blue_pulsing/blue_pulse_0832.png
# Saved: blue_pulsing/blue_pulse_0833.png
# Saved: blue_pulsing/blue_pulse_0834.png
# Saved: blue_pulsing/blue_pulse_0835.png
# Saved: blue_pulsing/blue_pulse_0836.png
# Saved: blue_pulsing/blue_pulse_0837.png
# Saved: blue_pulsing/blue_pulse_0838.png
# Saved: blue_pulsing/blue_pulse_0839.png
# Saved: blue_pulsing/blue_pulse_0840.png
# Saved: blue_pulsing/blue_pulse_0841.png
# Saved: blue_pulsing/blue_pulse_0842.png
# Saved: blue_pulsing/blue_pulse_0843.png
# Saved: blue_pulsing/blue_pulse_0844.png
# Saved: blue_pulsing/blue_pulse_0845.png
# Saved: blue_pulsing/blue_pulse_0846.png
# Saved: blue_pulsing/blue_pulse_0847.png
# Saved: blue_pulsing/blue_pulse_0848.png
# Saved: blue_pulsing/blue_pulse_0849.png
# Saved: blue_pulsing/blue_pulse_0850.png
# Saved: blue_pulsing/blue_pulse_0851.png
# Saved: blue_pulsing/blue_pulse_0852.png
# Saved: blue_pulsing/blue_pulse_0853.png
# Saved: blue_pulsing/blue_pulse_0854.png
# Saved: blue_pulsing/blue_pulse_0855.png
# Saved: blue_pulsing/blue_pulse_0856.png
# Saved: blue_pulsing/blue_pulse_0857.png
# Saved: blue_pulsing/blue_pulse_0858.png
# Saved: blue_pulsing/blue_pulse_0859.png
# Saved: blue_pulsing/blue_pulse_0860.png
# Saved: blue_pulsing/blue_pulse_0861.png
# Saved: blue_pulsing/blue_pulse_0862.png
# Saved: blue_pulsing/blue_pulse_0863.png
# Saved: blue_pulsing/blue_pulse_0864.png
# Saved: blue_pulsing/blue_pulse_0865.png
# Saved: blue_pulsing/blue_pulse_0866.png
# Saved: blue_pulsing/blue_pulse_0867.png
# Saved: blue_pulsing/blue_pulse_0868.png
# Saved: blue_pulsing/blue_pulse_0869.png
# Saved: blue_pulsing/blue_pulse_0870.png
# Saved: blue_pulsing/blue_pulse_0871.png
# Saved: blue_pulsing/blue_pulse_0872.png
# Saved: blue_pulsing/blue_pulse_0873.png
# Saved: blue_pulsing/blue_pulse_0874.png
# Saved: blue_pulsing/blue_pulse_0875.png
# Saved: blue_pulsing/blue_pulse_0876.png
# Saved: blue_pulsing/blue_pulse_0877.png
# Saved: blue_pulsing/blue_pulse_0878.png
# Saved: blue_pulsing/blue_pulse_0879.png
# Saved: blue_pulsing/blue_pulse_0880.png
# Saved: blue_pulsing/blue_pulse_0881.png
# Saved: blue_pulsing/blue_pulse_0882.png
# Saved: blue_pulsing/blue_pulse_0883.png
# Saved: blue_pulsing/blue_pulse_0884.png
# Saved: blue_pulsing/blue_pulse_0885.png
# Saved: blue_pulsing/blue_pulse_0886.png
# Saved: blue_pulsing/blue_pulse_0887.png
# Saved: blue_pulsing/blue_pulse_0888.png
# Saved: blue_pulsing/blue_pulse_0889.png
# Saved: blue_pulsing/blue_pulse_0890.png
# Saved: blue_pulsing/blue_pulse_0891.png
# Saved: blue_pulsing/blue_pulse_0892.png
# Saved: blue_pulsing/blue_pulse_0893.png
# Saved: blue_pulsing/blue_pulse_0894.png
# Saved: blue_pulsing/blue_pulse_0895.png
# Saved: blue_pulsing/blue_pulse_0896.png
# Saved: blue_pulsing/blue_pulse_0897.png
# Saved: blue_pulsing/blue_pulse_0898.png
# Saved: blue_pulsing/blue_pulse_0899.png
# Saved: blue_pulsing/blue_pulse_0900.png
# Saved: blue_pulsing/blue_pulse_0901.png
# Saved: blue_pulsing/blue_pulse_0902.png
# Saved: blue_pulsing/blue_pulse_0903.png
# Saved: blue_pulsing/blue_pulse_0904.png
# Saved: blue_pulsing/blue_pulse_0905.png
# Saved: blue_pulsing/blue_pulse_0906.png
# Saved: blue_pulsing/blue_pulse_0907.png
# Saved: blue_pulsing/blue_pulse_0908.png
# Saved: blue_pulsing/blue_pulse_0909.png
# Saved: blue_pulsing/blue_pulse_0910.png
# Saved: blue_pulsing/blue_pulse_0911.png
# Saved: blue_pulsing/blue_pulse_0912.png
# Saved: blue_pulsing/blue_pulse_0913.png
# Saved: blue_pulsing/blue_pulse_0914.png
# Saved: blue_pulsing/blue_pulse_0915.png
# Saved: blue_pulsing/blue_pulse_0916.png
# Saved: blue_pulsing/blue_pulse_0917.png
# Saved: blue_pulsing/blue_pulse_0918.png
# Saved: blue_pulsing/blue_pulse_0919.png
# Saved: blue_pulsing/blue_pulse_0920.png
# Saved: blue_pulsing/blue_pulse_0921.png
# Saved: blue_pulsing/blue_pulse_0922.png
# Saved: blue_pulsing/blue_pulse_0923.png
# Saved: blue_pulsing/blue_pulse_0924.png
# Saved: blue_pulsing/blue_pulse_0925.png
# Saved: blue_pulsing/blue_pulse_0926.png
# Saved: blue_pulsing/blue_pulse_0927.png
# Saved: blue_pulsing/blue_pulse_0928.png
# Saved: blue_pulsing/blue_pulse_0929.png
# Saved: blue_pulsing/blue_pulse_0930.png
# Saved: blue_pulsing/blue_pulse_0931.png
# Saved: blue_pulsing/blue_pulse_0932.png
# Saved: blue_pulsing/blue_pulse_0933.png
# Saved: blue_pulsing/blue_pulse_0934.png
# Saved: blue_pulsing/blue_pulse_0935.png
# Saved: blue_pulsing/blue_pulse_0936.png
# Saved: blue_pulsing/blue_pulse_0937.png
# Saved: blue_pulsing/blue_pulse_0938.png
# Saved: blue_pulsing/blue_pulse_0939.png
# Saved: blue_pulsing/blue_pulse_0940.png
# Saved: blue_pulsing/blue_pulse_0941.png
# Saved: blue_pulsing/blue_pulse_0942.png
# Saved: blue_pulsing/blue_pulse_0943.png
# Saved: blue_pulsing/blue_pulse_0944.png
# Saved: blue_pulsing/blue_pulse_0945.png
# Saved: blue_pulsing/blue_pulse_0946.png
# Saved: blue_pulsing/blue_pulse_0947.png
# Saved: blue_pulsing/blue_pulse_0948.png
# Saved: blue_pulsing/blue_pulse_0949.png
# Saved: blue_pulsing/blue_pulse_0950.png
# Saved: blue_pulsing/blue_pulse_0951.png
# Saved: blue_pulsing/blue_pulse_0952.png
# Saved: blue_pulsing/blue_pulse_0953.png
# Saved: blue_pulsing/blue_pulse_0954.png
# Saved: blue_pulsing/blue_pulse_0955.png
# Saved: blue_pulsing/blue_pulse_0956.png
# Saved: blue_pulsing/blue_pulse_0957.png
# Saved: blue_pulsing/blue_pulse_0958.png
# Saved: blue_pulsing/blue_pulse_0959.png
# Saved: blue_pulsing/blue_pulse_0960.png
# Saved: blue_pulsing/blue_pulse_0961.png
# Saved: blue_pulsing/blue_pulse_0962.png
# Saved: blue_pulsing/blue_pulse_0963.png
# Saved: blue_pulsing/blue_pulse_0964.png
# Saved: blue_pulsing/blue_pulse_0965.png
# Saved: blue_pulsing/blue_pulse_0966.png
# Saved: blue_pulsing/blue_pulse_0967.png
# Saved: blue_pulsing/blue_pulse_0968.png
# Saved: blue_pulsing/blue_pulse_0969.png
# Saved: blue_pulsing/blue_pulse_0970.png
# Saved: blue_pulsing/blue_pulse_0971.png
# Saved: blue_pulsing/blue_pulse_0972.png
# Saved: blue_pulsing/blue_pulse_0973.png
# Saved: blue_pulsing/blue_pulse_0974.png
# Saved: blue_pulsing/blue_pulse_0975.png
# Saved: blue_pulsing/blue_pulse_0976.png
# Saved: blue_pulsing/blue_pulse_0977.png
# Saved: blue_pulsing/blue_pulse_0978.png
# Saved: blue_pulsing/blue_pulse_0979.png
# Saved: blue_pulsing/blue_pulse_0980.png
# Saved: blue_pulsing/blue_pulse_0981.png
# Saved: blue_pulsing/blue_pulse_0982.png
# Saved: blue_pulsing/blue_pulse_0983.png
# Saved: blue_pulsing/blue_pulse_0984.png
# Saved: blue_pulsing/blue_pulse_0985.png
# Saved: blue_pulsing/blue_pulse_0986.png
# Saved: blue_pulsing/blue_pulse_0987.png
# Saved: blue_pulsing/blue_pulse_0988.png
# Saved: blue_pulsing/blue_pulse_0989.png
# Saved: blue_pulsing/blue_pulse_0990.png
# Saved: blue_pulsing/blue_pulse_0991.png
# Saved: blue_pulsing/blue_pulse_0992.png
# Saved: blue_pulsing/blue_pulse_0993.png
# Saved: blue_pulsing/blue_pulse_0994.png
# Saved: blue_pulsing/blue_pulse_0995.png
# Saved: blue_pulsing/blue_pulse_0996.png
# Saved: blue_pulsing/blue_pulse_0997.png
# Saved: blue_pulsing/blue_pulse_0998.png
# Saved: blue_pulsing/blue_pulse_0999.png

# %%
# blue_pulsing_movie.py
import cv2
import os
from glob import glob

def make_movie_from_frames(
    image_folder='blue_pulsing',
    output_filename='blue_pulsing.mp4',
    fps=10
):
    images = sorted(glob(os.path.join(image_folder, 'blue_pulse_*.png')))
    if not images:
        print(f"❌ No frames found in: {image_folder}")
        return

    first_frame = cv2.imread(images[0])
    height, width, _ = first_frame.shape

    out = cv2.VideoWriter(
        output_filename,
        cv2.VideoWriter_fourcc(*'mp4v'),
        fps,
        (width, height)
    )

    for img_path in images:
        frame = cv2.imread(img_path)
        if frame is not None:
            out.write(frame)

    out.release()
    print(f"✅ Movie saved to: {os.path.abspath(output_filename)}")

if __name__ == "__main__":
    make_movie_from_frames()
# Out:
# ✅ Movie saved to: /Users/krishitavaghani/blue_pulsing.mp4

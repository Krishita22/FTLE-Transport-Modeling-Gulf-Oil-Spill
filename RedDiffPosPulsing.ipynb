# %%
# save_reddiffpulsing_frames.py
import numpy as np
import matplotlib.pyplot as plt
import os

# === CONFIGURATION ===
T = 10
h = 0.01
frame_dt = 0.1
periods = 30
omega = (6 * np.pi) / 10
A = 0.1
epsilon = 0.25

# particle dot size (visual only)
blob_radius = 0.0002

# === GRID ===
x_vals = np.linspace(0, 2, 300)
y_vals = np.linspace(0, 1, 150)
X0, Y0 = np.meshgrid(x_vals, y_vals)
dx = x_vals[1] - x_vals[0]
dy = y_vals[1] - y_vals[0]

# === FUNCTIONS ===
def a(t): return epsilon * np.sin(omega * t)
def b(t): return 1 - 2 * epsilon * np.sin(omega * t)
def f(x, t): return a(t) * x**2 + b(t) * x
def df_dx(x, t): return 2 * a(t) * x + b(t)

def compute_flow(X, Y, t):
    fx = f(X, t)
    dfx = df_dx(X, t)
    x_dot = -np.pi * A * np.sin(np.pi * fx) * np.cos(np.pi * Y)
    y_dot = np.pi * A * np.cos(np.pi * fx) * np.sin(np.pi * Y) * dfx
    return x_dot, y_dot

def rk4_flow(X, Y, t, h):
    k1x, k1y = compute_flow(X, Y, t)
    k2x, k2y = compute_flow(X + 0.5*h*k1x, Y + 0.5*h*k1y, t + 0.5*h)
    k3x, k3y = compute_flow(X + 0.5*h*k2x, Y + 0.5*h*k2y, t + 0.5*h)
    k4x, k4y = compute_flow(X + h*k3x, Y + h*k3y, t + h)
    X_new = X + (h/6)*(k1x + 2*k2x + 2*k3x + k4x)
    Y_new = Y + (h/6)*(k1y + 2*k2y + 2*k3y + k4y)
    return X_new, Y_new

def compute_ftle(X0, Y0, t0, T, h):
    X, Y = X0.copy(), Y0.copy()
    for t in np.arange(t0, t0+T+h, h):
        X, Y = rk4_flow(X, Y, t, h)
    J11 = (X[2:,1:-1] - X[:-2,1:-1]) / (2*dx)
    J12 = (X[1:-1,2:] - X[1:-1,:-2]) / (2*dy)
    J21 = (Y[2:,1:-1] - Y[:-2,1:-1]) / (2*dx)
    J22 = (Y[1:-1,2:] - Y[1:-1,:-2]) / (2*dy)
    ftle = np.full(J11.shape, np.nan)
    for i in range(ftle.shape[0]):
        for j in range(ftle.shape[1]):
            J = np.array([[J11[i,j], J12[i,j]], [J21[i,j], J22[i,j]]])
            delta = J.T @ J
            eigvals = np.linalg.eigvalsh(delta)
            max_eig = np.max(eigvals)
            if max_eig > 1e-12 and np.isfinite(max_eig):
                ftle[i,j] = (1.0/T) * np.log(np.sqrt(max_eig))
    ftle_full = np.full_like(X0, np.nan, dtype=float)
    ftle_full[1:-1,1:-1] = ftle
    return ftle_full

# --- NEW: robust ridge-top picker (column-wise maxima on top band) ---
def pick_top_ridge_point(ftle_field, X0, Y0, y_cut=0.94):
    top_rows = np.where(Y0[:,0] >= y_cut)[0]
    if top_rows.size == 0:
        # fallback to global max
        i, j = np.unravel_index(np.nanargmax(ftle_field), ftle_field.shape)
        return X0[i,j], Y0[i,j]
    i_min = top_rows[0]
    best = (-np.inf, None, None)
    # for each column, take the local maximum within the top band
    for j in range(ftle_field.shape[1]):
        col = ftle_field[i_min:, j]
        if not np.isfinite(col).any():
            continue
        i_off = np.nanargmax(col)
        val = col[i_off]
        if np.isfinite(val) and val > best[0]:
            best = (val, i_min + i_off, j)
    if best[1] is None:
        i, j = np.unravel_index(np.nanargmax(ftle_field), ftle_field.shape)
    else:
        _, i, j = best
    return X0[i,j], Y0[i,j]

# === OUTPUT FOLDER ===
frame_folder = "reddiffpulsing"
os.makedirs(frame_folder, exist_ok=True)

# === (1) Detect the top red ridge once, to place the pulsing start ===
ftle0 = compute_ftle(X0, Y0, t0=0.0, T=T, h=h)
manual_start_x, manual_start_y = pick_top_ridge_point(ftle0, X0, Y0, y_cut=0.94)

# === (2) Pulsing particle arrays ===
particle_X = np.array([])
particle_Y = np.array([])

# === (3) Frame times over 'periods' full drive cycles (period = 10/3) ===
t0_values = np.arange(0, periods*(10/3), frame_dt)

# === MAIN LOOP ===
for frame_idx, t0 in enumerate(t0_values):
    ftle_frame = compute_ftle(X0, Y0, t0, T, h)

    # Drop a new particle at the ridge start (pulsing trail)
    if particle_X.size == 0:
        particle_X = np.array([manual_start_x])
        particle_Y = np.array([manual_start_y])
    else:
        particle_X = np.concatenate([particle_X, [manual_start_x]])
        particle_Y = np.concatenate([particle_Y, [manual_start_y]])

    # Advect ALL particles for this frame interval
    for t in np.arange(t0, t0 + frame_dt + h, h):
        particle_X, particle_Y = rk4_flow(particle_X, particle_Y, t, h)

    # Plot FTLE + pulsing particles
    plt.figure(figsize=(12, 6))
    plt.contourf(X0, Y0, np.ma.masked_invalid(ftle_frame), levels=100, cmap='jet')
    plt.colorbar(label="FTLE")
    plt.scatter(particle_X, particle_Y, color='black', s=(blob_radius*50000), marker='o')
    plt.title(f"Red Ridge Pulsing (top) | t0={t0:.2f}  start=({manual_start_x:.3f},{manual_start_y:.3f})")
    plt.xlabel("X"); plt.ylabel("Y")
    plt.xlim(0, 2); plt.ylim(0, 1); plt.gca().set_aspect('equal')

    filename = os.path.join(frame_folder, f"reddiffpulsing_{frame_idx:04d}.png")
    plt.savefig(filename, dpi=150, bbox_inches='tight')
    plt.close()
    print(f"Saved frame: {filename}")
# Out:
# Saved frame: reddiffpulsing/reddiffpulsing_0000.png
# Saved frame: reddiffpulsing/reddiffpulsing_0001.png
# Saved frame: reddiffpulsing/reddiffpulsing_0002.png
# Saved frame: reddiffpulsing/reddiffpulsing_0003.png
# Saved frame: reddiffpulsing/reddiffpulsing_0004.png
# Saved frame: reddiffpulsing/reddiffpulsing_0005.png
# Saved frame: reddiffpulsing/reddiffpulsing_0006.png
# Saved frame: reddiffpulsing/reddiffpulsing_0007.png
# Saved frame: reddiffpulsing/reddiffpulsing_0008.png
# Saved frame: reddiffpulsing/reddiffpulsing_0009.png
# Saved frame: reddiffpulsing/reddiffpulsing_0010.png
# Saved frame: reddiffpulsing/reddiffpulsing_0011.png
# Saved frame: reddiffpulsing/reddiffpulsing_0012.png
# Saved frame: reddiffpulsing/reddiffpulsing_0013.png
# Saved frame: reddiffpulsing/reddiffpulsing_0014.png
# Saved frame: reddiffpulsing/reddiffpulsing_0015.png
# Saved frame: reddiffpulsing/reddiffpulsing_0016.png
# Saved frame: reddiffpulsing/reddiffpulsing_0017.png
# Saved frame: reddiffpulsing/reddiffpulsing_0018.png
# Saved frame: reddiffpulsing/reddiffpulsing_0019.png
# Saved frame: reddiffpulsing/reddiffpulsing_0020.png
# Saved frame: reddiffpulsing/reddiffpulsing_0021.png
# Saved frame: reddiffpulsing/reddiffpulsing_0022.png
# Saved frame: reddiffpulsing/reddiffpulsing_0023.png
# Saved frame: reddiffpulsing/reddiffpulsing_0024.png
# Saved frame: reddiffpulsing/reddiffpulsing_0025.png
# Saved frame: reddiffpulsing/reddiffpulsing_0026.png
# Saved frame: reddiffpulsing/reddiffpulsing_0027.png
# Saved frame: reddiffpulsing/reddiffpulsing_0028.png
# Saved frame: reddiffpulsing/reddiffpulsing_0029.png
# Saved frame: reddiffpulsing/reddiffpulsing_0030.png
# Saved frame: reddiffpulsing/reddiffpulsing_0031.png
# Saved frame: reddiffpulsing/reddiffpulsing_0032.png
# Saved frame: reddiffpulsing/reddiffpulsing_0033.png
# Saved frame: reddiffpulsing/reddiffpulsing_0034.png
# Saved frame: reddiffpulsing/reddiffpulsing_0035.png
# Saved frame: reddiffpulsing/reddiffpulsing_0036.png
# Saved frame: reddiffpulsing/reddiffpulsing_0037.png
# Saved frame: reddiffpulsing/reddiffpulsing_0038.png
# Saved frame: reddiffpulsing/reddiffpulsing_0039.png
# Saved frame: reddiffpulsing/reddiffpulsing_0040.png
# Saved frame: reddiffpulsing/reddiffpulsing_0041.png
# Saved frame: reddiffpulsing/reddiffpulsing_0042.png
# Saved frame: reddiffpulsing/reddiffpulsing_0043.png
# Saved frame: reddiffpulsing/reddiffpulsing_0044.png
# Saved frame: reddiffpulsing/reddiffpulsing_0045.png
# Saved frame: reddiffpulsing/reddiffpulsing_0046.png
# Saved frame: reddiffpulsing/reddiffpulsing_0047.png
# Saved frame: reddiffpulsing/reddiffpulsing_0048.png
# Saved frame: reddiffpulsing/reddiffpulsing_0049.png
# Saved frame: reddiffpulsing/reddiffpulsing_0050.png
# Saved frame: reddiffpulsing/reddiffpulsing_0051.png
# Saved frame: reddiffpulsing/reddiffpulsing_0052.png
# Saved frame: reddiffpulsing/reddiffpulsing_0053.png
# Saved frame: reddiffpulsing/reddiffpulsing_0054.png
# Saved frame: reddiffpulsing/reddiffpulsing_0055.png
# Saved frame: reddiffpulsing/reddiffpulsing_0056.png
# Saved frame: reddiffpulsing/reddiffpulsing_0057.png
# Saved frame: reddiffpulsing/reddiffpulsing_0058.png
# Saved frame: reddiffpulsing/reddiffpulsing_0059.png
# Saved frame: reddiffpulsing/reddiffpulsing_0060.png
# Saved frame: reddiffpulsing/reddiffpulsing_0061.png
# Saved frame: reddiffpulsing/reddiffpulsing_0062.png
# Saved frame: reddiffpulsing/reddiffpulsing_0063.png
# Saved frame: reddiffpulsing/reddiffpulsing_0064.png
# Saved frame: reddiffpulsing/reddiffpulsing_0065.png
# Saved frame: reddiffpulsing/reddiffpulsing_0066.png
# Saved frame: reddiffpulsing/reddiffpulsing_0067.png
# Saved frame: reddiffpulsing/reddiffpulsing_0068.png
# Saved frame: reddiffpulsing/reddiffpulsing_0069.png
# Saved frame: reddiffpulsing/reddiffpulsing_0070.png
# Saved frame: reddiffpulsing/reddiffpulsing_0071.png
# Saved frame: reddiffpulsing/reddiffpulsing_0072.png
# Saved frame: reddiffpulsing/reddiffpulsing_0073.png
# Saved frame: reddiffpulsing/reddiffpulsing_0074.png
# Saved frame: reddiffpulsing/reddiffpulsing_0075.png
# Saved frame: reddiffpulsing/reddiffpulsing_0076.png
# Saved frame: reddiffpulsing/reddiffpulsing_0077.png
# Saved frame: reddiffpulsing/reddiffpulsing_0078.png
# Saved frame: reddiffpulsing/reddiffpulsing_0079.png
# Saved frame: reddiffpulsing/reddiffpulsing_0080.png
# Saved frame: reddiffpulsing/reddiffpulsing_0081.png
# Saved frame: reddiffpulsing/reddiffpulsing_0082.png
# Saved frame: reddiffpulsing/reddiffpulsing_0083.png
# Saved frame: reddiffpulsing/reddiffpulsing_0084.png
# Saved frame: reddiffpulsing/reddiffpulsing_0085.png
# Saved frame: reddiffpulsing/reddiffpulsing_0086.png
# Saved frame: reddiffpulsing/reddiffpulsing_0087.png
# Saved frame: reddiffpulsing/reddiffpulsing_0088.png
# Saved frame: reddiffpulsing/reddiffpulsing_0089.png
# Saved frame: reddiffpulsing/reddiffpulsing_0090.png
# Saved frame: reddiffpulsing/reddiffpulsing_0091.png
# Saved frame: reddiffpulsing/reddiffpulsing_0092.png
# Saved frame: reddiffpulsing/reddiffpulsing_0093.png
# Saved frame: reddiffpulsing/reddiffpulsing_0094.png
# Saved frame: reddiffpulsing/reddiffpulsing_0095.png
# Saved frame: reddiffpulsing/reddiffpulsing_0096.png
# Saved frame: reddiffpulsing/reddiffpulsing_0097.png
# Saved frame: reddiffpulsing/reddiffpulsing_0098.png
# Saved frame: reddiffpulsing/reddiffpulsing_0099.png
# Saved frame: reddiffpulsing/reddiffpulsing_0100.png
# Saved frame: reddiffpulsing/reddiffpulsing_0101.png
# Saved frame: reddiffpulsing/reddiffpulsing_0102.png
# Saved frame: reddiffpulsing/reddiffpulsing_0103.png
# Saved frame: reddiffpulsing/reddiffpulsing_0104.png
# Saved frame: reddiffpulsing/reddiffpulsing_0105.png
# Saved frame: reddiffpulsing/reddiffpulsing_0106.png
# Saved frame: reddiffpulsing/reddiffpulsing_0107.png
# Saved frame: reddiffpulsing/reddiffpulsing_0108.png
# Saved frame: reddiffpulsing/reddiffpulsing_0109.png
# Saved frame: reddiffpulsing/reddiffpulsing_0110.png
# Saved frame: reddiffpulsing/reddiffpulsing_0111.png
# Saved frame: reddiffpulsing/reddiffpulsing_0112.png
# Saved frame: reddiffpulsing/reddiffpulsing_0113.png
# Saved frame: reddiffpulsing/reddiffpulsing_0114.png
# Saved frame: reddiffpulsing/reddiffpulsing_0115.png
# Saved frame: reddiffpulsing/reddiffpulsing_0116.png
# Saved frame: reddiffpulsing/reddiffpulsing_0117.png
# Saved frame: reddiffpulsing/reddiffpulsing_0118.png
# Saved frame: reddiffpulsing/reddiffpulsing_0119.png
# Saved frame: reddiffpulsing/reddiffpulsing_0120.png
# Saved frame: reddiffpulsing/reddiffpulsing_0121.png
# Saved frame: reddiffpulsing/reddiffpulsing_0122.png
# Saved frame: reddiffpulsing/reddiffpulsing_0123.png
# Saved frame: reddiffpulsing/reddiffpulsing_0124.png
# Saved frame: reddiffpulsing/reddiffpulsing_0125.png
# Saved frame: reddiffpulsing/reddiffpulsing_0126.png
# Saved frame: reddiffpulsing/reddiffpulsing_0127.png
# Saved frame: reddiffpulsing/reddiffpulsing_0128.png
# Saved frame: reddiffpulsing/reddiffpulsing_0129.png
# Saved frame: reddiffpulsing/reddiffpulsing_0130.png
# Saved frame: reddiffpulsing/reddiffpulsing_0131.png
# Saved frame: reddiffpulsing/reddiffpulsing_0132.png
# Saved frame: reddiffpulsing/reddiffpulsing_0133.png
# Saved frame: reddiffpulsing/reddiffpulsing_0134.png
# Saved frame: reddiffpulsing/reddiffpulsing_0135.png
# Saved frame: reddiffpulsing/reddiffpulsing_0136.png
# Saved frame: reddiffpulsing/reddiffpulsing_0137.png
# Saved frame: reddiffpulsing/reddiffpulsing_0138.png
# Saved frame: reddiffpulsing/reddiffpulsing_0139.png
# Saved frame: reddiffpulsing/reddiffpulsing_0140.png
# Saved frame: reddiffpulsing/reddiffpulsing_0141.png
# Saved frame: reddiffpulsing/reddiffpulsing_0142.png
# Saved frame: reddiffpulsing/reddiffpulsing_0143.png
# Saved frame: reddiffpulsing/reddiffpulsing_0144.png
# Saved frame: reddiffpulsing/reddiffpulsing_0145.png
# Saved frame: reddiffpulsing/reddiffpulsing_0146.png
# Saved frame: reddiffpulsing/reddiffpulsing_0147.png
# Saved frame: reddiffpulsing/reddiffpulsing_0148.png
# Saved frame: reddiffpulsing/reddiffpulsing_0149.png
# Saved frame: reddiffpulsing/reddiffpulsing_0150.png
# Saved frame: reddiffpulsing/reddiffpulsing_0151.png
# Saved frame: reddiffpulsing/reddiffpulsing_0152.png
# Saved frame: reddiffpulsing/reddiffpulsing_0153.png
# Saved frame: reddiffpulsing/reddiffpulsing_0154.png
# Saved frame: reddiffpulsing/reddiffpulsing_0155.png
# Saved frame: reddiffpulsing/reddiffpulsing_0156.png
# Saved frame: reddiffpulsing/reddiffpulsing_0157.png
# Saved frame: reddiffpulsing/reddiffpulsing_0158.png
# Saved frame: reddiffpulsing/reddiffpulsing_0159.png
# Saved frame: reddiffpulsing/reddiffpulsing_0160.png
# Saved frame: reddiffpulsing/reddiffpulsing_0161.png
# Saved frame: reddiffpulsing/reddiffpulsing_0162.png
# Saved frame: reddiffpulsing/reddiffpulsing_0163.png
# Saved frame: reddiffpulsing/reddiffpulsing_0164.png
# Saved frame: reddiffpulsing/reddiffpulsing_0165.png
# Saved frame: reddiffpulsing/reddiffpulsing_0166.png
# Saved frame: reddiffpulsing/reddiffpulsing_0167.png
# Saved frame: reddiffpulsing/reddiffpulsing_0168.png
# Saved frame: reddiffpulsing/reddiffpulsing_0169.png
# Saved frame: reddiffpulsing/reddiffpulsing_0170.png
# Saved frame: reddiffpulsing/reddiffpulsing_0171.png
# Saved frame: reddiffpulsing/reddiffpulsing_0172.png
# Saved frame: reddiffpulsing/reddiffpulsing_0173.png
# Saved frame: reddiffpulsing/reddiffpulsing_0174.png
# Saved frame: reddiffpulsing/reddiffpulsing_0175.png
# Saved frame: reddiffpulsing/reddiffpulsing_0176.png
# Saved frame: reddiffpulsing/reddiffpulsing_0177.png
# Saved frame: reddiffpulsing/reddiffpulsing_0178.png
# Saved frame: reddiffpulsing/reddiffpulsing_0179.png
# Saved frame: reddiffpulsing/reddiffpulsing_0180.png
# Saved frame: reddiffpulsing/reddiffpulsing_0181.png
# Saved frame: reddiffpulsing/reddiffpulsing_0182.png
# Saved frame: reddiffpulsing/reddiffpulsing_0183.png
# Saved frame: reddiffpulsing/reddiffpulsing_0184.png
# Saved frame: reddiffpulsing/reddiffpulsing_0185.png
# Saved frame: reddiffpulsing/reddiffpulsing_0186.png
# Saved frame: reddiffpulsing/reddiffpulsing_0187.png
# Saved frame: reddiffpulsing/reddiffpulsing_0188.png
# Saved frame: reddiffpulsing/reddiffpulsing_0189.png
# Saved frame: reddiffpulsing/reddiffpulsing_0190.png
# Saved frame: reddiffpulsing/reddiffpulsing_0191.png
# Saved frame: reddiffpulsing/reddiffpulsing_0192.png
# Saved frame: reddiffpulsing/reddiffpulsing_0193.png
# Saved frame: reddiffpulsing/reddiffpulsing_0194.png
# Saved frame: reddiffpulsing/reddiffpulsing_0195.png
# Saved frame: reddiffpulsing/reddiffpulsing_0196.png
# Saved frame: reddiffpulsing/reddiffpulsing_0197.png
# Saved frame: reddiffpulsing/reddiffpulsing_0198.png
# Saved frame: reddiffpulsing/reddiffpulsing_0199.png
# Saved frame: reddiffpulsing/reddiffpulsing_0200.png
# Saved frame: reddiffpulsing/reddiffpulsing_0201.png
# Saved frame: reddiffpulsing/reddiffpulsing_0202.png
# Saved frame: reddiffpulsing/reddiffpulsing_0203.png
# Saved frame: reddiffpulsing/reddiffpulsing_0204.png
# Saved frame: reddiffpulsing/reddiffpulsing_0205.png
# Saved frame: reddiffpulsing/reddiffpulsing_0206.png
# Saved frame: reddiffpulsing/reddiffpulsing_0207.png
# Saved frame: reddiffpulsing/reddiffpulsing_0208.png
# Saved frame: reddiffpulsing/reddiffpulsing_0209.png
# Saved frame: reddiffpulsing/reddiffpulsing_0210.png
# Saved frame: reddiffpulsing/reddiffpulsing_0211.png
# Saved frame: reddiffpulsing/reddiffpulsing_0212.png
# Saved frame: reddiffpulsing/reddiffpulsing_0213.png
# Saved frame: reddiffpulsing/reddiffpulsing_0214.png
# Saved frame: reddiffpulsing/reddiffpulsing_0215.png
# Saved frame: reddiffpulsing/reddiffpulsing_0216.png
# Saved frame: reddiffpulsing/reddiffpulsing_0217.png
# Saved frame: reddiffpulsing/reddiffpulsing_0218.png
# Saved frame: reddiffpulsing/reddiffpulsing_0219.png
# Saved frame: reddiffpulsing/reddiffpulsing_0220.png
# Saved frame: reddiffpulsing/reddiffpulsing_0221.png
# Saved frame: reddiffpulsing/reddiffpulsing_0222.png
# Saved frame: reddiffpulsing/reddiffpulsing_0223.png
# Saved frame: reddiffpulsing/reddiffpulsing_0224.png
# Saved frame: reddiffpulsing/reddiffpulsing_0225.png
# Saved frame: reddiffpulsing/reddiffpulsing_0226.png
# Saved frame: reddiffpulsing/reddiffpulsing_0227.png
# Saved frame: reddiffpulsing/reddiffpulsing_0228.png
# Saved frame: reddiffpulsing/reddiffpulsing_0229.png
# Saved frame: reddiffpulsing/reddiffpulsing_0230.png
# Saved frame: reddiffpulsing/reddiffpulsing_0231.png
# Saved frame: reddiffpulsing/reddiffpulsing_0232.png
# Saved frame: reddiffpulsing/reddiffpulsing_0233.png
# Saved frame: reddiffpulsing/reddiffpulsing_0234.png
# Saved frame: reddiffpulsing/reddiffpulsing_0235.png
# Saved frame: reddiffpulsing/reddiffpulsing_0236.png
# Saved frame: reddiffpulsing/reddiffpulsing_0237.png
# Saved frame: reddiffpulsing/reddiffpulsing_0238.png
# Saved frame: reddiffpulsing/reddiffpulsing_0239.png
# Saved frame: reddiffpulsing/reddiffpulsing_0240.png
# Saved frame: reddiffpulsing/reddiffpulsing_0241.png
# Saved frame: reddiffpulsing/reddiffpulsing_0242.png
# Saved frame: reddiffpulsing/reddiffpulsing_0243.png
# Saved frame: reddiffpulsing/reddiffpulsing_0244.png
# Saved frame: reddiffpulsing/reddiffpulsing_0245.png
# Saved frame: reddiffpulsing/reddiffpulsing_0246.png
# Saved frame: reddiffpulsing/reddiffpulsing_0247.png
# Saved frame: reddiffpulsing/reddiffpulsing_0248.png
# Saved frame: reddiffpulsing/reddiffpulsing_0249.png
# Saved frame: reddiffpulsing/reddiffpulsing_0250.png
# Saved frame: reddiffpulsing/reddiffpulsing_0251.png
# Saved frame: reddiffpulsing/reddiffpulsing_0252.png
# Saved frame: reddiffpulsing/reddiffpulsing_0253.png
# Saved frame: reddiffpulsing/reddiffpulsing_0254.png
# Saved frame: reddiffpulsing/reddiffpulsing_0255.png
# Saved frame: reddiffpulsing/reddiffpulsing_0256.png
# Saved frame: reddiffpulsing/reddiffpulsing_0257.png
# Saved frame: reddiffpulsing/reddiffpulsing_0258.png
# Saved frame: reddiffpulsing/reddiffpulsing_0259.png
# Saved frame: reddiffpulsing/reddiffpulsing_0260.png
# Saved frame: reddiffpulsing/reddiffpulsing_0261.png
# Saved frame: reddiffpulsing/reddiffpulsing_0262.png
# Saved frame: reddiffpulsing/reddiffpulsing_0263.png
# Saved frame: reddiffpulsing/reddiffpulsing_0264.png
# Saved frame: reddiffpulsing/reddiffpulsing_0265.png
# Saved frame: reddiffpulsing/reddiffpulsing_0266.png
# Saved frame: reddiffpulsing/reddiffpulsing_0267.png
# Saved frame: reddiffpulsing/reddiffpulsing_0268.png
# Saved frame: reddiffpulsing/reddiffpulsing_0269.png
# Saved frame: reddiffpulsing/reddiffpulsing_0270.png
# Saved frame: reddiffpulsing/reddiffpulsing_0271.png
# Saved frame: reddiffpulsing/reddiffpulsing_0272.png
# Saved frame: reddiffpulsing/reddiffpulsing_0273.png
# Saved frame: reddiffpulsing/reddiffpulsing_0274.png
# Saved frame: reddiffpulsing/reddiffpulsing_0275.png
# Saved frame: reddiffpulsing/reddiffpulsing_0276.png
# Saved frame: reddiffpulsing/reddiffpulsing_0277.png
# Saved frame: reddiffpulsing/reddiffpulsing_0278.png
# Saved frame: reddiffpulsing/reddiffpulsing_0279.png
# Saved frame: reddiffpulsing/reddiffpulsing_0280.png
# Saved frame: reddiffpulsing/reddiffpulsing_0281.png
# Saved frame: reddiffpulsing/reddiffpulsing_0282.png
# Saved frame: reddiffpulsing/reddiffpulsing_0283.png
# Saved frame: reddiffpulsing/reddiffpulsing_0284.png
# Saved frame: reddiffpulsing/reddiffpulsing_0285.png
# Saved frame: reddiffpulsing/reddiffpulsing_0286.png
# Saved frame: reddiffpulsing/reddiffpulsing_0287.png
# Saved frame: reddiffpulsing/reddiffpulsing_0288.png
# Saved frame: reddiffpulsing/reddiffpulsing_0289.png
# Saved frame: reddiffpulsing/reddiffpulsing_0290.png
# Saved frame: reddiffpulsing/reddiffpulsing_0291.png
# Saved frame: reddiffpulsing/reddiffpulsing_0292.png
# Saved frame: reddiffpulsing/reddiffpulsing_0293.png
# Saved frame: reddiffpulsing/reddiffpulsing_0294.png
# Saved frame: reddiffpulsing/reddiffpulsing_0295.png
# Saved frame: reddiffpulsing/reddiffpulsing_0296.png
# Saved frame: reddiffpulsing/reddiffpulsing_0297.png
# Saved frame: reddiffpulsing/reddiffpulsing_0298.png
# Saved frame: reddiffpulsing/reddiffpulsing_0299.png
# Saved frame: reddiffpulsing/reddiffpulsing_0300.png
# Saved frame: reddiffpulsing/reddiffpulsing_0301.png
# Saved frame: reddiffpulsing/reddiffpulsing_0302.png
# Saved frame: reddiffpulsing/reddiffpulsing_0303.png
# Saved frame: reddiffpulsing/reddiffpulsing_0304.png
# Saved frame: reddiffpulsing/reddiffpulsing_0305.png
# Saved frame: reddiffpulsing/reddiffpulsing_0306.png
# Saved frame: reddiffpulsing/reddiffpulsing_0307.png
# Saved frame: reddiffpulsing/reddiffpulsing_0308.png
# Saved frame: reddiffpulsing/reddiffpulsing_0309.png
# Saved frame: reddiffpulsing/reddiffpulsing_0310.png
# Saved frame: reddiffpulsing/reddiffpulsing_0311.png
# Saved frame: reddiffpulsing/reddiffpulsing_0312.png
# Saved frame: reddiffpulsing/reddiffpulsing_0313.png
# Saved frame: reddiffpulsing/reddiffpulsing_0314.png
# Saved frame: reddiffpulsing/reddiffpulsing_0315.png
# Saved frame: reddiffpulsing/reddiffpulsing_0316.png
# Saved frame: reddiffpulsing/reddiffpulsing_0317.png
# Saved frame: reddiffpulsing/reddiffpulsing_0318.png
# Saved frame: reddiffpulsing/reddiffpulsing_0319.png
# Saved frame: reddiffpulsing/reddiffpulsing_0320.png
# Saved frame: reddiffpulsing/reddiffpulsing_0321.png
# Saved frame: reddiffpulsing/reddiffpulsing_0322.png
# Saved frame: reddiffpulsing/reddiffpulsing_0323.png
# Saved frame: reddiffpulsing/reddiffpulsing_0324.png
# Saved frame: reddiffpulsing/reddiffpulsing_0325.png
# Saved frame: reddiffpulsing/reddiffpulsing_0326.png
# Saved frame: reddiffpulsing/reddiffpulsing_0327.png
# Saved frame: reddiffpulsing/reddiffpulsing_0328.png
# Saved frame: reddiffpulsing/reddiffpulsing_0329.png
# Saved frame: reddiffpulsing/reddiffpulsing_0330.png
# Saved frame: reddiffpulsing/reddiffpulsing_0331.png
# Saved frame: reddiffpulsing/reddiffpulsing_0332.png
# Saved frame: reddiffpulsing/reddiffpulsing_0333.png
# Saved frame: reddiffpulsing/reddiffpulsing_0334.png
# Saved frame: reddiffpulsing/reddiffpulsing_0335.png
# Saved frame: reddiffpulsing/reddiffpulsing_0336.png
# Saved frame: reddiffpulsing/reddiffpulsing_0337.png
# Saved frame: reddiffpulsing/reddiffpulsing_0338.png
# Saved frame: reddiffpulsing/reddiffpulsing_0339.png
# Saved frame: reddiffpulsing/reddiffpulsing_0340.png
# Saved frame: reddiffpulsing/reddiffpulsing_0341.png
# Saved frame: reddiffpulsing/reddiffpulsing_0342.png
# Saved frame: reddiffpulsing/reddiffpulsing_0343.png
# Saved frame: reddiffpulsing/reddiffpulsing_0344.png
# Saved frame: reddiffpulsing/reddiffpulsing_0345.png
# Saved frame: reddiffpulsing/reddiffpulsing_0346.png
# Saved frame: reddiffpulsing/reddiffpulsing_0347.png
# Saved frame: reddiffpulsing/reddiffpulsing_0348.png
# Saved frame: reddiffpulsing/reddiffpulsing_0349.png
# Saved frame: reddiffpulsing/reddiffpulsing_0350.png
# Saved frame: reddiffpulsing/reddiffpulsing_0351.png
# Saved frame: reddiffpulsing/reddiffpulsing_0352.png
# Saved frame: reddiffpulsing/reddiffpulsing_0353.png
# Saved frame: reddiffpulsing/reddiffpulsing_0354.png
# Saved frame: reddiffpulsing/reddiffpulsing_0355.png
# Saved frame: reddiffpulsing/reddiffpulsing_0356.png
# Saved frame: reddiffpulsing/reddiffpulsing_0357.png
# Saved frame: reddiffpulsing/reddiffpulsing_0358.png
# Saved frame: reddiffpulsing/reddiffpulsing_0359.png
# Saved frame: reddiffpulsing/reddiffpulsing_0360.png
# Saved frame: reddiffpulsing/reddiffpulsing_0361.png
# Saved frame: reddiffpulsing/reddiffpulsing_0362.png
# Saved frame: reddiffpulsing/reddiffpulsing_0363.png
# Saved frame: reddiffpulsing/reddiffpulsing_0364.png
# Saved frame: reddiffpulsing/reddiffpulsing_0365.png
# Saved frame: reddiffpulsing/reddiffpulsing_0366.png
# Saved frame: reddiffpulsing/reddiffpulsing_0367.png
# Saved frame: reddiffpulsing/reddiffpulsing_0368.png
# Saved frame: reddiffpulsing/reddiffpulsing_0369.png
# Saved frame: reddiffpulsing/reddiffpulsing_0370.png
# Saved frame: reddiffpulsing/reddiffpulsing_0371.png
# Saved frame: reddiffpulsing/reddiffpulsing_0372.png
# Saved frame: reddiffpulsing/reddiffpulsing_0373.png
# Saved frame: reddiffpulsing/reddiffpulsing_0374.png
# Saved frame: reddiffpulsing/reddiffpulsing_0375.png
# Saved frame: reddiffpulsing/reddiffpulsing_0376.png
# Saved frame: reddiffpulsing/reddiffpulsing_0377.png
# Saved frame: reddiffpulsing/reddiffpulsing_0378.png
# Saved frame: reddiffpulsing/reddiffpulsing_0379.png
# Saved frame: reddiffpulsing/reddiffpulsing_0380.png
# Saved frame: reddiffpulsing/reddiffpulsing_0381.png
# Saved frame: reddiffpulsing/reddiffpulsing_0382.png
# Saved frame: reddiffpulsing/reddiffpulsing_0383.png
# Saved frame: reddiffpulsing/reddiffpulsing_0384.png
# Saved frame: reddiffpulsing/reddiffpulsing_0385.png
# Saved frame: reddiffpulsing/reddiffpulsing_0386.png
# Saved frame: reddiffpulsing/reddiffpulsing_0387.png
# Saved frame: reddiffpulsing/reddiffpulsing_0388.png
# Saved frame: reddiffpulsing/reddiffpulsing_0389.png
# Saved frame: reddiffpulsing/reddiffpulsing_0390.png
# Saved frame: reddiffpulsing/reddiffpulsing_0391.png
# Saved frame: reddiffpulsing/reddiffpulsing_0392.png
# Saved frame: reddiffpulsing/reddiffpulsing_0393.png
# Saved frame: reddiffpulsing/reddiffpulsing_0394.png
# Saved frame: reddiffpulsing/reddiffpulsing_0395.png
# Saved frame: reddiffpulsing/reddiffpulsing_0396.png
# Saved frame: reddiffpulsing/reddiffpulsing_0397.png
# Saved frame: reddiffpulsing/reddiffpulsing_0398.png
# Saved frame: reddiffpulsing/reddiffpulsing_0399.png
# Saved frame: reddiffpulsing/reddiffpulsing_0400.png
# Saved frame: reddiffpulsing/reddiffpulsing_0401.png
# Saved frame: reddiffpulsing/reddiffpulsing_0402.png
# Saved frame: reddiffpulsing/reddiffpulsing_0403.png
# Saved frame: reddiffpulsing/reddiffpulsing_0404.png
# Saved frame: reddiffpulsing/reddiffpulsing_0405.png
# Saved frame: reddiffpulsing/reddiffpulsing_0406.png
# Saved frame: reddiffpulsing/reddiffpulsing_0407.png
# Saved frame: reddiffpulsing/reddiffpulsing_0408.png
# Saved frame: reddiffpulsing/reddiffpulsing_0409.png
# Saved frame: reddiffpulsing/reddiffpulsing_0410.png
# Saved frame: reddiffpulsing/reddiffpulsing_0411.png
# Saved frame: reddiffpulsing/reddiffpulsing_0412.png
# Saved frame: reddiffpulsing/reddiffpulsing_0413.png
# Saved frame: reddiffpulsing/reddiffpulsing_0414.png
# Saved frame: reddiffpulsing/reddiffpulsing_0415.png
# Saved frame: reddiffpulsing/reddiffpulsing_0416.png
# Saved frame: reddiffpulsing/reddiffpulsing_0417.png
# Saved frame: reddiffpulsing/reddiffpulsing_0418.png
# Saved frame: reddiffpulsing/reddiffpulsing_0419.png
# Saved frame: reddiffpulsing/reddiffpulsing_0420.png
# Saved frame: reddiffpulsing/reddiffpulsing_0421.png
# Saved frame: reddiffpulsing/reddiffpulsing_0422.png
# Saved frame: reddiffpulsing/reddiffpulsing_0423.png
# Saved frame: reddiffpulsing/reddiffpulsing_0424.png
# Saved frame: reddiffpulsing/reddiffpulsing_0425.png
# Saved frame: reddiffpulsing/reddiffpulsing_0426.png
# Saved frame: reddiffpulsing/reddiffpulsing_0427.png
# Saved frame: reddiffpulsing/reddiffpulsing_0428.png
# Saved frame: reddiffpulsing/reddiffpulsing_0429.png
# Saved frame: reddiffpulsing/reddiffpulsing_0430.png
# Saved frame: reddiffpulsing/reddiffpulsing_0431.png
# Saved frame: reddiffpulsing/reddiffpulsing_0432.png
# Saved frame: reddiffpulsing/reddiffpulsing_0433.png
# Saved frame: reddiffpulsing/reddiffpulsing_0434.png
# Saved frame: reddiffpulsing/reddiffpulsing_0435.png
# Saved frame: reddiffpulsing/reddiffpulsing_0436.png
# Saved frame: reddiffpulsing/reddiffpulsing_0437.png
# Saved frame: reddiffpulsing/reddiffpulsing_0438.png
# Saved frame: reddiffpulsing/reddiffpulsing_0439.png
# Saved frame: reddiffpulsing/reddiffpulsing_0440.png
# Saved frame: reddiffpulsing/reddiffpulsing_0441.png
# Saved frame: reddiffpulsing/reddiffpulsing_0442.png
# Saved frame: reddiffpulsing/reddiffpulsing_0443.png
# Saved frame: reddiffpulsing/reddiffpulsing_0444.png
# Saved frame: reddiffpulsing/reddiffpulsing_0445.png
# Saved frame: reddiffpulsing/reddiffpulsing_0446.png
# Saved frame: reddiffpulsing/reddiffpulsing_0447.png
# Saved frame: reddiffpulsing/reddiffpulsing_0448.png
# Saved frame: reddiffpulsing/reddiffpulsing_0449.png
# Saved frame: reddiffpulsing/reddiffpulsing_0450.png
# Saved frame: reddiffpulsing/reddiffpulsing_0451.png
# Saved frame: reddiffpulsing/reddiffpulsing_0452.png
# Saved frame: reddiffpulsing/reddiffpulsing_0453.png
# Saved frame: reddiffpulsing/reddiffpulsing_0454.png
# Saved frame: reddiffpulsing/reddiffpulsing_0455.png
# Saved frame: reddiffpulsing/reddiffpulsing_0456.png
# Saved frame: reddiffpulsing/reddiffpulsing_0457.png
# Saved frame: reddiffpulsing/reddiffpulsing_0458.png
# Saved frame: reddiffpulsing/reddiffpulsing_0459.png
# Saved frame: reddiffpulsing/reddiffpulsing_0460.png
# Saved frame: reddiffpulsing/reddiffpulsing_0461.png
# Saved frame: reddiffpulsing/reddiffpulsing_0462.png
# Saved frame: reddiffpulsing/reddiffpulsing_0463.png
# Saved frame: reddiffpulsing/reddiffpulsing_0464.png
# Saved frame: reddiffpulsing/reddiffpulsing_0465.png
# Saved frame: reddiffpulsing/reddiffpulsing_0466.png
# Saved frame: reddiffpulsing/reddiffpulsing_0467.png
# Saved frame: reddiffpulsing/reddiffpulsing_0468.png
# Saved frame: reddiffpulsing/reddiffpulsing_0469.png
# Saved frame: reddiffpulsing/reddiffpulsing_0470.png
# Saved frame: reddiffpulsing/reddiffpulsing_0471.png
# Saved frame: reddiffpulsing/reddiffpulsing_0472.png
# Saved frame: reddiffpulsing/reddiffpulsing_0473.png
# Saved frame: reddiffpulsing/reddiffpulsing_0474.png
# Saved frame: reddiffpulsing/reddiffpulsing_0475.png
# Saved frame: reddiffpulsing/reddiffpulsing_0476.png
# Saved frame: reddiffpulsing/reddiffpulsing_0477.png
# Saved frame: reddiffpulsing/reddiffpulsing_0478.png
# Saved frame: reddiffpulsing/reddiffpulsing_0479.png
# Saved frame: reddiffpulsing/reddiffpulsing_0480.png
# Saved frame: reddiffpulsing/reddiffpulsing_0481.png
# Saved frame: reddiffpulsing/reddiffpulsing_0482.png
# Saved frame: reddiffpulsing/reddiffpulsing_0483.png
# Saved frame: reddiffpulsing/reddiffpulsing_0484.png
# Saved frame: reddiffpulsing/reddiffpulsing_0485.png
# Saved frame: reddiffpulsing/reddiffpulsing_0486.png
# Saved frame: reddiffpulsing/reddiffpulsing_0487.png
# Saved frame: reddiffpulsing/reddiffpulsing_0488.png
# Saved frame: reddiffpulsing/reddiffpulsing_0489.png
# Saved frame: reddiffpulsing/reddiffpulsing_0490.png
# Saved frame: reddiffpulsing/reddiffpulsing_0491.png
# Saved frame: reddiffpulsing/reddiffpulsing_0492.png
# Saved frame: reddiffpulsing/reddiffpulsing_0493.png
# Saved frame: reddiffpulsing/reddiffpulsing_0494.png
# Saved frame: reddiffpulsing/reddiffpulsing_0495.png
# Saved frame: reddiffpulsing/reddiffpulsing_0496.png
# Saved frame: reddiffpulsing/reddiffpulsing_0497.png
# Saved frame: reddiffpulsing/reddiffpulsing_0498.png
# Saved frame: reddiffpulsing/reddiffpulsing_0499.png
# Saved frame: reddiffpulsing/reddiffpulsing_0500.png
# Saved frame: reddiffpulsing/reddiffpulsing_0501.png
# Saved frame: reddiffpulsing/reddiffpulsing_0502.png
# Saved frame: reddiffpulsing/reddiffpulsing_0503.png
# Saved frame: reddiffpulsing/reddiffpulsing_0504.png
# Saved frame: reddiffpulsing/reddiffpulsing_0505.png
# Saved frame: reddiffpulsing/reddiffpulsing_0506.png
# Saved frame: reddiffpulsing/reddiffpulsing_0507.png
# Saved frame: reddiffpulsing/reddiffpulsing_0508.png
# Saved frame: reddiffpulsing/reddiffpulsing_0509.png
# Saved frame: reddiffpulsing/reddiffpulsing_0510.png
# Saved frame: reddiffpulsing/reddiffpulsing_0511.png
# Saved frame: reddiffpulsing/reddiffpulsing_0512.png
# Saved frame: reddiffpulsing/reddiffpulsing_0513.png
# Saved frame: reddiffpulsing/reddiffpulsing_0514.png
# Saved frame: reddiffpulsing/reddiffpulsing_0515.png
# Saved frame: reddiffpulsing/reddiffpulsing_0516.png
# Saved frame: reddiffpulsing/reddiffpulsing_0517.png
# Saved frame: reddiffpulsing/reddiffpulsing_0518.png
# Saved frame: reddiffpulsing/reddiffpulsing_0519.png
# Saved frame: reddiffpulsing/reddiffpulsing_0520.png
# Saved frame: reddiffpulsing/reddiffpulsing_0521.png
# Saved frame: reddiffpulsing/reddiffpulsing_0522.png
# Saved frame: reddiffpulsing/reddiffpulsing_0523.png
# Saved frame: reddiffpulsing/reddiffpulsing_0524.png
# Saved frame: reddiffpulsing/reddiffpulsing_0525.png
# Saved frame: reddiffpulsing/reddiffpulsing_0526.png
# Saved frame: reddiffpulsing/reddiffpulsing_0527.png
# Saved frame: reddiffpulsing/reddiffpulsing_0528.png
# Saved frame: reddiffpulsing/reddiffpulsing_0529.png
# Saved frame: reddiffpulsing/reddiffpulsing_0530.png
# Saved frame: reddiffpulsing/reddiffpulsing_0531.png
# Saved frame: reddiffpulsing/reddiffpulsing_0532.png
# Saved frame: reddiffpulsing/reddiffpulsing_0533.png
# Saved frame: reddiffpulsing/reddiffpulsing_0534.png
# Saved frame: reddiffpulsing/reddiffpulsing_0535.png
# Saved frame: reddiffpulsing/reddiffpulsing_0536.png
# Saved frame: reddiffpulsing/reddiffpulsing_0537.png
# Saved frame: reddiffpulsing/reddiffpulsing_0538.png
# Saved frame: reddiffpulsing/reddiffpulsing_0539.png
# Saved frame: reddiffpulsing/reddiffpulsing_0540.png
# Saved frame: reddiffpulsing/reddiffpulsing_0541.png
# Saved frame: reddiffpulsing/reddiffpulsing_0542.png
# Saved frame: reddiffpulsing/reddiffpulsing_0543.png
# Saved frame: reddiffpulsing/reddiffpulsing_0544.png
# Saved frame: reddiffpulsing/reddiffpulsing_0545.png
# Saved frame: reddiffpulsing/reddiffpulsing_0546.png
# Saved frame: reddiffpulsing/reddiffpulsing_0547.png
# Saved frame: reddiffpulsing/reddiffpulsing_0548.png
# Saved frame: reddiffpulsing/reddiffpulsing_0549.png
# Saved frame: reddiffpulsing/reddiffpulsing_0550.png
# Saved frame: reddiffpulsing/reddiffpulsing_0551.png
# Saved frame: reddiffpulsing/reddiffpulsing_0552.png
# Saved frame: reddiffpulsing/reddiffpulsing_0553.png
# Saved frame: reddiffpulsing/reddiffpulsing_0554.png
# Saved frame: reddiffpulsing/reddiffpulsing_0555.png
# Saved frame: reddiffpulsing/reddiffpulsing_0556.png
# Saved frame: reddiffpulsing/reddiffpulsing_0557.png
# Saved frame: reddiffpulsing/reddiffpulsing_0558.png
# Saved frame: reddiffpulsing/reddiffpulsing_0559.png
# Saved frame: reddiffpulsing/reddiffpulsing_0560.png
# Saved frame: reddiffpulsing/reddiffpulsing_0561.png
# Saved frame: reddiffpulsing/reddiffpulsing_0562.png
# Saved frame: reddiffpulsing/reddiffpulsing_0563.png
# Saved frame: reddiffpulsing/reddiffpulsing_0564.png
# Saved frame: reddiffpulsing/reddiffpulsing_0565.png
# Saved frame: reddiffpulsing/reddiffpulsing_0566.png
# Saved frame: reddiffpulsing/reddiffpulsing_0567.png
# Saved frame: reddiffpulsing/reddiffpulsing_0568.png
# Saved frame: reddiffpulsing/reddiffpulsing_0569.png
# Saved frame: reddiffpulsing/reddiffpulsing_0570.png
# Saved frame: reddiffpulsing/reddiffpulsing_0571.png
# Saved frame: reddiffpulsing/reddiffpulsing_0572.png
# Saved frame: reddiffpulsing/reddiffpulsing_0573.png
# Saved frame: reddiffpulsing/reddiffpulsing_0574.png
# Saved frame: reddiffpulsing/reddiffpulsing_0575.png
# Saved frame: reddiffpulsing/reddiffpulsing_0576.png
# Saved frame: reddiffpulsing/reddiffpulsing_0577.png
# Saved frame: reddiffpulsing/reddiffpulsing_0578.png
# Saved frame: reddiffpulsing/reddiffpulsing_0579.png
# Saved frame: reddiffpulsing/reddiffpulsing_0580.png
# Saved frame: reddiffpulsing/reddiffpulsing_0581.png
# Saved frame: reddiffpulsing/reddiffpulsing_0582.png
# Saved frame: reddiffpulsing/reddiffpulsing_0583.png
# Saved frame: reddiffpulsing/reddiffpulsing_0584.png
# Saved frame: reddiffpulsing/reddiffpulsing_0585.png
# Saved frame: reddiffpulsing/reddiffpulsing_0586.png
# Saved frame: reddiffpulsing/reddiffpulsing_0587.png
# Saved frame: reddiffpulsing/reddiffpulsing_0588.png
# Saved frame: reddiffpulsing/reddiffpulsing_0589.png
# Saved frame: reddiffpulsing/reddiffpulsing_0590.png
# Saved frame: reddiffpulsing/reddiffpulsing_0591.png
# Saved frame: reddiffpulsing/reddiffpulsing_0592.png
# Saved frame: reddiffpulsing/reddiffpulsing_0593.png
# Saved frame: reddiffpulsing/reddiffpulsing_0594.png
# Saved frame: reddiffpulsing/reddiffpulsing_0595.png
# Saved frame: reddiffpulsing/reddiffpulsing_0596.png
# Saved frame: reddiffpulsing/reddiffpulsing_0597.png
# Saved frame: reddiffpulsing/reddiffpulsing_0598.png
# Saved frame: reddiffpulsing/reddiffpulsing_0599.png
# Saved frame: reddiffpulsing/reddiffpulsing_0600.png
# Saved frame: reddiffpulsing/reddiffpulsing_0601.png
# Saved frame: reddiffpulsing/reddiffpulsing_0602.png
# Saved frame: reddiffpulsing/reddiffpulsing_0603.png
# Saved frame: reddiffpulsing/reddiffpulsing_0604.png
# Saved frame: reddiffpulsing/reddiffpulsing_0605.png
# Saved frame: reddiffpulsing/reddiffpulsing_0606.png
# Saved frame: reddiffpulsing/reddiffpulsing_0607.png
# Saved frame: reddiffpulsing/reddiffpulsing_0608.png
# Saved frame: reddiffpulsing/reddiffpulsing_0609.png
# Saved frame: reddiffpulsing/reddiffpulsing_0610.png
# Saved frame: reddiffpulsing/reddiffpulsing_0611.png
# Saved frame: reddiffpulsing/reddiffpulsing_0612.png
# Saved frame: reddiffpulsing/reddiffpulsing_0613.png
# Saved frame: reddiffpulsing/reddiffpulsing_0614.png
# Saved frame: reddiffpulsing/reddiffpulsing_0615.png
# Saved frame: reddiffpulsing/reddiffpulsing_0616.png
# Saved frame: reddiffpulsing/reddiffpulsing_0617.png
# Saved frame: reddiffpulsing/reddiffpulsing_0618.png
# Saved frame: reddiffpulsing/reddiffpulsing_0619.png
# Saved frame: reddiffpulsing/reddiffpulsing_0620.png
# Saved frame: reddiffpulsing/reddiffpulsing_0621.png
# Saved frame: reddiffpulsing/reddiffpulsing_0622.png
# Saved frame: reddiffpulsing/reddiffpulsing_0623.png
# Saved frame: reddiffpulsing/reddiffpulsing_0624.png
# Saved frame: reddiffpulsing/reddiffpulsing_0625.png
# Saved frame: reddiffpulsing/reddiffpulsing_0626.png
# Saved frame: reddiffpulsing/reddiffpulsing_0627.png
# Saved frame: reddiffpulsing/reddiffpulsing_0628.png
# Saved frame: reddiffpulsing/reddiffpulsing_0629.png
# Saved frame: reddiffpulsing/reddiffpulsing_0630.png
# Saved frame: reddiffpulsing/reddiffpulsing_0631.png
# Saved frame: reddiffpulsing/reddiffpulsing_0632.png
# Saved frame: reddiffpulsing/reddiffpulsing_0633.png
# Saved frame: reddiffpulsing/reddiffpulsing_0634.png
# Saved frame: reddiffpulsing/reddiffpulsing_0635.png
# Saved frame: reddiffpulsing/reddiffpulsing_0636.png
# Saved frame: reddiffpulsing/reddiffpulsing_0637.png
# Saved frame: reddiffpulsing/reddiffpulsing_0638.png
# Saved frame: reddiffpulsing/reddiffpulsing_0639.png
# Saved frame: reddiffpulsing/reddiffpulsing_0640.png
# Saved frame: reddiffpulsing/reddiffpulsing_0641.png
# Saved frame: reddiffpulsing/reddiffpulsing_0642.png
# Saved frame: reddiffpulsing/reddiffpulsing_0643.png
# Saved frame: reddiffpulsing/reddiffpulsing_0644.png
# Saved frame: reddiffpulsing/reddiffpulsing_0645.png
# Saved frame: reddiffpulsing/reddiffpulsing_0646.png
# Saved frame: reddiffpulsing/reddiffpulsing_0647.png
# Saved frame: reddiffpulsing/reddiffpulsing_0648.png
# Saved frame: reddiffpulsing/reddiffpulsing_0649.png
# Saved frame: reddiffpulsing/reddiffpulsing_0650.png
# Saved frame: reddiffpulsing/reddiffpulsing_0651.png
# Saved frame: reddiffpulsing/reddiffpulsing_0652.png
# Saved frame: reddiffpulsing/reddiffpulsing_0653.png
# Saved frame: reddiffpulsing/reddiffpulsing_0654.png
# Saved frame: reddiffpulsing/reddiffpulsing_0655.png
# Saved frame: reddiffpulsing/reddiffpulsing_0656.png
# Saved frame: reddiffpulsing/reddiffpulsing_0657.png
# Saved frame: reddiffpulsing/reddiffpulsing_0658.png
# Saved frame: reddiffpulsing/reddiffpulsing_0659.png
# Saved frame: reddiffpulsing/reddiffpulsing_0660.png
# Saved frame: reddiffpulsing/reddiffpulsing_0661.png
# Saved frame: reddiffpulsing/reddiffpulsing_0662.png
# Saved frame: reddiffpulsing/reddiffpulsing_0663.png
# Saved frame: reddiffpulsing/reddiffpulsing_0664.png
# Saved frame: reddiffpulsing/reddiffpulsing_0665.png
# Saved frame: reddiffpulsing/reddiffpulsing_0666.png
# Saved frame: reddiffpulsing/reddiffpulsing_0667.png
# Saved frame: reddiffpulsing/reddiffpulsing_0668.png
# Saved frame: reddiffpulsing/reddiffpulsing_0669.png
# Saved frame: reddiffpulsing/reddiffpulsing_0670.png
# Saved frame: reddiffpulsing/reddiffpulsing_0671.png
# Saved frame: reddiffpulsing/reddiffpulsing_0672.png
# Saved frame: reddiffpulsing/reddiffpulsing_0673.png
# Saved frame: reddiffpulsing/reddiffpulsing_0674.png
# Saved frame: reddiffpulsing/reddiffpulsing_0675.png
# Saved frame: reddiffpulsing/reddiffpulsing_0676.png
# Saved frame: reddiffpulsing/reddiffpulsing_0677.png
# Saved frame: reddiffpulsing/reddiffpulsing_0678.png
# Saved frame: reddiffpulsing/reddiffpulsing_0679.png
# Saved frame: reddiffpulsing/reddiffpulsing_0680.png
# Saved frame: reddiffpulsing/reddiffpulsing_0681.png
# Saved frame: reddiffpulsing/reddiffpulsing_0682.png
# Saved frame: reddiffpulsing/reddiffpulsing_0683.png
# Saved frame: reddiffpulsing/reddiffpulsing_0684.png
# Saved frame: reddiffpulsing/reddiffpulsing_0685.png
# Saved frame: reddiffpulsing/reddiffpulsing_0686.png
# Saved frame: reddiffpulsing/reddiffpulsing_0687.png
# Saved frame: reddiffpulsing/reddiffpulsing_0688.png
# Saved frame: reddiffpulsing/reddiffpulsing_0689.png
# Saved frame: reddiffpulsing/reddiffpulsing_0690.png
# Saved frame: reddiffpulsing/reddiffpulsing_0691.png
# Saved frame: reddiffpulsing/reddiffpulsing_0692.png
# Saved frame: reddiffpulsing/reddiffpulsing_0693.png
# Saved frame: reddiffpulsing/reddiffpulsing_0694.png
# Saved frame: reddiffpulsing/reddiffpulsing_0695.png
# Saved frame: reddiffpulsing/reddiffpulsing_0696.png
# Saved frame: reddiffpulsing/reddiffpulsing_0697.png
# Saved frame: reddiffpulsing/reddiffpulsing_0698.png
# Saved frame: reddiffpulsing/reddiffpulsing_0699.png
# Saved frame: reddiffpulsing/reddiffpulsing_0700.png
# Saved frame: reddiffpulsing/reddiffpulsing_0701.png
# Saved frame: reddiffpulsing/reddiffpulsing_0702.png
# Saved frame: reddiffpulsing/reddiffpulsing_0703.png
# Saved frame: reddiffpulsing/reddiffpulsing_0704.png
# Saved frame: reddiffpulsing/reddiffpulsing_0705.png
# Saved frame: reddiffpulsing/reddiffpulsing_0706.png
# Saved frame: reddiffpulsing/reddiffpulsing_0707.png
# Saved frame: reddiffpulsing/reddiffpulsing_0708.png
# Saved frame: reddiffpulsing/reddiffpulsing_0709.png
# Saved frame: reddiffpulsing/reddiffpulsing_0710.png
# Saved frame: reddiffpulsing/reddiffpulsing_0711.png
# Saved frame: reddiffpulsing/reddiffpulsing_0712.png
# Saved frame: reddiffpulsing/reddiffpulsing_0713.png
# Saved frame: reddiffpulsing/reddiffpulsing_0714.png
# Saved frame: reddiffpulsing/reddiffpulsing_0715.png
# Saved frame: reddiffpulsing/reddiffpulsing_0716.png
# Saved frame: reddiffpulsing/reddiffpulsing_0717.png
# Saved frame: reddiffpulsing/reddiffpulsing_0718.png
# Saved frame: reddiffpulsing/reddiffpulsing_0719.png
# Saved frame: reddiffpulsing/reddiffpulsing_0720.png
# Saved frame: reddiffpulsing/reddiffpulsing_0721.png
# Saved frame: reddiffpulsing/reddiffpulsing_0722.png
# Saved frame: reddiffpulsing/reddiffpulsing_0723.png
# Saved frame: reddiffpulsing/reddiffpulsing_0724.png
# Saved frame: reddiffpulsing/reddiffpulsing_0725.png
# Saved frame: reddiffpulsing/reddiffpulsing_0726.png
# Saved frame: reddiffpulsing/reddiffpulsing_0727.png
# Saved frame: reddiffpulsing/reddiffpulsing_0728.png
# Saved frame: reddiffpulsing/reddiffpulsing_0729.png
# Saved frame: reddiffpulsing/reddiffpulsing_0730.png
# Saved frame: reddiffpulsing/reddiffpulsing_0731.png
# Saved frame: reddiffpulsing/reddiffpulsing_0732.png
# Saved frame: reddiffpulsing/reddiffpulsing_0733.png
# Saved frame: reddiffpulsing/reddiffpulsing_0734.png
# Saved frame: reddiffpulsing/reddiffpulsing_0735.png
# Saved frame: reddiffpulsing/reddiffpulsing_0736.png
# Saved frame: reddiffpulsing/reddiffpulsing_0737.png
# Saved frame: reddiffpulsing/reddiffpulsing_0738.png
# Saved frame: reddiffpulsing/reddiffpulsing_0739.png
# Saved frame: reddiffpulsing/reddiffpulsing_0740.png
# Saved frame: reddiffpulsing/reddiffpulsing_0741.png
# Saved frame: reddiffpulsing/reddiffpulsing_0742.png
# Saved frame: reddiffpulsing/reddiffpulsing_0743.png
# Saved frame: reddiffpulsing/reddiffpulsing_0744.png
# Saved frame: reddiffpulsing/reddiffpulsing_0745.png
# Saved frame: reddiffpulsing/reddiffpulsing_0746.png
# Saved frame: reddiffpulsing/reddiffpulsing_0747.png
# Saved frame: reddiffpulsing/reddiffpulsing_0748.png
# Saved frame: reddiffpulsing/reddiffpulsing_0749.png
# Saved frame: reddiffpulsing/reddiffpulsing_0750.png
# Saved frame: reddiffpulsing/reddiffpulsing_0751.png
# Saved frame: reddiffpulsing/reddiffpulsing_0752.png
# Saved frame: reddiffpulsing/reddiffpulsing_0753.png
# Saved frame: reddiffpulsing/reddiffpulsing_0754.png
# Saved frame: reddiffpulsing/reddiffpulsing_0755.png
# Saved frame: reddiffpulsing/reddiffpulsing_0756.png
# Saved frame: reddiffpulsing/reddiffpulsing_0757.png
# Saved frame: reddiffpulsing/reddiffpulsing_0758.png
# Saved frame: reddiffpulsing/reddiffpulsing_0759.png
# Saved frame: reddiffpulsing/reddiffpulsing_0760.png
# Saved frame: reddiffpulsing/reddiffpulsing_0761.png
# Saved frame: reddiffpulsing/reddiffpulsing_0762.png
# Saved frame: reddiffpulsing/reddiffpulsing_0763.png
# Saved frame: reddiffpulsing/reddiffpulsing_0764.png
# Saved frame: reddiffpulsing/reddiffpulsing_0765.png
# Saved frame: reddiffpulsing/reddiffpulsing_0766.png
# Saved frame: reddiffpulsing/reddiffpulsing_0767.png
# Saved frame: reddiffpulsing/reddiffpulsing_0768.png
# Saved frame: reddiffpulsing/reddiffpulsing_0769.png
# Saved frame: reddiffpulsing/reddiffpulsing_0770.png
# Saved frame: reddiffpulsing/reddiffpulsing_0771.png
# Saved frame: reddiffpulsing/reddiffpulsing_0772.png
# Saved frame: reddiffpulsing/reddiffpulsing_0773.png
# Saved frame: reddiffpulsing/reddiffpulsing_0774.png
# Saved frame: reddiffpulsing/reddiffpulsing_0775.png
# Saved frame: reddiffpulsing/reddiffpulsing_0776.png
# Saved frame: reddiffpulsing/reddiffpulsing_0777.png
# Saved frame: reddiffpulsing/reddiffpulsing_0778.png
# Saved frame: reddiffpulsing/reddiffpulsing_0779.png
# Saved frame: reddiffpulsing/reddiffpulsing_0780.png
# Saved frame: reddiffpulsing/reddiffpulsing_0781.png
# Saved frame: reddiffpulsing/reddiffpulsing_0782.png
# Saved frame: reddiffpulsing/reddiffpulsing_0783.png
# Saved frame: reddiffpulsing/reddiffpulsing_0784.png
# Saved frame: reddiffpulsing/reddiffpulsing_0785.png
# Saved frame: reddiffpulsing/reddiffpulsing_0786.png
# Saved frame: reddiffpulsing/reddiffpulsing_0787.png
# Saved frame: reddiffpulsing/reddiffpulsing_0788.png
# Saved frame: reddiffpulsing/reddiffpulsing_0789.png
# Saved frame: reddiffpulsing/reddiffpulsing_0790.png
# Saved frame: reddiffpulsing/reddiffpulsing_0791.png
# Saved frame: reddiffpulsing/reddiffpulsing_0792.png
# Saved frame: reddiffpulsing/reddiffpulsing_0793.png
# Saved frame: reddiffpulsing/reddiffpulsing_0794.png
# Saved frame: reddiffpulsing/reddiffpulsing_0795.png
# Saved frame: reddiffpulsing/reddiffpulsing_0796.png
# Saved frame: reddiffpulsing/reddiffpulsing_0797.png
# Saved frame: reddiffpulsing/reddiffpulsing_0798.png
# Saved frame: reddiffpulsing/reddiffpulsing_0799.png
# Saved frame: reddiffpulsing/reddiffpulsing_0800.png
# Saved frame: reddiffpulsing/reddiffpulsing_0801.png
# Saved frame: reddiffpulsing/reddiffpulsing_0802.png
# Saved frame: reddiffpulsing/reddiffpulsing_0803.png
# Saved frame: reddiffpulsing/reddiffpulsing_0804.png
# Saved frame: reddiffpulsing/reddiffpulsing_0805.png
# Saved frame: reddiffpulsing/reddiffpulsing_0806.png
# Saved frame: reddiffpulsing/reddiffpulsing_0807.png
# Saved frame: reddiffpulsing/reddiffpulsing_0808.png
# Saved frame: reddiffpulsing/reddiffpulsing_0809.png
# Saved frame: reddiffpulsing/reddiffpulsing_0810.png
# Saved frame: reddiffpulsing/reddiffpulsing_0811.png
# Saved frame: reddiffpulsing/reddiffpulsing_0812.png
# Saved frame: reddiffpulsing/reddiffpulsing_0813.png
# Saved frame: reddiffpulsing/reddiffpulsing_0814.png
# Saved frame: reddiffpulsing/reddiffpulsing_0815.png
# Saved frame: reddiffpulsing/reddiffpulsing_0816.png
# Saved frame: reddiffpulsing/reddiffpulsing_0817.png
# Saved frame: reddiffpulsing/reddiffpulsing_0818.png
# Saved frame: reddiffpulsing/reddiffpulsing_0819.png
# Saved frame: reddiffpulsing/reddiffpulsing_0820.png
# Saved frame: reddiffpulsing/reddiffpulsing_0821.png
# Saved frame: reddiffpulsing/reddiffpulsing_0822.png
# Saved frame: reddiffpulsing/reddiffpulsing_0823.png
# Saved frame: reddiffpulsing/reddiffpulsing_0824.png
# Saved frame: reddiffpulsing/reddiffpulsing_0825.png
# Saved frame: reddiffpulsing/reddiffpulsing_0826.png
# Saved frame: reddiffpulsing/reddiffpulsing_0827.png
# Saved frame: reddiffpulsing/reddiffpulsing_0828.png
# Saved frame: reddiffpulsing/reddiffpulsing_0829.png
# Saved frame: reddiffpulsing/reddiffpulsing_0830.png
# Saved frame: reddiffpulsing/reddiffpulsing_0831.png
# Saved frame: reddiffpulsing/reddiffpulsing_0832.png
# Saved frame: reddiffpulsing/reddiffpulsing_0833.png
# Saved frame: reddiffpulsing/reddiffpulsing_0834.png
# Saved frame: reddiffpulsing/reddiffpulsing_0835.png
# Saved frame: reddiffpulsing/reddiffpulsing_0836.png
# Saved frame: reddiffpulsing/reddiffpulsing_0837.png
# Saved frame: reddiffpulsing/reddiffpulsing_0838.png
# Saved frame: reddiffpulsing/reddiffpulsing_0839.png
# Saved frame: reddiffpulsing/reddiffpulsing_0840.png
# Saved frame: reddiffpulsing/reddiffpulsing_0841.png
# Saved frame: reddiffpulsing/reddiffpulsing_0842.png
# Saved frame: reddiffpulsing/reddiffpulsing_0843.png
# Saved frame: reddiffpulsing/reddiffpulsing_0844.png
# Saved frame: reddiffpulsing/reddiffpulsing_0845.png
# Saved frame: reddiffpulsing/reddiffpulsing_0846.png
# Saved frame: reddiffpulsing/reddiffpulsing_0847.png
# Saved frame: reddiffpulsing/reddiffpulsing_0848.png
# Saved frame: reddiffpulsing/reddiffpulsing_0849.png
# Saved frame: reddiffpulsing/reddiffpulsing_0850.png
# Saved frame: reddiffpulsing/reddiffpulsing_0851.png
# Saved frame: reddiffpulsing/reddiffpulsing_0852.png
# Saved frame: reddiffpulsing/reddiffpulsing_0853.png
# Saved frame: reddiffpulsing/reddiffpulsing_0854.png
# Saved frame: reddiffpulsing/reddiffpulsing_0855.png
# Saved frame: reddiffpulsing/reddiffpulsing_0856.png
# Saved frame: reddiffpulsing/reddiffpulsing_0857.png
# Saved frame: reddiffpulsing/reddiffpulsing_0858.png
# Saved frame: reddiffpulsing/reddiffpulsing_0859.png
# Saved frame: reddiffpulsing/reddiffpulsing_0860.png
# Saved frame: reddiffpulsing/reddiffpulsing_0861.png
# Saved frame: reddiffpulsing/reddiffpulsing_0862.png
# Saved frame: reddiffpulsing/reddiffpulsing_0863.png
# Saved frame: reddiffpulsing/reddiffpulsing_0864.png
# Saved frame: reddiffpulsing/reddiffpulsing_0865.png
# Saved frame: reddiffpulsing/reddiffpulsing_0866.png
# Saved frame: reddiffpulsing/reddiffpulsing_0867.png
# Saved frame: reddiffpulsing/reddiffpulsing_0868.png
# Saved frame: reddiffpulsing/reddiffpulsing_0869.png
# Saved frame: reddiffpulsing/reddiffpulsing_0870.png
# Saved frame: reddiffpulsing/reddiffpulsing_0871.png
# Saved frame: reddiffpulsing/reddiffpulsing_0872.png
# Saved frame: reddiffpulsing/reddiffpulsing_0873.png
# Saved frame: reddiffpulsing/reddiffpulsing_0874.png
# Saved frame: reddiffpulsing/reddiffpulsing_0875.png
# Saved frame: reddiffpulsing/reddiffpulsing_0876.png
# Saved frame: reddiffpulsing/reddiffpulsing_0877.png
# Saved frame: reddiffpulsing/reddiffpulsing_0878.png
# Saved frame: reddiffpulsing/reddiffpulsing_0879.png
# Saved frame: reddiffpulsing/reddiffpulsing_0880.png
# Saved frame: reddiffpulsing/reddiffpulsing_0881.png
# Saved frame: reddiffpulsing/reddiffpulsing_0882.png
# Saved frame: reddiffpulsing/reddiffpulsing_0883.png
# Saved frame: reddiffpulsing/reddiffpulsing_0884.png
# Saved frame: reddiffpulsing/reddiffpulsing_0885.png
# Saved frame: reddiffpulsing/reddiffpulsing_0886.png
# Saved frame: reddiffpulsing/reddiffpulsing_0887.png
# Saved frame: reddiffpulsing/reddiffpulsing_0888.png
# Saved frame: reddiffpulsing/reddiffpulsing_0889.png
# Saved frame: reddiffpulsing/reddiffpulsing_0890.png
# Saved frame: reddiffpulsing/reddiffpulsing_0891.png
# Saved frame: reddiffpulsing/reddiffpulsing_0892.png
# Saved frame: reddiffpulsing/reddiffpulsing_0893.png
# Saved frame: reddiffpulsing/reddiffpulsing_0894.png
# Saved frame: reddiffpulsing/reddiffpulsing_0895.png
# Saved frame: reddiffpulsing/reddiffpulsing_0896.png
# Saved frame: reddiffpulsing/reddiffpulsing_0897.png
# Saved frame: reddiffpulsing/reddiffpulsing_0898.png
# Saved frame: reddiffpulsing/reddiffpulsing_0899.png
# Saved frame: reddiffpulsing/reddiffpulsing_0900.png
# Saved frame: reddiffpulsing/reddiffpulsing_0901.png
# Saved frame: reddiffpulsing/reddiffpulsing_0902.png
# Saved frame: reddiffpulsing/reddiffpulsing_0903.png
# Saved frame: reddiffpulsing/reddiffpulsing_0904.png
# Saved frame: reddiffpulsing/reddiffpulsing_0905.png
# Saved frame: reddiffpulsing/reddiffpulsing_0906.png
# Saved frame: reddiffpulsing/reddiffpulsing_0907.png
# Saved frame: reddiffpulsing/reddiffpulsing_0908.png
# Saved frame: reddiffpulsing/reddiffpulsing_0909.png
# Saved frame: reddiffpulsing/reddiffpulsing_0910.png
# Saved frame: reddiffpulsing/reddiffpulsing_0911.png
# Saved frame: reddiffpulsing/reddiffpulsing_0912.png
# Saved frame: reddiffpulsing/reddiffpulsing_0913.png
# Saved frame: reddiffpulsing/reddiffpulsing_0914.png
# Saved frame: reddiffpulsing/reddiffpulsing_0915.png
# Saved frame: reddiffpulsing/reddiffpulsing_0916.png
# Saved frame: reddiffpulsing/reddiffpulsing_0917.png
# Saved frame: reddiffpulsing/reddiffpulsing_0918.png
# Saved frame: reddiffpulsing/reddiffpulsing_0919.png
# Saved frame: reddiffpulsing/reddiffpulsing_0920.png
# Saved frame: reddiffpulsing/reddiffpulsing_0921.png
# Saved frame: reddiffpulsing/reddiffpulsing_0922.png
# Saved frame: reddiffpulsing/reddiffpulsing_0923.png
# Saved frame: reddiffpulsing/reddiffpulsing_0924.png
# Saved frame: reddiffpulsing/reddiffpulsing_0925.png
# Saved frame: reddiffpulsing/reddiffpulsing_0926.png
# Saved frame: reddiffpulsing/reddiffpulsing_0927.png
# Saved frame: reddiffpulsing/reddiffpulsing_0928.png
# Saved frame: reddiffpulsing/reddiffpulsing_0929.png
# Saved frame: reddiffpulsing/reddiffpulsing_0930.png
# Saved frame: reddiffpulsing/reddiffpulsing_0931.png
# Saved frame: reddiffpulsing/reddiffpulsing_0932.png
# Saved frame: reddiffpulsing/reddiffpulsing_0933.png
# Saved frame: reddiffpulsing/reddiffpulsing_0934.png
# Saved frame: reddiffpulsing/reddiffpulsing_0935.png
# Saved frame: reddiffpulsing/reddiffpulsing_0936.png
# Saved frame: reddiffpulsing/reddiffpulsing_0937.png
# Saved frame: reddiffpulsing/reddiffpulsing_0938.png
# Saved frame: reddiffpulsing/reddiffpulsing_0939.png
# Saved frame: reddiffpulsing/reddiffpulsing_0940.png
# Saved frame: reddiffpulsing/reddiffpulsing_0941.png
# Saved frame: reddiffpulsing/reddiffpulsing_0942.png
# Saved frame: reddiffpulsing/reddiffpulsing_0943.png
# Saved frame: reddiffpulsing/reddiffpulsing_0944.png
# Saved frame: reddiffpulsing/reddiffpulsing_0945.png
# Saved frame: reddiffpulsing/reddiffpulsing_0946.png
# Saved frame: reddiffpulsing/reddiffpulsing_0947.png
# Saved frame: reddiffpulsing/reddiffpulsing_0948.png
# Saved frame: reddiffpulsing/reddiffpulsing_0949.png
# Saved frame: reddiffpulsing/reddiffpulsing_0950.png
# Saved frame: reddiffpulsing/reddiffpulsing_0951.png
# Saved frame: reddiffpulsing/reddiffpulsing_0952.png
# Saved frame: reddiffpulsing/reddiffpulsing_0953.png
# Saved frame: reddiffpulsing/reddiffpulsing_0954.png
# Saved frame: reddiffpulsing/reddiffpulsing_0955.png
# Saved frame: reddiffpulsing/reddiffpulsing_0956.png
# Saved frame: reddiffpulsing/reddiffpulsing_0957.png
# Saved frame: reddiffpulsing/reddiffpulsing_0958.png
# Saved frame: reddiffpulsing/reddiffpulsing_0959.png
# Saved frame: reddiffpulsing/reddiffpulsing_0960.png
# Saved frame: reddiffpulsing/reddiffpulsing_0961.png
# Saved frame: reddiffpulsing/reddiffpulsing_0962.png
# Saved frame: reddiffpulsing/reddiffpulsing_0963.png
# Saved frame: reddiffpulsing/reddiffpulsing_0964.png
# Saved frame: reddiffpulsing/reddiffpulsing_0965.png
# Saved frame: reddiffpulsing/reddiffpulsing_0966.png
# Saved frame: reddiffpulsing/reddiffpulsing_0967.png
# Saved frame: reddiffpulsing/reddiffpulsing_0968.png
# Saved frame: reddiffpulsing/reddiffpulsing_0969.png
# Saved frame: reddiffpulsing/reddiffpulsing_0970.png
# Saved frame: reddiffpulsing/reddiffpulsing_0971.png
# Saved frame: reddiffpulsing/reddiffpulsing_0972.png
# Saved frame: reddiffpulsing/reddiffpulsing_0973.png
# Saved frame: reddiffpulsing/reddiffpulsing_0974.png
# Saved frame: reddiffpulsing/reddiffpulsing_0975.png
# Saved frame: reddiffpulsing/reddiffpulsing_0976.png
# Saved frame: reddiffpulsing/reddiffpulsing_0977.png
# Saved frame: reddiffpulsing/reddiffpulsing_0978.png
# Saved frame: reddiffpulsing/reddiffpulsing_0979.png
# Saved frame: reddiffpulsing/reddiffpulsing_0980.png
# Saved frame: reddiffpulsing/reddiffpulsing_0981.png
# Saved frame: reddiffpulsing/reddiffpulsing_0982.png
# Saved frame: reddiffpulsing/reddiffpulsing_0983.png
# Saved frame: reddiffpulsing/reddiffpulsing_0984.png
# Saved frame: reddiffpulsing/reddiffpulsing_0985.png
# Saved frame: reddiffpulsing/reddiffpulsing_0986.png
# Saved frame: reddiffpulsing/reddiffpulsing_0987.png
# Saved frame: reddiffpulsing/reddiffpulsing_0988.png
# Saved frame: reddiffpulsing/reddiffpulsing_0989.png
# Saved frame: reddiffpulsing/reddiffpulsing_0990.png
# Saved frame: reddiffpulsing/reddiffpulsing_0991.png
# Saved frame: reddiffpulsing/reddiffpulsing_0992.png
# Saved frame: reddiffpulsing/reddiffpulsing_0993.png
# Saved frame: reddiffpulsing/reddiffpulsing_0994.png
# Saved frame: reddiffpulsing/reddiffpulsing_0995.png
# Saved frame: reddiffpulsing/reddiffpulsing_0996.png
# Saved frame: reddiffpulsing/reddiffpulsing_0997.png
# Saved frame: reddiffpulsing/reddiffpulsing_0998.png
# Saved frame: reddiffpulsing/reddiffpulsing_0999.png

# %%
# make_reddiffpulsing_movie.py
import cv2
import os

frame_folder = "reddiffpulsing"
output_video = "reddiffpulsing.mp4"
fps = 20

frames = sorted([f for f in os.listdir(frame_folder) if f.endswith(".png")])
if not frames:
    raise ValueError(f"No frames found in folder: {frame_folder}")

first_frame = cv2.imread(os.path.join(frame_folder, frames[0]))
height, width, _ = first_frame.shape

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
video = cv2.VideoWriter(output_video, fourcc, fps, (width, height))

for f in frames:
    img = cv2.imread(os.path.join(frame_folder, f))
    video.write(img)

video.release()
print(f"Movie saved: {output_video}")
# Out:
# [ WARN:0@0.079] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@0.192] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@0.253] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@0.270] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@0.289] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@0.409] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@0.527] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@0.582] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@0.693] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@0.752] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@0.769] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@0.787] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@0.910] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@1.033] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@1.081] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@1.191] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@1.251] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@1.269] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@1.287] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@1.409] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@1.529] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@1.581] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@1.693] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@1.755] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@1.774] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@1.793] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@1.930] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@2.067] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@2.119] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@2.245] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@2.316] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@2.337] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@2.357] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@2.490] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@2.627] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@2.684] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@2.809] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@2.876] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@2.896] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@2.916] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@3.062] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@3.211] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@3.269] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@3.400] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@3.471] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@3.492] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@3.512] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@3.648] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@3.782] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@3.835] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@3.955] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@4.018] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@4.038] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@4.057] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@4.190] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@4.321] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@4.373] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@4.491] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@4.558] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@4.578] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@4.597] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@4.736] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@4.866] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@4.920] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@5.040] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@5.104] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@5.123] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@5.143] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@5.275] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@5.410] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@5.462] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@5.585] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@5.652] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@5.672] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@5.691] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@5.824] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@5.958] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@6.013] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@6.136] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@6.200] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@6.219] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@6.239] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@6.381] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@6.515] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@6.568] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@6.690] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@6.757] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@6.777] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@6.797] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@6.936] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@7.071] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@7.127] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@7.251] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@7.317] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@7.337] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@7.357] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@7.495] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@7.633] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@7.687] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@7.811] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@7.879] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@7.900] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@7.920] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@8.057] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@8.197] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@8.254] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@8.381] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@8.448] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@8.468] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@8.488] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@8.628] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@8.772] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@8.827] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@8.953] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@9.024] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@9.045] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@9.066] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@9.205] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@9.347] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@9.405] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@9.534] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@9.602] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@9.622] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@9.642] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@9.784] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@9.925] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@9.981] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@10.110] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@10.182] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@10.203] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@10.224] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@10.368] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@10.510] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@10.568] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@10.699] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@10.767] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@10.788] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@10.808] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# [ WARN:0@10.951] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame
# Movie saved: reddiffpulsing.mp4
# [ WARN:0@11.094] global cap_ffmpeg.cpp:198 write FFmpeg: Failed to write frame

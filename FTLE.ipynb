# %%
# ftle_frames_only.py
import numpy as np
import matplotlib.pyplot as plt
import os

# === CONFIGURATION ===
mode = "ftle_only"
T = 10           # FTLE integration window
h = 0.01
frame_dt = 0.1
periods = 30
omega = (6 * np.pi) / 10
A = 0.1
epsilon = 0.25

# === FUNCTIONS ===
def a(t): return epsilon * np.sin(omega * t)
def b(t): return 1 - 2 * epsilon * np.sin(omega * t)
def f(x, t): return a(t) * x**2 + b(t) * x
def df_dx(x, t): return 2 * a(t) * x + b(t)

def compute_flow(X, Y, t):
    fx = f(X, t)
    dfx = df_dx(X, t)
    x_dot = -np.pi * A * np.sin(np.pi * fx) * np.cos(np.pi * Y)
    y_dot = np.pi * A * np.cos(np.pi * fx) * np.sin(np.pi * Y) * dfx
    return x_dot, y_dot

def rk4_flow(X, Y, t, h):
    k1x, k1y = compute_flow(X, Y, t)
    k2x, k2y = compute_flow(X + 0.5*h*k1x, Y + 0.5*h*k1y, t + 0.5*h)
    k3x, k3y = compute_flow(X + 0.5*h*k2x, Y + 0.5*h*k2y, t + 0.5*h)
    k4x, k4y = compute_flow(X + h*k3x, Y + h*k3y, t + h)
    X_new = X + (h/6)*(k1x + 2*k2x + 2*k3x + k4x)
    Y_new = Y + (h/6)*(k1y + 2*k2y + 2*k3y + k4y)
    return X_new, Y_new

# === GRID SETUP ===
x_vals = np.linspace(0, 2, 300)
y_vals = np.linspace(0, 1, 150)
X0, Y0 = np.meshgrid(x_vals, y_vals)

# === OUTPUT SETUP ===
output_folder = f"ftle_frames"
os.makedirs(output_folder, exist_ok=True)

# === MAIN LOOP ===
t0_values = np.arange(0, periods * (10/3), frame_dt)

for frame_idx, t0 in enumerate(t0_values):
    t_max = t0 + T
    X, Y = X0.copy(), Y0.copy()
    
    # Advect grid for FTLE integration
    for t in np.arange(t0, t_max + h, h):
        X, Y = rk4_flow(X, Y, t, h)

    # Compute FTLE
    dx = x_vals[1] - x_vals[0]
    dy = y_vals[1] - y_vals[0]
    J11 = (X[2:,1:-1] - X[:-2,1:-1]) / (2*dx)
    J12 = (X[1:-1,2:] - X[1:-1,:-2]) / (2*dy)
    J21 = (Y[2:,1:-1] - Y[:-2,1:-1]) / (2*dx)
    J22 = (Y[1:-1,2:] - Y[1:-1,:-2]) / (2*dy)

    ftle = np.full(J11.shape, np.nan)
    for i in range(ftle.shape[0]):
        for j in range(ftle.shape[1]):
            J = np.array([[J11[i,j], J12[i,j]],
                          [J21[i,j], J22[i,j]]])
            delta = J.T @ J
            eigvals = np.linalg.eigvalsh(delta)
            max_eig = np.max(eigvals)
            if max_eig > 1e-12 and np.isfinite(max_eig):
                ftle[i,j] = (1.0/T) * np.log(np.sqrt(max_eig))

    ftle_full = np.full_like(X0, np.nan)
    ftle_full[1:-1, 1:-1] = ftle

    # Plot and save
    plt.figure(figsize=(12,6))
    plt.contourf(X0, Y0, np.ma.masked_invalid(ftle_full), levels=100, cmap='jet')
    plt.colorbar(label='FTLE')
    plt.title(f"FTLE Only | t={t0:.1f} → {t0+T:.1f}")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.xlim(0,2)
    plt.ylim(0,1)
    plt.gca().set_aspect('equal')
    filename = os.path.join(output_folder, f"ftle_{frame_idx:04d}.png")
    plt.savefig(filename, dpi=150)
    plt.close()
    print(f"Saved: {filename}")
# Out:
# Saved: ftle_frames/ftle_0000.png
# Saved: ftle_frames/ftle_0001.png
# Saved: ftle_frames/ftle_0002.png
# Saved: ftle_frames/ftle_0003.png
# Saved: ftle_frames/ftle_0004.png
# Saved: ftle_frames/ftle_0005.png
# Saved: ftle_frames/ftle_0006.png
# Saved: ftle_frames/ftle_0007.png
# Saved: ftle_frames/ftle_0008.png
# Saved: ftle_frames/ftle_0009.png
# Saved: ftle_frames/ftle_0010.png
# Saved: ftle_frames/ftle_0011.png
# Saved: ftle_frames/ftle_0012.png
# Saved: ftle_frames/ftle_0013.png
# Saved: ftle_frames/ftle_0014.png
# Saved: ftle_frames/ftle_0015.png
# Saved: ftle_frames/ftle_0016.png
# Saved: ftle_frames/ftle_0017.png
# Saved: ftle_frames/ftle_0018.png
# Saved: ftle_frames/ftle_0019.png
# Saved: ftle_frames/ftle_0020.png
# Saved: ftle_frames/ftle_0021.png
# Saved: ftle_frames/ftle_0022.png
# Saved: ftle_frames/ftle_0023.png
# Saved: ftle_frames/ftle_0024.png
# Saved: ftle_frames/ftle_0025.png
# Saved: ftle_frames/ftle_0026.png
# Saved: ftle_frames/ftle_0027.png
# Saved: ftle_frames/ftle_0028.png
# Saved: ftle_frames/ftle_0029.png
# Saved: ftle_frames/ftle_0030.png
# Saved: ftle_frames/ftle_0031.png
# Saved: ftle_frames/ftle_0032.png
# Saved: ftle_frames/ftle_0033.png
# Saved: ftle_frames/ftle_0034.png
# Saved: ftle_frames/ftle_0035.png
# Saved: ftle_frames/ftle_0036.png
# Saved: ftle_frames/ftle_0037.png
# Saved: ftle_frames/ftle_0038.png
# Saved: ftle_frames/ftle_0039.png
# Saved: ftle_frames/ftle_0040.png
# Saved: ftle_frames/ftle_0041.png
# Saved: ftle_frames/ftle_0042.png
# Saved: ftle_frames/ftle_0043.png
# Saved: ftle_frames/ftle_0044.png
# Saved: ftle_frames/ftle_0045.png
# Saved: ftle_frames/ftle_0046.png
# Saved: ftle_frames/ftle_0047.png
# Saved: ftle_frames/ftle_0048.png
# Saved: ftle_frames/ftle_0049.png
# Saved: ftle_frames/ftle_0050.png
# Saved: ftle_frames/ftle_0051.png
# Saved: ftle_frames/ftle_0052.png
# Saved: ftle_frames/ftle_0053.png
# Saved: ftle_frames/ftle_0054.png
# Saved: ftle_frames/ftle_0055.png
# Saved: ftle_frames/ftle_0056.png
# Saved: ftle_frames/ftle_0057.png
# Saved: ftle_frames/ftle_0058.png
# Saved: ftle_frames/ftle_0059.png
# Saved: ftle_frames/ftle_0060.png
# Saved: ftle_frames/ftle_0061.png
# Saved: ftle_frames/ftle_0062.png
# Saved: ftle_frames/ftle_0063.png
# Saved: ftle_frames/ftle_0064.png
# Saved: ftle_frames/ftle_0065.png
# Saved: ftle_frames/ftle_0066.png
# Saved: ftle_frames/ftle_0067.png
# Saved: ftle_frames/ftle_0068.png
# Saved: ftle_frames/ftle_0069.png
# Saved: ftle_frames/ftle_0070.png
# Saved: ftle_frames/ftle_0071.png
# Saved: ftle_frames/ftle_0072.png
# Saved: ftle_frames/ftle_0073.png
# Saved: ftle_frames/ftle_0074.png
# Saved: ftle_frames/ftle_0075.png
# Saved: ftle_frames/ftle_0076.png
# Saved: ftle_frames/ftle_0077.png
# Saved: ftle_frames/ftle_0078.png
# Saved: ftle_frames/ftle_0079.png
# Saved: ftle_frames/ftle_0080.png
# Saved: ftle_frames/ftle_0081.png
# Saved: ftle_frames/ftle_0082.png
# Saved: ftle_frames/ftle_0083.png
# Saved: ftle_frames/ftle_0084.png
# Saved: ftle_frames/ftle_0085.png
# Saved: ftle_frames/ftle_0086.png
# Saved: ftle_frames/ftle_0087.png
# Saved: ftle_frames/ftle_0088.png
# Saved: ftle_frames/ftle_0089.png
# Saved: ftle_frames/ftle_0090.png
# Saved: ftle_frames/ftle_0091.png
# Saved: ftle_frames/ftle_0092.png
# Saved: ftle_frames/ftle_0093.png
# Saved: ftle_frames/ftle_0094.png
# Saved: ftle_frames/ftle_0095.png
# Saved: ftle_frames/ftle_0096.png
# Saved: ftle_frames/ftle_0097.png
# Saved: ftle_frames/ftle_0098.png
# Saved: ftle_frames/ftle_0099.png
# Saved: ftle_frames/ftle_0100.png
# Saved: ftle_frames/ftle_0101.png
# Saved: ftle_frames/ftle_0102.png
# Saved: ftle_frames/ftle_0103.png
# Saved: ftle_frames/ftle_0104.png
# Saved: ftle_frames/ftle_0105.png
# Saved: ftle_frames/ftle_0106.png
# Saved: ftle_frames/ftle_0107.png
# Saved: ftle_frames/ftle_0108.png
# Saved: ftle_frames/ftle_0109.png
# Saved: ftle_frames/ftle_0110.png
# Saved: ftle_frames/ftle_0111.png
# Saved: ftle_frames/ftle_0112.png
# Saved: ftle_frames/ftle_0113.png
# Saved: ftle_frames/ftle_0114.png
# Saved: ftle_frames/ftle_0115.png
# Saved: ftle_frames/ftle_0116.png
# Saved: ftle_frames/ftle_0117.png
# Saved: ftle_frames/ftle_0118.png
# Saved: ftle_frames/ftle_0119.png
# Saved: ftle_frames/ftle_0120.png
# Saved: ftle_frames/ftle_0121.png
# Saved: ftle_frames/ftle_0122.png
# Saved: ftle_frames/ftle_0123.png
# Saved: ftle_frames/ftle_0124.png
# Saved: ftle_frames/ftle_0125.png
# Saved: ftle_frames/ftle_0126.png
# Saved: ftle_frames/ftle_0127.png
# Saved: ftle_frames/ftle_0128.png
# Saved: ftle_frames/ftle_0129.png
# Saved: ftle_frames/ftle_0130.png
# Saved: ftle_frames/ftle_0131.png
# Saved: ftle_frames/ftle_0132.png
# Saved: ftle_frames/ftle_0133.png
# Saved: ftle_frames/ftle_0134.png
# Saved: ftle_frames/ftle_0135.png
# Saved: ftle_frames/ftle_0136.png
# Saved: ftle_frames/ftle_0137.png
# Saved: ftle_frames/ftle_0138.png
# Saved: ftle_frames/ftle_0139.png
# Saved: ftle_frames/ftle_0140.png
# Saved: ftle_frames/ftle_0141.png
# Saved: ftle_frames/ftle_0142.png
# Saved: ftle_frames/ftle_0143.png
# Saved: ftle_frames/ftle_0144.png
# Saved: ftle_frames/ftle_0145.png
# Saved: ftle_frames/ftle_0146.png
# Saved: ftle_frames/ftle_0147.png
# Saved: ftle_frames/ftle_0148.png
# Saved: ftle_frames/ftle_0149.png
# Saved: ftle_frames/ftle_0150.png
# Saved: ftle_frames/ftle_0151.png
# Saved: ftle_frames/ftle_0152.png
# Saved: ftle_frames/ftle_0153.png
# Saved: ftle_frames/ftle_0154.png
# Saved: ftle_frames/ftle_0155.png
# Saved: ftle_frames/ftle_0156.png
# Saved: ftle_frames/ftle_0157.png
# Saved: ftle_frames/ftle_0158.png
# Saved: ftle_frames/ftle_0159.png
# Saved: ftle_frames/ftle_0160.png
# Saved: ftle_frames/ftle_0161.png
# Saved: ftle_frames/ftle_0162.png
# Saved: ftle_frames/ftle_0163.png
# Saved: ftle_frames/ftle_0164.png
# Saved: ftle_frames/ftle_0165.png
# Saved: ftle_frames/ftle_0166.png
# Saved: ftle_frames/ftle_0167.png
# Saved: ftle_frames/ftle_0168.png
# Saved: ftle_frames/ftle_0169.png
# Saved: ftle_frames/ftle_0170.png
# Saved: ftle_frames/ftle_0171.png
# Saved: ftle_frames/ftle_0172.png
# Saved: ftle_frames/ftle_0173.png
# Saved: ftle_frames/ftle_0174.png
# Saved: ftle_frames/ftle_0175.png
# Saved: ftle_frames/ftle_0176.png
# Saved: ftle_frames/ftle_0177.png
# Saved: ftle_frames/ftle_0178.png
# Saved: ftle_frames/ftle_0179.png
# Saved: ftle_frames/ftle_0180.png
# Saved: ftle_frames/ftle_0181.png
# Saved: ftle_frames/ftle_0182.png
# Saved: ftle_frames/ftle_0183.png
# Saved: ftle_frames/ftle_0184.png
# Saved: ftle_frames/ftle_0185.png
# Saved: ftle_frames/ftle_0186.png
# Saved: ftle_frames/ftle_0187.png
# Saved: ftle_frames/ftle_0188.png
# Saved: ftle_frames/ftle_0189.png
# Saved: ftle_frames/ftle_0190.png
# Saved: ftle_frames/ftle_0191.png
# Saved: ftle_frames/ftle_0192.png
# Saved: ftle_frames/ftle_0193.png
# Saved: ftle_frames/ftle_0194.png
# Saved: ftle_frames/ftle_0195.png
# Saved: ftle_frames/ftle_0196.png
# Saved: ftle_frames/ftle_0197.png
# Saved: ftle_frames/ftle_0198.png
# Saved: ftle_frames/ftle_0199.png
# Saved: ftle_frames/ftle_0200.png
# Saved: ftle_frames/ftle_0201.png
# Saved: ftle_frames/ftle_0202.png
# Saved: ftle_frames/ftle_0203.png
# Saved: ftle_frames/ftle_0204.png
# Saved: ftle_frames/ftle_0205.png
# Saved: ftle_frames/ftle_0206.png
# Saved: ftle_frames/ftle_0207.png
# Saved: ftle_frames/ftle_0208.png
# Saved: ftle_frames/ftle_0209.png
# Saved: ftle_frames/ftle_0210.png
# Saved: ftle_frames/ftle_0211.png
# Saved: ftle_frames/ftle_0212.png
# Saved: ftle_frames/ftle_0213.png
# Saved: ftle_frames/ftle_0214.png
# Saved: ftle_frames/ftle_0215.png
# Saved: ftle_frames/ftle_0216.png
# Saved: ftle_frames/ftle_0217.png
# Saved: ftle_frames/ftle_0218.png
# Saved: ftle_frames/ftle_0219.png
# Saved: ftle_frames/ftle_0220.png
# Saved: ftle_frames/ftle_0221.png
# Saved: ftle_frames/ftle_0222.png
# Saved: ftle_frames/ftle_0223.png
# Saved: ftle_frames/ftle_0224.png
# Saved: ftle_frames/ftle_0225.png
# Saved: ftle_frames/ftle_0226.png
# Saved: ftle_frames/ftle_0227.png
# Saved: ftle_frames/ftle_0228.png
# Saved: ftle_frames/ftle_0229.png
# Saved: ftle_frames/ftle_0230.png
# Saved: ftle_frames/ftle_0231.png
# Saved: ftle_frames/ftle_0232.png
# Saved: ftle_frames/ftle_0233.png
# Saved: ftle_frames/ftle_0234.png
# Saved: ftle_frames/ftle_0235.png
# Saved: ftle_frames/ftle_0236.png
# Saved: ftle_frames/ftle_0237.png
# Saved: ftle_frames/ftle_0238.png
# Saved: ftle_frames/ftle_0239.png
# Saved: ftle_frames/ftle_0240.png
# Saved: ftle_frames/ftle_0241.png
# Saved: ftle_frames/ftle_0242.png
# Saved: ftle_frames/ftle_0243.png
# Saved: ftle_frames/ftle_0244.png
# Saved: ftle_frames/ftle_0245.png
# Saved: ftle_frames/ftle_0246.png
# Saved: ftle_frames/ftle_0247.png
# Saved: ftle_frames/ftle_0248.png
# Saved: ftle_frames/ftle_0249.png
# Saved: ftle_frames/ftle_0250.png
# Saved: ftle_frames/ftle_0251.png
# Saved: ftle_frames/ftle_0252.png
# Saved: ftle_frames/ftle_0253.png
# Saved: ftle_frames/ftle_0254.png
# Saved: ftle_frames/ftle_0255.png
# Saved: ftle_frames/ftle_0256.png
# Saved: ftle_frames/ftle_0257.png
# Saved: ftle_frames/ftle_0258.png
# Saved: ftle_frames/ftle_0259.png
# Saved: ftle_frames/ftle_0260.png
# Saved: ftle_frames/ftle_0261.png
# Saved: ftle_frames/ftle_0262.png
# Saved: ftle_frames/ftle_0263.png
# Saved: ftle_frames/ftle_0264.png
# Saved: ftle_frames/ftle_0265.png
# Saved: ftle_frames/ftle_0266.png
# Saved: ftle_frames/ftle_0267.png
# Saved: ftle_frames/ftle_0268.png
# Saved: ftle_frames/ftle_0269.png
# Saved: ftle_frames/ftle_0270.png
# Saved: ftle_frames/ftle_0271.png
# Saved: ftle_frames/ftle_0272.png
# Saved: ftle_frames/ftle_0273.png
# Saved: ftle_frames/ftle_0274.png
# Saved: ftle_frames/ftle_0275.png
# Saved: ftle_frames/ftle_0276.png
# Saved: ftle_frames/ftle_0277.png
# Saved: ftle_frames/ftle_0278.png
# Saved: ftle_frames/ftle_0279.png
# Saved: ftle_frames/ftle_0280.png
# Saved: ftle_frames/ftle_0281.png
# Saved: ftle_frames/ftle_0282.png
# Saved: ftle_frames/ftle_0283.png
# Saved: ftle_frames/ftle_0284.png
# Saved: ftle_frames/ftle_0285.png
# Saved: ftle_frames/ftle_0286.png
# Saved: ftle_frames/ftle_0287.png
# Saved: ftle_frames/ftle_0288.png
# Saved: ftle_frames/ftle_0289.png
# Saved: ftle_frames/ftle_0290.png
# Saved: ftle_frames/ftle_0291.png
# Saved: ftle_frames/ftle_0292.png
# Saved: ftle_frames/ftle_0293.png
# Saved: ftle_frames/ftle_0294.png
# Saved: ftle_frames/ftle_0295.png
# Saved: ftle_frames/ftle_0296.png
# Saved: ftle_frames/ftle_0297.png
# Saved: ftle_frames/ftle_0298.png
# Saved: ftle_frames/ftle_0299.png
# Saved: ftle_frames/ftle_0300.png
# Saved: ftle_frames/ftle_0301.png
# Saved: ftle_frames/ftle_0302.png
# Saved: ftle_frames/ftle_0303.png
# Saved: ftle_frames/ftle_0304.png
# Saved: ftle_frames/ftle_0305.png
# Saved: ftle_frames/ftle_0306.png
# Saved: ftle_frames/ftle_0307.png
# Saved: ftle_frames/ftle_0308.png
# Saved: ftle_frames/ftle_0309.png
# Saved: ftle_frames/ftle_0310.png
# Saved: ftle_frames/ftle_0311.png
# Saved: ftle_frames/ftle_0312.png
# Saved: ftle_frames/ftle_0313.png
# Saved: ftle_frames/ftle_0314.png
# Saved: ftle_frames/ftle_0315.png
# Saved: ftle_frames/ftle_0316.png
# Saved: ftle_frames/ftle_0317.png
# Saved: ftle_frames/ftle_0318.png
# Saved: ftle_frames/ftle_0319.png
# Saved: ftle_frames/ftle_0320.png
# Saved: ftle_frames/ftle_0321.png
# Saved: ftle_frames/ftle_0322.png
# Saved: ftle_frames/ftle_0323.png
# Saved: ftle_frames/ftle_0324.png
# Saved: ftle_frames/ftle_0325.png
# Saved: ftle_frames/ftle_0326.png
# Saved: ftle_frames/ftle_0327.png
# Saved: ftle_frames/ftle_0328.png
# Saved: ftle_frames/ftle_0329.png
# Saved: ftle_frames/ftle_0330.png
# Saved: ftle_frames/ftle_0331.png
# Saved: ftle_frames/ftle_0332.png
# Saved: ftle_frames/ftle_0333.png
# Saved: ftle_frames/ftle_0334.png
# Saved: ftle_frames/ftle_0335.png
# Saved: ftle_frames/ftle_0336.png
# Saved: ftle_frames/ftle_0337.png
# Saved: ftle_frames/ftle_0338.png
# Saved: ftle_frames/ftle_0339.png
# Saved: ftle_frames/ftle_0340.png
# Saved: ftle_frames/ftle_0341.png
# Saved: ftle_frames/ftle_0342.png
# Saved: ftle_frames/ftle_0343.png
# Saved: ftle_frames/ftle_0344.png
# Saved: ftle_frames/ftle_0345.png
# Saved: ftle_frames/ftle_0346.png
# Saved: ftle_frames/ftle_0347.png
# Saved: ftle_frames/ftle_0348.png
# Saved: ftle_frames/ftle_0349.png
# Saved: ftle_frames/ftle_0350.png
# Saved: ftle_frames/ftle_0351.png
# Saved: ftle_frames/ftle_0352.png
# Saved: ftle_frames/ftle_0353.png
# Saved: ftle_frames/ftle_0354.png
# Saved: ftle_frames/ftle_0355.png
# Saved: ftle_frames/ftle_0356.png
# Saved: ftle_frames/ftle_0357.png
# Saved: ftle_frames/ftle_0358.png
# Saved: ftle_frames/ftle_0359.png
# Saved: ftle_frames/ftle_0360.png
# Saved: ftle_frames/ftle_0361.png
# Saved: ftle_frames/ftle_0362.png
# Saved: ftle_frames/ftle_0363.png
# Saved: ftle_frames/ftle_0364.png
# Saved: ftle_frames/ftle_0365.png
# Saved: ftle_frames/ftle_0366.png
# Saved: ftle_frames/ftle_0367.png
# Saved: ftle_frames/ftle_0368.png
# Saved: ftle_frames/ftle_0369.png
# Saved: ftle_frames/ftle_0370.png
# Saved: ftle_frames/ftle_0371.png
# Saved: ftle_frames/ftle_0372.png
# Saved: ftle_frames/ftle_0373.png
# Saved: ftle_frames/ftle_0374.png
# Saved: ftle_frames/ftle_0375.png
# Saved: ftle_frames/ftle_0376.png
# Saved: ftle_frames/ftle_0377.png
# Saved: ftle_frames/ftle_0378.png
# Saved: ftle_frames/ftle_0379.png
# Saved: ftle_frames/ftle_0380.png
# Saved: ftle_frames/ftle_0381.png
# Saved: ftle_frames/ftle_0382.png
# Saved: ftle_frames/ftle_0383.png
# Saved: ftle_frames/ftle_0384.png
# Saved: ftle_frames/ftle_0385.png
# Saved: ftle_frames/ftle_0386.png
# Saved: ftle_frames/ftle_0387.png
# Saved: ftle_frames/ftle_0388.png
# Saved: ftle_frames/ftle_0389.png
# Saved: ftle_frames/ftle_0390.png
# Saved: ftle_frames/ftle_0391.png
# Saved: ftle_frames/ftle_0392.png
# Saved: ftle_frames/ftle_0393.png
# Saved: ftle_frames/ftle_0394.png
# Saved: ftle_frames/ftle_0395.png
# Saved: ftle_frames/ftle_0396.png
# Saved: ftle_frames/ftle_0397.png
# Saved: ftle_frames/ftle_0398.png
# Saved: ftle_frames/ftle_0399.png
# Saved: ftle_frames/ftle_0400.png
# Saved: ftle_frames/ftle_0401.png
# Saved: ftle_frames/ftle_0402.png
# Saved: ftle_frames/ftle_0403.png
# Saved: ftle_frames/ftle_0404.png
# Saved: ftle_frames/ftle_0405.png
# Saved: ftle_frames/ftle_0406.png
# Saved: ftle_frames/ftle_0407.png
# Saved: ftle_frames/ftle_0408.png
# Saved: ftle_frames/ftle_0409.png
# Saved: ftle_frames/ftle_0410.png
# Saved: ftle_frames/ftle_0411.png
# Saved: ftle_frames/ftle_0412.png
# Saved: ftle_frames/ftle_0413.png
# Saved: ftle_frames/ftle_0414.png
# Saved: ftle_frames/ftle_0415.png
# Saved: ftle_frames/ftle_0416.png
# Saved: ftle_frames/ftle_0417.png
# Saved: ftle_frames/ftle_0418.png
# Saved: ftle_frames/ftle_0419.png
# Saved: ftle_frames/ftle_0420.png
# Saved: ftle_frames/ftle_0421.png
# Saved: ftle_frames/ftle_0422.png
# Saved: ftle_frames/ftle_0423.png
# Saved: ftle_frames/ftle_0424.png
# Saved: ftle_frames/ftle_0425.png
# Saved: ftle_frames/ftle_0426.png
# Saved: ftle_frames/ftle_0427.png
# Saved: ftle_frames/ftle_0428.png
# Saved: ftle_frames/ftle_0429.png
# Saved: ftle_frames/ftle_0430.png
# Saved: ftle_frames/ftle_0431.png
# Saved: ftle_frames/ftle_0432.png
# Saved: ftle_frames/ftle_0433.png
# Saved: ftle_frames/ftle_0434.png
# Saved: ftle_frames/ftle_0435.png
# Saved: ftle_frames/ftle_0436.png
# Saved: ftle_frames/ftle_0437.png
# Saved: ftle_frames/ftle_0438.png
# Saved: ftle_frames/ftle_0439.png
# Saved: ftle_frames/ftle_0440.png
# Saved: ftle_frames/ftle_0441.png
# Saved: ftle_frames/ftle_0442.png
# Saved: ftle_frames/ftle_0443.png
# Saved: ftle_frames/ftle_0444.png
# Saved: ftle_frames/ftle_0445.png
# Saved: ftle_frames/ftle_0446.png
# Saved: ftle_frames/ftle_0447.png
# Saved: ftle_frames/ftle_0448.png
# Saved: ftle_frames/ftle_0449.png
# Saved: ftle_frames/ftle_0450.png
# Saved: ftle_frames/ftle_0451.png
# Saved: ftle_frames/ftle_0452.png
# Saved: ftle_frames/ftle_0453.png
# Saved: ftle_frames/ftle_0454.png
# Saved: ftle_frames/ftle_0455.png
# Saved: ftle_frames/ftle_0456.png
# Saved: ftle_frames/ftle_0457.png
# Saved: ftle_frames/ftle_0458.png
# Saved: ftle_frames/ftle_0459.png
# Saved: ftle_frames/ftle_0460.png
# Saved: ftle_frames/ftle_0461.png
# Saved: ftle_frames/ftle_0462.png
# Saved: ftle_frames/ftle_0463.png
# Saved: ftle_frames/ftle_0464.png
# Saved: ftle_frames/ftle_0465.png
# Saved: ftle_frames/ftle_0466.png
# Saved: ftle_frames/ftle_0467.png
# Saved: ftle_frames/ftle_0468.png
# Saved: ftle_frames/ftle_0469.png
# Saved: ftle_frames/ftle_0470.png
# Saved: ftle_frames/ftle_0471.png
# Saved: ftle_frames/ftle_0472.png
# Saved: ftle_frames/ftle_0473.png
# Saved: ftle_frames/ftle_0474.png
# Saved: ftle_frames/ftle_0475.png
# Saved: ftle_frames/ftle_0476.png
# Saved: ftle_frames/ftle_0477.png
# Saved: ftle_frames/ftle_0478.png
# Saved: ftle_frames/ftle_0479.png
# Saved: ftle_frames/ftle_0480.png
# Saved: ftle_frames/ftle_0481.png
# Saved: ftle_frames/ftle_0482.png
# Saved: ftle_frames/ftle_0483.png
# Saved: ftle_frames/ftle_0484.png
# Saved: ftle_frames/ftle_0485.png
# Saved: ftle_frames/ftle_0486.png
# Saved: ftle_frames/ftle_0487.png
# Saved: ftle_frames/ftle_0488.png
# Saved: ftle_frames/ftle_0489.png
# Saved: ftle_frames/ftle_0490.png
# Saved: ftle_frames/ftle_0491.png
# Saved: ftle_frames/ftle_0492.png
# Saved: ftle_frames/ftle_0493.png
# Saved: ftle_frames/ftle_0494.png
# Saved: ftle_frames/ftle_0495.png
# Saved: ftle_frames/ftle_0496.png
# Saved: ftle_frames/ftle_0497.png
# Saved: ftle_frames/ftle_0498.png
# Saved: ftle_frames/ftle_0499.png
# Saved: ftle_frames/ftle_0500.png
# Saved: ftle_frames/ftle_0501.png
# Saved: ftle_frames/ftle_0502.png
# Saved: ftle_frames/ftle_0503.png
# Saved: ftle_frames/ftle_0504.png
# Saved: ftle_frames/ftle_0505.png
# Saved: ftle_frames/ftle_0506.png
# Saved: ftle_frames/ftle_0507.png
# Saved: ftle_frames/ftle_0508.png
# Saved: ftle_frames/ftle_0509.png
# Saved: ftle_frames/ftle_0510.png
# Saved: ftle_frames/ftle_0511.png
# Saved: ftle_frames/ftle_0512.png
# Saved: ftle_frames/ftle_0513.png
# Saved: ftle_frames/ftle_0514.png
# Saved: ftle_frames/ftle_0515.png
# Saved: ftle_frames/ftle_0516.png
# Saved: ftle_frames/ftle_0517.png
# Saved: ftle_frames/ftle_0518.png
# Saved: ftle_frames/ftle_0519.png
# Saved: ftle_frames/ftle_0520.png
# Saved: ftle_frames/ftle_0521.png
# Saved: ftle_frames/ftle_0522.png
# Saved: ftle_frames/ftle_0523.png
# Saved: ftle_frames/ftle_0524.png
# Saved: ftle_frames/ftle_0525.png
# Saved: ftle_frames/ftle_0526.png
# Saved: ftle_frames/ftle_0527.png
# Saved: ftle_frames/ftle_0528.png
# Saved: ftle_frames/ftle_0529.png
# Saved: ftle_frames/ftle_0530.png
# Saved: ftle_frames/ftle_0531.png
# Saved: ftle_frames/ftle_0532.png
# Saved: ftle_frames/ftle_0533.png
# Saved: ftle_frames/ftle_0534.png
# Saved: ftle_frames/ftle_0535.png
# Saved: ftle_frames/ftle_0536.png
# Saved: ftle_frames/ftle_0537.png
# Saved: ftle_frames/ftle_0538.png
# Saved: ftle_frames/ftle_0539.png
# Saved: ftle_frames/ftle_0540.png
# Saved: ftle_frames/ftle_0541.png
# Saved: ftle_frames/ftle_0542.png
# Saved: ftle_frames/ftle_0543.png
# Saved: ftle_frames/ftle_0544.png
# Saved: ftle_frames/ftle_0545.png
# Saved: ftle_frames/ftle_0546.png
# Saved: ftle_frames/ftle_0547.png
# Saved: ftle_frames/ftle_0548.png
# Saved: ftle_frames/ftle_0549.png
# Saved: ftle_frames/ftle_0550.png
# Saved: ftle_frames/ftle_0551.png
# Saved: ftle_frames/ftle_0552.png
# Saved: ftle_frames/ftle_0553.png
# Saved: ftle_frames/ftle_0554.png
# Saved: ftle_frames/ftle_0555.png
# Saved: ftle_frames/ftle_0556.png
# Saved: ftle_frames/ftle_0557.png
# Saved: ftle_frames/ftle_0558.png
# Saved: ftle_frames/ftle_0559.png
# Saved: ftle_frames/ftle_0560.png
# Saved: ftle_frames/ftle_0561.png
# Saved: ftle_frames/ftle_0562.png
# Saved: ftle_frames/ftle_0563.png
# Saved: ftle_frames/ftle_0564.png
# Saved: ftle_frames/ftle_0565.png
# Saved: ftle_frames/ftle_0566.png
# Saved: ftle_frames/ftle_0567.png
# Saved: ftle_frames/ftle_0568.png
# Saved: ftle_frames/ftle_0569.png
# Saved: ftle_frames/ftle_0570.png
# Saved: ftle_frames/ftle_0571.png
# Saved: ftle_frames/ftle_0572.png
# Saved: ftle_frames/ftle_0573.png
# Saved: ftle_frames/ftle_0574.png
# Saved: ftle_frames/ftle_0575.png
# Saved: ftle_frames/ftle_0576.png
# Saved: ftle_frames/ftle_0577.png
# Saved: ftle_frames/ftle_0578.png
# Saved: ftle_frames/ftle_0579.png
# Saved: ftle_frames/ftle_0580.png
# Saved: ftle_frames/ftle_0581.png
# Saved: ftle_frames/ftle_0582.png
# Saved: ftle_frames/ftle_0583.png
# Saved: ftle_frames/ftle_0584.png
# Saved: ftle_frames/ftle_0585.png
# Saved: ftle_frames/ftle_0586.png
# Saved: ftle_frames/ftle_0587.png
# Saved: ftle_frames/ftle_0588.png
# Saved: ftle_frames/ftle_0589.png
# Saved: ftle_frames/ftle_0590.png
# Saved: ftle_frames/ftle_0591.png
# Saved: ftle_frames/ftle_0592.png
# Saved: ftle_frames/ftle_0593.png
# Saved: ftle_frames/ftle_0594.png
# Saved: ftle_frames/ftle_0595.png
# Saved: ftle_frames/ftle_0596.png
# Saved: ftle_frames/ftle_0597.png
# Saved: ftle_frames/ftle_0598.png
# Saved: ftle_frames/ftle_0599.png
# Saved: ftle_frames/ftle_0600.png
# Saved: ftle_frames/ftle_0601.png
# Saved: ftle_frames/ftle_0602.png
# Saved: ftle_frames/ftle_0603.png
# Saved: ftle_frames/ftle_0604.png
# Saved: ftle_frames/ftle_0605.png
# Saved: ftle_frames/ftle_0606.png
# Saved: ftle_frames/ftle_0607.png
# Saved: ftle_frames/ftle_0608.png
# Saved: ftle_frames/ftle_0609.png
# Saved: ftle_frames/ftle_0610.png
# Saved: ftle_frames/ftle_0611.png
# Saved: ftle_frames/ftle_0612.png
# Saved: ftle_frames/ftle_0613.png
# Saved: ftle_frames/ftle_0614.png
# Saved: ftle_frames/ftle_0615.png
# Saved: ftle_frames/ftle_0616.png
# Saved: ftle_frames/ftle_0617.png
# Saved: ftle_frames/ftle_0618.png
# Saved: ftle_frames/ftle_0619.png
# Saved: ftle_frames/ftle_0620.png
# Saved: ftle_frames/ftle_0621.png
# Saved: ftle_frames/ftle_0622.png
# Saved: ftle_frames/ftle_0623.png
# Saved: ftle_frames/ftle_0624.png
# Saved: ftle_frames/ftle_0625.png
# Saved: ftle_frames/ftle_0626.png
# Saved: ftle_frames/ftle_0627.png
# Saved: ftle_frames/ftle_0628.png
# Saved: ftle_frames/ftle_0629.png
# Saved: ftle_frames/ftle_0630.png
# Saved: ftle_frames/ftle_0631.png
# Saved: ftle_frames/ftle_0632.png
# Saved: ftle_frames/ftle_0633.png
# Saved: ftle_frames/ftle_0634.png
# Saved: ftle_frames/ftle_0635.png
# Saved: ftle_frames/ftle_0636.png
# Saved: ftle_frames/ftle_0637.png
# Saved: ftle_frames/ftle_0638.png
# Saved: ftle_frames/ftle_0639.png
# Saved: ftle_frames/ftle_0640.png
# Saved: ftle_frames/ftle_0641.png
# Saved: ftle_frames/ftle_0642.png
# Saved: ftle_frames/ftle_0643.png
# Saved: ftle_frames/ftle_0644.png
# Saved: ftle_frames/ftle_0645.png
# Saved: ftle_frames/ftle_0646.png
# Saved: ftle_frames/ftle_0647.png
# Saved: ftle_frames/ftle_0648.png
# Saved: ftle_frames/ftle_0649.png
# Saved: ftle_frames/ftle_0650.png
# Saved: ftle_frames/ftle_0651.png
# Saved: ftle_frames/ftle_0652.png
# Saved: ftle_frames/ftle_0653.png
# Saved: ftle_frames/ftle_0654.png
# Saved: ftle_frames/ftle_0655.png
# Saved: ftle_frames/ftle_0656.png
# Saved: ftle_frames/ftle_0657.png
# Saved: ftle_frames/ftle_0658.png
# Saved: ftle_frames/ftle_0659.png
# Saved: ftle_frames/ftle_0660.png
# Saved: ftle_frames/ftle_0661.png
# Saved: ftle_frames/ftle_0662.png
# Saved: ftle_frames/ftle_0663.png
# Saved: ftle_frames/ftle_0664.png
# Saved: ftle_frames/ftle_0665.png
# Saved: ftle_frames/ftle_0666.png
# Saved: ftle_frames/ftle_0667.png
# Saved: ftle_frames/ftle_0668.png
# Saved: ftle_frames/ftle_0669.png
# Saved: ftle_frames/ftle_0670.png
# Saved: ftle_frames/ftle_0671.png
# Saved: ftle_frames/ftle_0672.png
# Saved: ftle_frames/ftle_0673.png
# Saved: ftle_frames/ftle_0674.png
# Saved: ftle_frames/ftle_0675.png
# Saved: ftle_frames/ftle_0676.png
# Saved: ftle_frames/ftle_0677.png
# Saved: ftle_frames/ftle_0678.png
# Saved: ftle_frames/ftle_0679.png
# Saved: ftle_frames/ftle_0680.png
# Saved: ftle_frames/ftle_0681.png
# Saved: ftle_frames/ftle_0682.png
# Saved: ftle_frames/ftle_0683.png
# Saved: ftle_frames/ftle_0684.png
# Saved: ftle_frames/ftle_0685.png
# Saved: ftle_frames/ftle_0686.png
# Saved: ftle_frames/ftle_0687.png
# Saved: ftle_frames/ftle_0688.png
# Saved: ftle_frames/ftle_0689.png
# Saved: ftle_frames/ftle_0690.png
# Saved: ftle_frames/ftle_0691.png
# Saved: ftle_frames/ftle_0692.png
# Saved: ftle_frames/ftle_0693.png
# Saved: ftle_frames/ftle_0694.png
# Saved: ftle_frames/ftle_0695.png
# Saved: ftle_frames/ftle_0696.png
# Saved: ftle_frames/ftle_0697.png
# Saved: ftle_frames/ftle_0698.png
# Saved: ftle_frames/ftle_0699.png
# Saved: ftle_frames/ftle_0700.png
# Saved: ftle_frames/ftle_0701.png
# Saved: ftle_frames/ftle_0702.png
# Saved: ftle_frames/ftle_0703.png
# Saved: ftle_frames/ftle_0704.png
# Saved: ftle_frames/ftle_0705.png
# Saved: ftle_frames/ftle_0706.png
# Saved: ftle_frames/ftle_0707.png
# Saved: ftle_frames/ftle_0708.png
# Saved: ftle_frames/ftle_0709.png
# Saved: ftle_frames/ftle_0710.png
# Saved: ftle_frames/ftle_0711.png
# Saved: ftle_frames/ftle_0712.png
# Saved: ftle_frames/ftle_0713.png
# Saved: ftle_frames/ftle_0714.png
# Saved: ftle_frames/ftle_0715.png
# Saved: ftle_frames/ftle_0716.png
# Saved: ftle_frames/ftle_0717.png
# Saved: ftle_frames/ftle_0718.png
# Saved: ftle_frames/ftle_0719.png
# Saved: ftle_frames/ftle_0720.png
# Saved: ftle_frames/ftle_0721.png
# Saved: ftle_frames/ftle_0722.png
# Saved: ftle_frames/ftle_0723.png
# Saved: ftle_frames/ftle_0724.png
# Saved: ftle_frames/ftle_0725.png
# Saved: ftle_frames/ftle_0726.png
# Saved: ftle_frames/ftle_0727.png
# Saved: ftle_frames/ftle_0728.png
# Saved: ftle_frames/ftle_0729.png
# Saved: ftle_frames/ftle_0730.png
# Saved: ftle_frames/ftle_0731.png
# Saved: ftle_frames/ftle_0732.png
# Saved: ftle_frames/ftle_0733.png
# Saved: ftle_frames/ftle_0734.png
# Saved: ftle_frames/ftle_0735.png
# Saved: ftle_frames/ftle_0736.png
# Saved: ftle_frames/ftle_0737.png
# Saved: ftle_frames/ftle_0738.png
# Saved: ftle_frames/ftle_0739.png
# Saved: ftle_frames/ftle_0740.png
# Saved: ftle_frames/ftle_0741.png
# Saved: ftle_frames/ftle_0742.png
# Saved: ftle_frames/ftle_0743.png
# Saved: ftle_frames/ftle_0744.png
# Saved: ftle_frames/ftle_0745.png
# Saved: ftle_frames/ftle_0746.png
# Saved: ftle_frames/ftle_0747.png
# Saved: ftle_frames/ftle_0748.png
# Saved: ftle_frames/ftle_0749.png
# Saved: ftle_frames/ftle_0750.png
# Saved: ftle_frames/ftle_0751.png
# Saved: ftle_frames/ftle_0752.png
# Saved: ftle_frames/ftle_0753.png
# Saved: ftle_frames/ftle_0754.png
# Saved: ftle_frames/ftle_0755.png
# Saved: ftle_frames/ftle_0756.png
# Saved: ftle_frames/ftle_0757.png
# Saved: ftle_frames/ftle_0758.png
# Saved: ftle_frames/ftle_0759.png
# Saved: ftle_frames/ftle_0760.png
# Saved: ftle_frames/ftle_0761.png
# Saved: ftle_frames/ftle_0762.png
# Saved: ftle_frames/ftle_0763.png
# Saved: ftle_frames/ftle_0764.png
# Saved: ftle_frames/ftle_0765.png
# Saved: ftle_frames/ftle_0766.png
# Saved: ftle_frames/ftle_0767.png
# Saved: ftle_frames/ftle_0768.png
# Saved: ftle_frames/ftle_0769.png
# Saved: ftle_frames/ftle_0770.png
# Saved: ftle_frames/ftle_0771.png
# Saved: ftle_frames/ftle_0772.png
# Saved: ftle_frames/ftle_0773.png
# Saved: ftle_frames/ftle_0774.png
# Saved: ftle_frames/ftle_0775.png
# Saved: ftle_frames/ftle_0776.png
# Saved: ftle_frames/ftle_0777.png
# Saved: ftle_frames/ftle_0778.png
# Saved: ftle_frames/ftle_0779.png
# Saved: ftle_frames/ftle_0780.png
# Saved: ftle_frames/ftle_0781.png
# Saved: ftle_frames/ftle_0782.png
# Saved: ftle_frames/ftle_0783.png
# Saved: ftle_frames/ftle_0784.png
# Saved: ftle_frames/ftle_0785.png
# Saved: ftle_frames/ftle_0786.png
# Saved: ftle_frames/ftle_0787.png
# Saved: ftle_frames/ftle_0788.png
# Saved: ftle_frames/ftle_0789.png
# Saved: ftle_frames/ftle_0790.png
# Saved: ftle_frames/ftle_0791.png
# Saved: ftle_frames/ftle_0792.png
# Saved: ftle_frames/ftle_0793.png
# Saved: ftle_frames/ftle_0794.png
# Saved: ftle_frames/ftle_0795.png
# Saved: ftle_frames/ftle_0796.png
# Saved: ftle_frames/ftle_0797.png
# Saved: ftle_frames/ftle_0798.png
# Saved: ftle_frames/ftle_0799.png
# Saved: ftle_frames/ftle_0800.png
# Saved: ftle_frames/ftle_0801.png
# Saved: ftle_frames/ftle_0802.png
# Saved: ftle_frames/ftle_0803.png
# Saved: ftle_frames/ftle_0804.png
# Saved: ftle_frames/ftle_0805.png
# Saved: ftle_frames/ftle_0806.png
# Saved: ftle_frames/ftle_0807.png
# Saved: ftle_frames/ftle_0808.png
# Saved: ftle_frames/ftle_0809.png
# Saved: ftle_frames/ftle_0810.png
# Saved: ftle_frames/ftle_0811.png
# Saved: ftle_frames/ftle_0812.png
# Saved: ftle_frames/ftle_0813.png
# Saved: ftle_frames/ftle_0814.png
# Saved: ftle_frames/ftle_0815.png
# Saved: ftle_frames/ftle_0816.png
# Saved: ftle_frames/ftle_0817.png
# Saved: ftle_frames/ftle_0818.png
# Saved: ftle_frames/ftle_0819.png
# Saved: ftle_frames/ftle_0820.png
# Saved: ftle_frames/ftle_0821.png
# Saved: ftle_frames/ftle_0822.png
# Saved: ftle_frames/ftle_0823.png
# Saved: ftle_frames/ftle_0824.png
# Saved: ftle_frames/ftle_0825.png
# Saved: ftle_frames/ftle_0826.png
# Saved: ftle_frames/ftle_0827.png
# Saved: ftle_frames/ftle_0828.png
# Saved: ftle_frames/ftle_0829.png
# Saved: ftle_frames/ftle_0830.png
# Saved: ftle_frames/ftle_0831.png
# Saved: ftle_frames/ftle_0832.png
# Saved: ftle_frames/ftle_0833.png
# Saved: ftle_frames/ftle_0834.png
# Saved: ftle_frames/ftle_0835.png
# Saved: ftle_frames/ftle_0836.png
# Saved: ftle_frames/ftle_0837.png
# Saved: ftle_frames/ftle_0838.png
# Saved: ftle_frames/ftle_0839.png
# Saved: ftle_frames/ftle_0840.png
# Saved: ftle_frames/ftle_0841.png
# Saved: ftle_frames/ftle_0842.png
# Saved: ftle_frames/ftle_0843.png
# Saved: ftle_frames/ftle_0844.png
# Saved: ftle_frames/ftle_0845.png
# Saved: ftle_frames/ftle_0846.png
# Saved: ftle_frames/ftle_0847.png
# Saved: ftle_frames/ftle_0848.png
# Saved: ftle_frames/ftle_0849.png
# Saved: ftle_frames/ftle_0850.png
# Saved: ftle_frames/ftle_0851.png
# Saved: ftle_frames/ftle_0852.png
# Saved: ftle_frames/ftle_0853.png
# Saved: ftle_frames/ftle_0854.png
# Saved: ftle_frames/ftle_0855.png
# Saved: ftle_frames/ftle_0856.png
# Saved: ftle_frames/ftle_0857.png
# Saved: ftle_frames/ftle_0858.png
# Saved: ftle_frames/ftle_0859.png
# Saved: ftle_frames/ftle_0860.png
# Saved: ftle_frames/ftle_0861.png
# Saved: ftle_frames/ftle_0862.png
# Saved: ftle_frames/ftle_0863.png
# Saved: ftle_frames/ftle_0864.png
# Saved: ftle_frames/ftle_0865.png
# Saved: ftle_frames/ftle_0866.png
# Saved: ftle_frames/ftle_0867.png
# Saved: ftle_frames/ftle_0868.png
# Saved: ftle_frames/ftle_0869.png
# Saved: ftle_frames/ftle_0870.png
# Saved: ftle_frames/ftle_0871.png
# Saved: ftle_frames/ftle_0872.png
# Saved: ftle_frames/ftle_0873.png
# Saved: ftle_frames/ftle_0874.png
# Saved: ftle_frames/ftle_0875.png
# Saved: ftle_frames/ftle_0876.png
# Saved: ftle_frames/ftle_0877.png
# Saved: ftle_frames/ftle_0878.png
# Saved: ftle_frames/ftle_0879.png
# Saved: ftle_frames/ftle_0880.png
# Saved: ftle_frames/ftle_0881.png
# Saved: ftle_frames/ftle_0882.png
# Saved: ftle_frames/ftle_0883.png
# Saved: ftle_frames/ftle_0884.png
# Saved: ftle_frames/ftle_0885.png
# Saved: ftle_frames/ftle_0886.png
# Saved: ftle_frames/ftle_0887.png
# Saved: ftle_frames/ftle_0888.png
# Saved: ftle_frames/ftle_0889.png
# Saved: ftle_frames/ftle_0890.png
# Saved: ftle_frames/ftle_0891.png
# Saved: ftle_frames/ftle_0892.png
# Saved: ftle_frames/ftle_0893.png
# Saved: ftle_frames/ftle_0894.png
# Saved: ftle_frames/ftle_0895.png
# Saved: ftle_frames/ftle_0896.png
# Saved: ftle_frames/ftle_0897.png
# Saved: ftle_frames/ftle_0898.png
# Saved: ftle_frames/ftle_0899.png
# Saved: ftle_frames/ftle_0900.png
# Saved: ftle_frames/ftle_0901.png
# Saved: ftle_frames/ftle_0902.png
# Saved: ftle_frames/ftle_0903.png
# Saved: ftle_frames/ftle_0904.png
# Saved: ftle_frames/ftle_0905.png
# Saved: ftle_frames/ftle_0906.png
# Saved: ftle_frames/ftle_0907.png
# Saved: ftle_frames/ftle_0908.png
# Saved: ftle_frames/ftle_0909.png
# Saved: ftle_frames/ftle_0910.png
# Saved: ftle_frames/ftle_0911.png
# Saved: ftle_frames/ftle_0912.png
# Saved: ftle_frames/ftle_0913.png
# Saved: ftle_frames/ftle_0914.png
# Saved: ftle_frames/ftle_0915.png
# Saved: ftle_frames/ftle_0916.png
# Saved: ftle_frames/ftle_0917.png
# Saved: ftle_frames/ftle_0918.png
# Saved: ftle_frames/ftle_0919.png
# Saved: ftle_frames/ftle_0920.png
# Saved: ftle_frames/ftle_0921.png
# Saved: ftle_frames/ftle_0922.png
# Saved: ftle_frames/ftle_0923.png
# Saved: ftle_frames/ftle_0924.png
# Saved: ftle_frames/ftle_0925.png
# Saved: ftle_frames/ftle_0926.png
# Saved: ftle_frames/ftle_0927.png
# Saved: ftle_frames/ftle_0928.png
# Saved: ftle_frames/ftle_0929.png
# Saved: ftle_frames/ftle_0930.png
# Saved: ftle_frames/ftle_0931.png
# Saved: ftle_frames/ftle_0932.png
# Saved: ftle_frames/ftle_0933.png
# Saved: ftle_frames/ftle_0934.png
# Saved: ftle_frames/ftle_0935.png
# Saved: ftle_frames/ftle_0936.png
# Saved: ftle_frames/ftle_0937.png
# Saved: ftle_frames/ftle_0938.png
# Saved: ftle_frames/ftle_0939.png
# Saved: ftle_frames/ftle_0940.png
# Saved: ftle_frames/ftle_0941.png
# Saved: ftle_frames/ftle_0942.png
# Saved: ftle_frames/ftle_0943.png
# Saved: ftle_frames/ftle_0944.png
# Saved: ftle_frames/ftle_0945.png
# Saved: ftle_frames/ftle_0946.png
# Saved: ftle_frames/ftle_0947.png
# Saved: ftle_frames/ftle_0948.png
# Saved: ftle_frames/ftle_0949.png
# Saved: ftle_frames/ftle_0950.png
# Saved: ftle_frames/ftle_0951.png
# Saved: ftle_frames/ftle_0952.png
# Saved: ftle_frames/ftle_0953.png
# Saved: ftle_frames/ftle_0954.png
# Saved: ftle_frames/ftle_0955.png
# Saved: ftle_frames/ftle_0956.png
# Saved: ftle_frames/ftle_0957.png
# Saved: ftle_frames/ftle_0958.png
# Saved: ftle_frames/ftle_0959.png
# Saved: ftle_frames/ftle_0960.png
# Saved: ftle_frames/ftle_0961.png
# Saved: ftle_frames/ftle_0962.png
# Saved: ftle_frames/ftle_0963.png
# Saved: ftle_frames/ftle_0964.png
# Saved: ftle_frames/ftle_0965.png
# Saved: ftle_frames/ftle_0966.png
# Saved: ftle_frames/ftle_0967.png
# Saved: ftle_frames/ftle_0968.png
# Saved: ftle_frames/ftle_0969.png
# Saved: ftle_frames/ftle_0970.png
# Saved: ftle_frames/ftle_0971.png
# Saved: ftle_frames/ftle_0972.png
# Saved: ftle_frames/ftle_0973.png
# Saved: ftle_frames/ftle_0974.png
# Saved: ftle_frames/ftle_0975.png
# Saved: ftle_frames/ftle_0976.png
# Saved: ftle_frames/ftle_0977.png
# Saved: ftle_frames/ftle_0978.png
# Saved: ftle_frames/ftle_0979.png
# Saved: ftle_frames/ftle_0980.png
# Saved: ftle_frames/ftle_0981.png
# Saved: ftle_frames/ftle_0982.png
# Saved: ftle_frames/ftle_0983.png
# Saved: ftle_frames/ftle_0984.png
# Saved: ftle_frames/ftle_0985.png
# Saved: ftle_frames/ftle_0986.png
# Saved: ftle_frames/ftle_0987.png
# Saved: ftle_frames/ftle_0988.png
# Saved: ftle_frames/ftle_0989.png
# Saved: ftle_frames/ftle_0990.png
# Saved: ftle_frames/ftle_0991.png
# Saved: ftle_frames/ftle_0992.png
# Saved: ftle_frames/ftle_0993.png
# Saved: ftle_frames/ftle_0994.png
# Saved: ftle_frames/ftle_0995.png
# Saved: ftle_frames/ftle_0996.png
# Saved: ftle_frames/ftle_0997.png
# Saved: ftle_frames/ftle_0998.png
# Saved: ftle_frames/ftle_0999.png

# %%
# ftle_movie.py
import cv2
import os
import glob

frames_folder = "ftle_frames"
output_video = "ftle_movie.mp4"
fps = 20

# Get sorted list of frames
frames = sorted(glob.glob(os.path.join(frames_folder, "*.png")))

# Read first frame to get dimensions
frame_example = cv2.imread(frames[0])
height, width, layers = frame_example.shape

# Create video writer
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
video = cv2.VideoWriter(output_video, fourcc, fps, (width, height))

for frame_file in frames:
    img = cv2.imread(frame_file)
    video.write(img)

video.release()
print(f"Movie saved as {output_video}")
# Out:
# Movie saved as ftle_movie.mp4
